# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR
from time import time
import json
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData
import yfinance as yf
import os

# to run distributed training
import torch.distributed as dist
from torch.nn.parallel import DistributedDataParallel as DDP
import torch.multiprocessing as mp

# %%
print("PyTorch version " + torch.__version__)
print("Num GPUs Available: ", torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# PyTorch version 1.13.1
# Num GPUs Available:  1
# True

# %%
class DDDQN(torch.nn.Module):
    def __init__(self, input_features, window_size):
        super().__init__()
        self.input_size = input_features * window_size  # input size
        # The use of LeakyReLU activation functions can help alleviate the vanishing gradient problem
        self.leaky_relu = torch.nn.LeakyReLU(negative_slope=0.1) 
        
        # Dueling DQN architecture
        self.d1 = torch.nn.Linear(self.input_size, 256)  # input layer
        self.bn1 = torch.nn.BatchNorm1d(256)  # batch normalization  used to normalize the input layer by adjusting and scaling the activations
        self.d2 = torch.nn.Linear(256, 512)  # hidden layer
        self.bn2 = torch.nn.BatchNorm1d(512)  # batch normalization used to normalize the input layer by adjusting and scaling the activations
        self.drop1 = torch.nn.Dropout(0.5)  # dropout layer used to prevent overfitting
        self.d3 = torch.nn.Linear(512, 512)  # hidden layer
        self.bn3 = torch.nn.BatchNorm1d(512)  # batch normalization used to normalize the input layer by adjusting and scaling the activations
        self.drop2 = torch.nn.Dropout(0.5)  # dropout layer used to prevent overfitting
        self.d4 = torch.nn.Linear(512, 256)  # hidden layer
        self.bn4 = torch.nn.BatchNorm1d(256)    # batch normalization used to normalize the input layer by adjusting and scaling the activations
        self.drop3 = torch.nn.Dropout(0.3)  # dropout layer used to prevent overfitting
        self.dv1 = torch.nn.Linear(256, 128)  # value hidden layer
        self.da1 = torch.nn.Linear(256, 128)  # actions hidden layer
        self.dv2 = torch.nn.Linear(128, 1)  # value output
        self.da2 = torch.nn.Linear(128, 9)  # actions output

    # forward propagation
    def forward(self, input_data):
        input_data = input_data.reshape(input_data.size(0), -1)  # Flatten the input tensor
        x = self.leaky_relu(self.d1(input_data))  # activation function
        x = self.bn1(x)  # batch normalization
        x = x.view(x.size(0), -1)  # equivalent to Flatten()
        x = self.leaky_relu(self.d2(x))  # activation function
        x = self.bn2(x)  # batch normalization
        x = self.drop1(x)  # dropout
        x = self.leaky_relu(self.d3(x))  # activation function
        x = self.bn3(x)  # batch normalization
        x = self.drop2(x)  # dropout
        x = self.leaky_relu(self.d4(x))   # activation function
        x = self.bn4(x)  # batch normalization
        x = self.drop3(x)  # dropout
        v = self.leaky_relu(self.dv1(x))  # value function
        a = self.leaky_relu(self.da1(x))  # actions function
        v = self.dv2(v)     # value output
        a = self.da2(a)   # actions output
        Q = v + (a - torch.mean(a, dim=1, keepdim=True)) # dueling Q values
        return Q   # return Q values
    
    # advantage function is used to calculate the advantage of taking each action at each state
    # processes the input state through the common layers and then the advantage stream layers.
    # used for debugging or analysis purposes.
    def advantage(self, state):
        # Common processing
        x = self.leaky_relu(self.d1(state))
        x = self.bn1(x)
        x = self.leaky_relu(self.d2(x))
        x = self.bn2(x)
        x = self.drop1(x)
        x = self.leaky_relu(self.d3(x))
        x = self.bn3(x)
        x = self.drop2(x)
        x = self.leaky_relu(self.d4(x))
        x = self.bn4(x)
        x = self.drop3(x)

        # Advantage stream processing
        a = self.leaky_relu(self.da1(x))  # actions function 
        a = self.da2(a) # actions output

        return a  # return advantage values

# %%
import numpy as np
import torch

# The sumtree is used to store the priorities of the experiences it receives and to sample the experiences based on their priorities.
class SumTree:
    def __init__(self, capacity):
        self.capacity = capacity   # capacity of the sumtree
        self.tree = np.zeros(2 * capacity - 1) # stores the priorities
        self.data = np.zeros(capacity, dtype=object)  # stores the experiences
        self.write = 0  # pointer to the next experience to be stored
        self.n_entries = 0  # number of experiences stored

    def _propagate(self, idx, change): # propagate the change in the priority value up the tree
        parent = (idx - 1) // 2  # parent node
        self.tree[parent] += change  # update the priority value
        if parent != 0:  # if the parent node is not the root node
            self._propagate(parent, change)  # propagate the change in the priority value up the tree

    def _retrieve(self, idx, s):  # retrieve the experience based on the priority value
        left = 2 * idx + 1  # left node
        right = left + 1  # right node
        if left >= len(self.tree):  # if the left node is a leaf node
            return idx  # return the index of the leaf node
        if s <= self.tree[left]:  # if the priority value is less than or equal to the priority value of the left node
            return self._retrieve(left, s)  # retrieve the experience from the left node
        else: # if the priority value is greater than the priority value of the left node
            return self._retrieve(right, s - self.tree[left])  # retrieve the experience from the right node

    def total(self):  # return the total priority value of the sumtree
        return self.tree[0]  # return the priority value of the root node

    def add(self, data, p):  # add the experience and its priority value to the sumtree
        idx = self.write + self.capacity - 1  # index of the leaf node
        self.data[self.write] = data  # store the experience
        self.update(idx, p)  # update the priority value of the leaf node
        self.write += 1  # increment the pointer to the next experience to be stored
        if self.write >= self.capacity:  # if the pointer to the next experience to be stored exceeds the capacity of the sumtree
            self.write = 0  # reset the pointer to the next experience to be stored
        if self.n_entries < self.capacity:   # if the number of experiences stored is less than the capacity of the sumtree
            self.n_entries += 1  # increment the number of experiences stored

    def update(self, idx, p): # update the priority value of the leaf node
        change = p - self.tree[idx] # change in the priority value
        self.tree[idx] = p # update the priority value
        self._propagate(idx, change) # propagate the change in the priority value up the tree

    def get(self, s): # retrieve the experience based on the priority value
        idx = self._retrieve(0, s)  # retrieve the experience
        dataIdx = idx - self.capacity + 1 # index of the experience
        return idx, self.tree[idx], self.data[dataIdx]  # return the index of the experience, the priority value of the experience, and the experience

# The prioritized experience replay buffer is used to store the experiences and sample the experiences based on their priorities.
class PrioritizedExpReplay():    
    def __init__(self, num_features, window_size, device, buffer_size=1000000, alpha=0.6, beta=0.4): # initialize the prioritized experience replay buffer
        self.tree = SumTree(buffer_size) # initialize the sumtree
        self.alpha = alpha # initialize the alpha value which is used to control the amount of prioritization
        self.beta = beta    # initialize the beta value which is used to control the amount of importance sampling
        self.device = device    # initialize the device (GPU)
        self.buffer_size = buffer_size # initialize the capacity of the sumtree
        self.window_size = window_size # initialize the window size
        self.num_features = num_features    # initialize the number of features

    def add_exp(self, state, action, reward, next_state, done):
        max_priority = np.max(self.tree.tree[-self.tree.capacity:])
        if max_priority == 0:
            max_priority = 1
        exp = (state, action, reward, next_state, done)
        self.tree.add(exp, max_priority ** self.alpha)

    def sample_exp(self, batch_size=64):
        batch = []
        idxs = []
        segment = self.tree.total() / batch_size
        priorities = []

        for i in range(batch_size):
            a = segment * i
            b = segment * (i + 1)
            s = np.random.uniform(a, b)
            idx, p, exp = self.tree.get(s)
            priorities.append(p)
            batch.append(exp)
            idxs.append(idx)

        sampling_probabilities = np.array(priorities) / self.tree.total()
        is_weights = np.power(self.tree.n_entries * sampling_probabilities, -self.beta)
        is_weights /= np.max(is_weights)

        
        states, actions, rewards, next_states, dones = zip(*batch)
        
        states = torch.tensor(states, dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.int64).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(self.device)
        next_states = torch.tensor(next_states, dtype=torch.float32).to(self.device)
        dones = torch.tensor(dones, dtype=torch.bool).to(self.device)
        is_weights = torch.tensor(is_weights, dtype=torch.float32).to(self.device)
        
        return states, actions, rewards, next_states, dones, idxs, is_weights

    def update_priorities(self, idxs, td_errors):
        priorities = np.abs(td_errors) + 1e-5
        for idx, priority in zip(idxs, priorities):
            self.tree.update(idx, priority ** self.alpha)

# %%
class Agent():

    # Initializes the agent with various parameters such as window_size, gamma, number of episodes, learning rate, minimum epsilon, and update interval. 
    # It also initializes the device, portfolio, epsilon, training step counter, memory, batch size, online and target networks, optimizer, scheduler, 
    # and the holding time.
    def __init__(self, data_shape, num_episodes, window_size=30, gamma=0.99, update_interval=30, lr=0.001, min_epsilon=0.02):
        
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.window_size = window_size  # number of previous prices to use as state
        self.data_shape = data_shape  # [num_features, window_size]
        self.portfolio = [0, 0, 0, 0]  # [total eth, cash_held, total_portfolio_value (eth value + cash held - initial investment), max ether held so far]
        self.inventory = [] 
        self.gamma = gamma  # discount factor for future rewards
        self.num_episodes = num_episodes    # number of episodes
        self.epsilon = 1.0  # exploration rate
        self.min_epsilon = min_epsilon   # minimum exploration rate
        self.update_interval = update_interval  # number of steps between target network updates
        self.trainstep = 0
        # self.memory = ExpReplay(self.window_size, data_shape[1], self.device)        
        self.memory = PrioritizedExpReplay(self.window_size, data_shape[1], self.device)
        self.batch_size = 64
        self.online_net = DDDQN(self.data_shape[1], window_size).to(self.device)
        self.target_net = DDDQN(self.data_shape[1], window_size).to(self.device)
        self.target_net.load_state_dict(self.online_net.state_dict())
        self.holding_time = 0 # Number of timesteps for which the agent has held the position
        initial_learning_rate = lr
        decay_steps = self.num_episodes * self.data_shape[0] // 10  # You can adjust the divisor to control the decay rate
        decay_rate = 0.9  # You can adjust this value to control the decay rate
        self.optimizer = optim.Adam(self.online_net.parameters(), lr=initial_learning_rate)
        self.scheduler = ExponentialLR(self.optimizer, gamma=decay_rate)
        self.criterion = nn.MSELoss()

    # CURRICULUM TRAINING PART 1
    def get_action(self, state):
            state_numpy = np.array(state)
            state_tensor = torch.FloatTensor(state_numpy).to(self.device).unsqueeze(0)
            # create a random number between 0 and 1 and compare it to epsilon for our epsilon-greedy algorithm
            if np.random.rand() <= self.epsilon:
                # Select a random action out of the list of available actions
                if len(self.inventory) > 0:  # if we have inventory to sell
                    return np.random.choice([0, 1, 2, 3, 4, 5, 6, 7, 8])
                else:
                    return np.random.choice([4, 5, 6, 7, 8])  # we can only buy or hold
            else:
                with torch.no_grad():
                    self.online_net.eval()
                    actions = self.online_net(state_tensor)
                    # actions = self.online_net.advantage(state_tensor)
                    self.online_net.train()

                    if len(self.inventory) > 0:
                        action = torch.argmax(actions[0, :]).item()
                    else: # if we don't have inventory to sell, we remove that action option
                        action = torch.argmax(actions[0, 4:]).item() + 4
                    return action

    # # CURRICULUM TRAINING PART 2
    # # Takes the current state and cash balance as inputs and returns an action based on epsilon-greedy exploration strategy.
    # # It returns an action between 0 and 8, depending on the random number generated and the current portfolio status.
    # def get_action(self, state, cash_balance):
    #     eth_held = self.portfolio[0]
    #     cash_held = self.portfolio[1]
    #     total_portfolio_value = self.portfolio[2]
    #     max_eth_held = self.portfolio[3]
    #     state_numpy = np.array(state)
    #     state_tensor = torch.FloatTensor(state_numpy).to(self.device).unsqueeze(0)
    #     if np.random.rand() <= self.epsilon:
    #         # print("Random action based on epsilon")
    #         if eth_held > 0.001 and cash_balance >= 10 and len(self.inventory) > 0:# if we have ether and cash
    #             # print("we have ether and cash so our options are [0, 1, 2, 3, 4, 5, 6, 7, 8]")
    #             return np.random.choice([0, 1, 2, 3, 4, 5, 6, 7, 8])  # we can perform any action
    #         elif eth_held > 0.001 and cash_balance < 10:  # if we have ether but no cash
    #             # print("we have ether but no cash so our options are [0, 1, 2, 3, 4]")
    #             return np.random.choice([0, 1, 2, 3, 4])  # we can only sell or hold
    #         elif eth_held <= 0.001 and cash_balance >= 10:  # if we have cash but no ether
    #             # print("we have cash but no ether so our options are [4, 5, 6, 7, 8]")
    #             return np.random.choice([4, 5, 6, 7, 8])  # we can only buy or hold
    #         else:
    #             # print("we have neither cash nor ether so our only option is 4")
    #             action = 4  # hold
    #             return action
    #     else:
    #         # print("Action based on neural network output")
    #         with torch.no_grad():
    #             self.online_net.eval()
    #             actions = self.online_net(state_tensor)
    #             self.online_net.train()
    #             # print(f"Neural network output: {actions}")
                
    #             if eth_held > 0.001 and cash_balance >= 10:
    #                 # print("we have ether and cash so our options are [0, 1, 2, 3, 4, 5, 6, 7, 8]")
    #                 action = torch.argmax(actions[0, :]).item()
    #             elif eth_held > 0.001 and cash_balance < 10:
    #                 # print("we have ether but no cash so our options are [0, 1, 2, 3, 4]")
    #                 action = torch.argmax(actions[0, :5]).item()
    #             elif eth_held <= 0.001 and cash_balance >= 10:
    #                 # print("we have cash but no ether so our options are [4, 5, 6, 7, 8]")
    #                 action = torch.argmax(actions[0, 4:]).item() + 4
    #             else:
    #                 # print("we have neither cash nor ether so our only option is 4")
    #                 action = 4
        
    #     # print(f"Selected action: {action}")
    #     return action



    #  This method softly updates the target network by blending the weights of the online network and target network using the parameter tau.
    def update_target(self, tau=0.001):
        for target_param, online_param in zip(self.target_net.parameters(), self.online_net.parameters()):
            target_param.data.copy_(tau * online_param.data + (1.0 - tau) * target_param.data)

    #  Linearly decays the epsilon value from its initial value to the minimum epsilon value over the course of the total training steps.
    def update_epsilon(self):
        if self.epsilon > self.min_epsilon:
            # b = self.min_epsilon**(1/(self.num_episodes*self.data_shape[0]))
            # self.epsilon = b**self.trainstep # exponential decay
            self.epsilon -= (1.0 - self.min_epsilon) / (self.num_episodes * self.data_shape[0])   # linear decay

    # Trains the online network using the samples from the prioritized experience replay memory. 
    # It updates the target network periodically based on the update_interval. 
    # It also calculates the loss, applies the importance sampling weights, and updates the priorities in the buffer.
    def train(self):
        if self.memory.tree.n_entries < self.batch_size:
            return

        if self.trainstep % self.update_interval == 0:
            self.update_target()

        states, actions, rewards, next_states, dones, idxs, is_weights = self.memory.sample_exp(self.batch_size)

        q_next_state_online_net = self.online_net(next_states)
        q_next_state_target_net = self.target_net(next_states)

        max_action = torch.argmax(q_next_state_online_net, dim=1).to(self.device)

        batch_index = torch.arange(self.batch_size, dtype=torch.int64).to(self.device)

        q_predicted = self.online_net(states)
        q_target = q_predicted.clone().detach()

        q_target[batch_index, actions] = rewards + self.gamma * q_next_state_target_net[batch_index, max_action] * dones

        td_errors = q_target - q_predicted
        td_errors = td_errors.detach().cpu().numpy()
        td_errors = td_errors[np.arange(self.batch_size), actions.cpu().numpy()]

        # Update priorities in the buffer
        self.memory.update_priorities(idxs, td_errors)

        # loss = self.criterion(q_predicted, q_target)
        # loss *= is_weights  # Apply importance sampling weights
        # loss = loss.mean()

        loss = self.criterion(q_predicted, q_target).view(-1, 1)
        loss = (loss * is_weights).mean()

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.update_epsilon()
        self.trainstep += 1
        return loss.item()

    # This method is called to save the model parameters of the online and target networks in the Output folder.
    def save_model(self):
        import os

        output_directory = "Output"
        online_model_directory = os.path.join(output_directory, "online_model")
        target_model_directory = os.path.join(output_directory, "target_model")

        os.makedirs(online_model_directory, exist_ok=True)
        os.makedirs(target_model_directory, exist_ok=True)

        torch.save(self.online_net.state_dict(), os.path.join(online_model_directory, 'model.pt'))
        torch.save(self.target_net.state_dict(), os.path.join(target_model_directory, 'model.pt'))

    # This method is called to load the model parameters of the online and target networks from the Output folder.
    def load_model(self):
        import os

        output_directory = "Output"
        online_model_directory = os.path.join(output_directory, "online_model")
        print("loaded model from: ", online_model_directory)
        target_model_directory = os.path.join(output_directory, "target_model")
        print("loaded model from: ", target_model_directory)


        self.online_net.load_state_dict(torch.load(os.path.join(online_model_directory, 'model.pt')))
        self.target_net.load_state_dict(torch.load(os.path.join(target_model_directory, 'model.pt')))

    # This method is called to calculate the reward for the sell action.
    # def calculate_sell_reward(self, t, eth_df, eth_close_price_unscaled, amount_to_sell, initial_investment, trading_fee_rate):
    #     ether_held, cash_held, previous_portfolio_value, max_ether_held_so_far = self.portfolio

    #     unscaled_close_price = eth_close_price_unscaled["Close"].iloc[t]
    #     value_of_eth_sold = unscaled_close_price * amount_to_sell
    #     trading_fee = value_of_eth_sold * trading_fee_rate
    #     cash_received = value_of_eth_sold - trading_fee
    #     new_cash_held = cash_held + cash_received
    #     new_ether_held = ether_held - amount_to_sell

    #     # Calculate portfolio value
    #     # new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price) - initial_investment
    #     new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price)
    #     # Calculate the reward based on the change in portfolio value
    #     reward = (new_portfolio_value - previous_portfolio_value) / initial_investment

    #     # Update portfolio
    #     self.portfolio = [new_ether_held, new_cash_held, new_portfolio_value, max_ether_held_so_far]

    #     # Add a bonus if the portfolio value is greater than the initial investment
    #     if new_portfolio_value > initial_investment:
    #         bonus = min((new_portfolio_value - initial_investment) / initial_investment, 0.5)
    #         reward = reward * (1 + bonus)

    #     return reward

    # # This method is called to calculate the reward for the buy action.
    # def calculate_buy_reward(self, t, eth_df, eth_close_price_unscaled, eth_to_buy, cash_spent, initial_investment):
    #     ether_held, cash_held, previous_portfolio_value, max_ether_held_so_far = self.portfolio

    #     unscaled_close_price = eth_close_price_unscaled["Close"].iloc[t]
    #     eth_received = eth_to_buy  # trading fee is already accounted for in the amount of ETH to buy
    #     new_cash_held = cash_held - cash_spent
    #     new_ether_held = ether_held + eth_received
    #     # Calculate portfolio value
    #     # new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price) - initial_investment
    #     new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price)
    #     # Calculate the reward based on the change in portfolio value
    #     # reward = (new_portfolio_value - previous_portfolio_value) / initial_investment
    #     reward_eth_held = (new_ether_held - max_ether_held_so_far) / (new_ether_held + max_ether_held_so_far)

    #     if new_ether_held > max_ether_held_so_far:
    #         max_ether_held_so_far = new_ether_held
        
    #     # Combine the rewards
    #     reward = reward_eth_held

    #     # Update portfolio
    #     self.portfolio = [new_ether_held, new_cash_held, new_portfolio_value, max_ether_held_so_far]

    #     # Add a bonus if the portfolio value is greater than the initial investment
    #     if new_portfolio_value > initial_investment:
    #         bonus = min((new_portfolio_value - initial_investment) / initial_investment, 0.5)
    #         reward = reward * (1 + bonus)

    #     return reward

    # # Takes an action and updates the portfolio accordingly. 
    # # It calculates the reward for the action and applies a penalty if the agent doesn't have enough 
    # # Ethereum or cash balance to perform the requested action.
    # def trade(self, t, action, eth_df, eth_df_unscaled, initial_investment, trading_fee_rate):
    #     reward = 0
    #     eth_held, cash_balance, previous_portfolio_value, max_ether_held_so_far = self.portfolio
    #     sell_percentages = [0.25, 0.5, 0.75, 1.0]
    #     buy_percentages = [0.25, 0.5, 0.75, 1.0]

    #     # SELL
    #     if action >= 0 and action <= 3:
    #         print("SELL with action: ", action)
    #         # Reset holding time when selling
    #         self.holding_time = 0
    #         sell_percentage = sell_percentages[action]
    #         amount_to_sell = eth_held * sell_percentage

    #         while amount_to_sell > 0 and eth_held > 0.001:

    #             reward = self.calculate_sell_reward(t, eth_df, eth_df_unscaled, amount_to_sell, initial_investment, trading_fee_rate)

    #             eth_held, cash_balance, current_portfolio_value, max_ether_held_so_far = self.portfolio  # Update portfolio after selling
    #             amount_to_sell = 0
    #     # HOLD
    #     elif action == 4:
    #         print("HOLD with action: ", action)
    #         # self.portfolio[2] = cash_balance + (eth_held * eth_df_unscaled["Close"].iloc[t]) - initial_investment
    #         self.portfolio[2] = cash_balance + (eth_held * eth_df_unscaled["Close"].iloc[t])
    #         # Increment holding time when holding
    #         self.holding_time += 1
    #         # Apply a holding time reward
    #         reward = -0.01 * self.holding_time
    #     # BUY
    #     elif action >= 5:
    #         print("BUY with action: ", action)
    #         # Reset holding time when buying
    #         self.holding_time = 0
    #         buy_percentage = buy_percentages[action - 5]
    #         money_to_spend = (cash_balance * buy_percentage)
    #         trading_fee = money_to_spend * trading_fee_rate
    #         eth_to_buy = (money_to_spend - trading_fee) / eth_df_unscaled["Close"].iloc[t]
    #         cash_spent = eth_to_buy * eth_df_unscaled["Close"].iloc[t]

    #         reward = self.calculate_buy_reward(t, eth_df, eth_df_unscaled, eth_to_buy, cash_spent, initial_investment)

    #     return reward
    
    def trade(self, t, action, eth_df, eth_df_unscaled, initial_investment, trading_fee_rate):
        eth_held, balance, previous_portfolio_value, max_ether_held_so_far = self.portfolio
        reward = 0
        if action >= 0 and action <= 3:
            # reward = eth_df_unscaled["Close"].iloc[t] - self.inventory.pop(0) # this sells the oldest bought eth
            reward = eth_df_unscaled["Close"].iloc[t] - self.inventory.pop() # this sells the most recently bought eth (worth a shot)
        elif action == 4:
            reward = -0.1
            pass
        elif action >= 5 and balance >= eth_df_unscaled["Close"].iloc[t]:
            self.inventory.append(eth_df_unscaled["Close"].iloc[t])
        return reward

    def get_state(self, t, eth_df):
        num_rows = t - self.window_size + 1
        if num_rows >= 0:
            window = eth_df.iloc[num_rows : t + 1]
        else:
            repeated_first_row = pd.concat([pd.DataFrame(np.repeat(eth_df.iloc[[0]].values, -num_rows, axis=0), columns=eth_df.columns)])
            new_data = eth_df.iloc[0 : t + 1]
            window = pd.concat([repeated_first_row, new_data], ignore_index=True)  # prevents us from sampling data that doesn't exist at the start.
        return window.values

# %%
def get_crypto_data(start_date, end_date, split_date):
    try:
        train = pd.read_csv("Datasets/train_eth.csv", index_col=0)
        test = pd.read_csv("Datasets/test_eth.csv", index_col=0)
    except:
        df = HistoricalData('ETH-USD', 3600, start_date, end_date).retrieve_data()  # 3600 is the interval in seconds which is 1 hour
        split_row = df.index.get_loc(split_date)
        cols = df.columns.tolist()
        df = pd.DataFrame(MinMaxScaler().fit_transform(df), columns=cols)
        train = df[:split_row]
        test = df[split_row:]
        train.to_csv("Datasets/train_eth.csv")
        test.to_csv("Datasets/test_eth.csv")
    return train, test

# %%
def get_crypto_data(start_date, end_date):
    historic_data_df = HistoricalData('ETH-USD', 21600, start_date, end_date).retrieve_data()  # 3600 is the interval in seconds which is 1 hour
    cols = historic_data_df.columns.tolist()
    historic_data_df = pd.DataFrame(MinMaxScaler().fit_transform(historic_data_df), columns=cols)
    historic_data_df.to_csv("Datasets/train_eth.csv")
    return historic_data_df

# %%
# pre-collected data
def get_precollected_data(split_ratio=0.8):
    # try:
    # historic_data = pd.read_csv("Datasets/eth_historical_data_simple.csv", index_col=0)
    historic_data = pd.read_csv("Datasets/eth_combined_hourly_daily.csv", index_col=0)
    print('Pre-collected data loaded successfully.')
    # convert date to datetime if it isn't the index
    if historic_data.index.name != 'Date':
        historic_data['Date'] = pd.to_datetime(historic_data['Date'], infer_datetime_format=True)
        print('Date converted to datetime.')
        # set date as index
        historic_data = historic_data.set_index('Date')
        print('Date set as index.')
    # drop nan values
    historic_data = historic_data.dropna()
    print('NaN values dropped.')
    cols = historic_data.columns.tolist()
    train_unscaled, test_unscaled = train_test_split(historic_data, train_size=split_ratio,shuffle=False)
    train_scaled = pd.DataFrame(MinMaxScaler().fit_transform(train_unscaled), columns=cols)
    test_scaled = pd.DataFrame(MinMaxScaler().fit_transform(test_unscaled), columns=cols)
    print('Data split.')
    # set the index to the date
    train_unscaled = pd.DataFrame(train_unscaled,  columns=cols)
    test_unscaled = pd.DataFrame(test_unscaled,  columns=cols)
    # convert train_unscaled and test_unscaled to df with only the Open, High, Low, and Close column
    train_unscaled = train_unscaled[['Low', 'High', 'Open', 'Close', 'Yesterday_Open', 'Yesterday_High', 'Yesterday_Low', 'Yesterday_Close']]
    test_unscaled = test_unscaled[['Low', 'High', 'Open', 'Close', 'Yesterday_Open', 'Yesterday_High', 'Yesterday_Low', 'Yesterday_Close']]

    train_unscaled.to_csv("Output/train_unscaled.csv")
    train_scaled.to_csv("Output/train_scaled.csv")
    print('Train data saved.')
    test_unscaled.to_csv("Output/test_unscaled.csv")
    test_scaled.to_csv("Output/test_scaled.csv")
    print('Test data saved.')
    return train_scaled, test_scaled, train_unscaled, test_unscaled
        
    # except:
    #     # throw error
    #     print("No pre-collected data found. Please run the data collection script first.")
    #     exit()

# %%
# historic_data = pd.read_csv("Datasets/eth_historical_data_simple.csv", index_col=0)
historic_data = pd.read_csv("Datasets/eth_combined_hourly_daily.csv", index_col=0)
historic_data.head()
# Out:
#                    Low    High    Open   Close       Volume  Yesterday_Open  \
# Date
# 7/20/2019 0:00  220.78  224.49  221.30  221.57  7137.372100        226.6577
# 7/20/2019 1:00  219.98  222.15  221.57  221.06  3254.139090        226.6577
# 7/20/2019 2:00  221.15  226.66  221.16  225.69  4862.143208        226.6577
# 7/20/2019 3:00  225.62  229.00  225.62  227.20  5270.123232        226.6577
# 7/20/2019 4:00  226.56  228.94  227.20  228.36  3139.452682        226.6577
#
#                 Yesterday_High  Yesterday_Low  Yesterday_Close  \
# Date
# 7/20/2019 0:00      226.940475     215.838242        221.33342
# 7/20/2019 1:00      226.940475     215.838242        221.33342
# 7/20/2019 2:00      226.940475     215.838242        221.33342
# 7/20/2019 3:00      226.940475     215.838242        221.33342
# 7/20/2019 4:00      226.940475     215.838242        221.33342
#
#                 Yesterday_Volume  ...  Yesterday_Volume_USDC  \
# Date                              ...
# 7/20/2019 0:00        7606433131  ...            123323972.0
# 7/20/2019 1:00        7606433131  ...            123323972.0
# 7/20/2019 2:00        7606433131  ...            123323972.0
# 7/20/2019 3:00        7606433131  ...            123323972.0
# 7/20/2019 4:00        7606433131  ...            123323972.0
#
#                 Yesterday_VolumeDelta_USDC  Yesterday_7day_Past_Mean_Price  \
# Date
# 7/20/2019 0:00                 -46731557.0                      226.483728
# 7/20/2019 1:00                 -46731557.0                      226.483728
# 7/20/2019 2:00                 -46731557.0                      226.483728
# 7/20/2019 3:00                 -46731557.0                      226.483728
# 7/20/2019 4:00                 -46731557.0                      226.483728
#
#                 Yesterday_Yesterday_Volume  Yesterday_3day_Past_Mean_Volume  \
# Date
# 7/20/2019 0:00                  9327816059                       8773998943
# 7/20/2019 1:00                  9327816059                       8773998943
# 7/20/2019 2:00                  9327816059                       8773998943
# 7/20/2019 3:00                  9327816059                       8773998943
# 7/20/2019 4:00                  9327816059                       8773998943
#
#                 Yesterday_7day_Past_Mean_Volume  Yesterday_Yesterday_Vol_USDT  \
# Date
# 7/20/2019 0:00                       8625351483                  2.660702e+10
# 7/20/2019 1:00                       8625351483                  2.660702e+10
# 7/20/2019 2:00                       8625351483                  2.660702e+10
# 7/20/2019 3:00                       8625351483                  2.660702e+10
# 7/20/2019 4:00                       8625351483                  2.660702e+10
#
#                 Yesterday_3day_Past_Mean_Vol_USDT  \
# Date
# 7/20/2019 0:00                       2.550249e+10
# 7/20/2019 1:00                       2.550249e+10
# 7/20/2019 2:00                       2.550249e+10
# 7/20/2019 3:00                       2.550249e+10
# 7/20/2019 4:00                       2.550249e+10
#
#                 Yesterday_7day_Past_Mean_Vol_USDT  Yesterday_RSI
# Date
# 7/20/2019 0:00                       2.516096e+10      37.863434
# 7/20/2019 1:00                       2.516096e+10      37.863434
# 7/20/2019 2:00                       2.516096e+10      37.863434
# 7/20/2019 3:00                       2.516096e+10      37.863434
# 7/20/2019 4:00                       2.516096e+10      37.863434
#
# [5 rows x 48 columns]

# %%
def main(trading_agent, train_df, test_df, train_close, test_close):

    # # CURRICULUM 1
    episode_mem = [{"Actions": [], "Inventory Size": [], "Portfolio Value": [], "Realized Profit": [], "Reward": [], "Done": [], "Epsilon": [], "MSE Loss": []} for i in range(NUM_EPISODES)]
    # # CURRICULUM 2
    # # episode_mem = [{"Actions": [], "Eth Held": [], "Cash Held": [], "Portfolio Value": [], "Reward": [], "Done": [], "Epsilon": [], "MSE Loss": []} for i in range(NUM_EPISODES)]
    t0 = time()

    # ######################## Training ########################
    for s in range(NUM_EPISODES):
        print(f"\n===== Episode {s + 1} / {NUM_EPISODES} =====")
        trading_agent.inventory = []
        state = trading_agent.get_state(0, train_df)
        balance = INITIAL_INVESTMENT
        # portfolio_value_usd = INITIAL_INVESTMENT
        portfolio_value_usd = 0
        # Reset the agent's portfolio at the beginning of each episode
        trading_agent.portfolio = [0 , INITIAL_INVESTMENT, portfolio_value_usd, 0]

        done = False
        for t in range(len(train_df) - 1):
            if done:
                break

            # CURRICULUM 1
            action = trading_agent.get_action(state)
            next_state = trading_agent.get_state(t + 1, train_df)
            reward = trading_agent.trade(t, action, train_df, train_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
            balance += reward
            done = balance < train_close["Close"].iloc[t]  # if we run out of money to buy, consider the episode "done"
            trading_agent.memory.add_exp(state, action, reward, next_state, done)
            loss = trading_agent.train()


            # CURRICULUM 2
            # action = trading_agent.get_action(state, cash_balance)
            # next_state = trading_agent.get_state(t + 1, train_df)
            # reward = trading_agent.trade(t, action, train_df, train_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
            # eth_held, cash_held, new_portfolio_value, max_ether_held_so_far = trading_agent.portfolio
            # cash_balance = cash_held  # update cash balance
            # portfolio_value_usd = new_portfolio_value  # update portfolio value
            
            # if t != 0:  # if not the first trade
            #     done = cash_balance <= 10 and eth_held <= 0.001
            # trading_agent.memory.add_exp(state, action, reward, next_state, done)
            # loss = trading_agent.train()
            
            if not loss:
                loss = 0
            state = next_state
            
            # CURRICULUM 1
            episode_mem[s]["Actions"].append(int(action))
            episode_mem[s]["Inventory Size"].append(len(trading_agent.inventory))
            episode_mem[s]["Portfolio Value"].append(float(balance + train_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)) - INITIAL_INVESTMENT)
            episode_mem[s]["Realized Profit"].append(float(balance - INITIAL_INVESTMENT))
            episode_mem[s]["Reward"].append(float(reward))
            episode_mem[s]["Done"].append(bool(done))
            episode_mem[s]["Epsilon"].append(trading_agent.epsilon)
            episode_mem[s]["MSE Loss"].append(loss)

            if t % 1 == 0:
                print(f"Time step {t} / {len(train_df)}   |   Portfolio Value: {round(episode_mem[s]['Portfolio Value'][t], 3)}   |   Inventory: {len(trading_agent.inventory)}   |   Reward: {float(reward)}   |   Epsilon: {round(trading_agent.epsilon, 4)}   |   MSE Loss: {loss}")
            
        # if we have leftover inventory at the end of the episode, calculate its value by selling them all at the current market rate
        balance += train_df["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)

            # CURRICULUM 2
            # episode_mem[s]["Actions"].append(int(action))
            # episode_mem[s]["Eth Held"].append(float(eth_held))
            # episode_mem[s]["Cash Held"].append(round(float(cash_balance), 2))
            # episode_mem[s]["Portfolio Value"].append(float(portfolio_value_usd))
            # episode_mem[s]["Reward"].append(float(reward))
            # episode_mem[s]["Done"].append(bool(done))
            # episode_mem[s]["Epsilon"].append(trading_agent.epsilon)
            # episode_mem[s]["MSE Loss"].append(float(loss))

            # if t % 1 == 0:
            #     print(f"Time step {t} / {len(train_df)}   |  Eth: {round(episode_mem[s]['Eth Held'][t], 7)}  |  Cash: {round(episode_mem[s]['Cash Held'][t], 2)}  |  Portfolio Value: {round(episode_mem[s]['Portfolio Value'][t], 3)}  |   MSE: {round(episode_mem[s]['MSE Loss'][t], 3)}  |  Reward: {round(episode_mem[s]['Reward'][t], 3)}  |  Action: {int(episode_mem[s]['Actions'][t])}  |  Epsilon: {round(trading_agent.epsilon, 3)}")

    
    with open('Output/training_scores.out', 'a') as f:
        f.write(f"EPISODE {s} (runtime: {time() - t0})   | Portfolio Value is {round(episode_mem[s]['Portfolio Value'][-1], 3)} Epsilon is {round(trading_agent.epsilon, 3)}   |   MSE Loss is {round(episode_mem[s]['MSE Loss'][-1], 3)}\n")
    # Save the episode memory to a json file, if one exists, add a number to the end of the file name
    episode_mem_file = "Output/episode_mem.json"

    with open(episode_mem_file, 'w') as f:
        json.dump(episode_mem, f)

######################## Testing ########################
    t0 = time()
    # CURRICULUM 1
    testing_mem = {"Actions": [], "Inventory Size": [], "Portfolio Value": [], "Realized Profit": [], "Reward": [], "Done": []}
    # CURRICULUM 2
    # testing_mem = {"Actions": [], "Eth Held": [], "Cash Held": [], "Portfolio Value": [], "Reward": [], "Done": []}
    trading_agent.epsilon = 0
    trading_agent.inventory = [] # inventory reset
    state = trading_agent.get_state(0, test_df)
    balance = INITIAL_INVESTMENT
    # portfolio_value_usd = INITIAL_INVESTMENT
    portfolio_value_usd = 0
    # Reset the agent's portfolio at the beginning of each episode
    trading_agent.portfolio = [0 , INITIAL_INVESTMENT, portfolio_value_usd, 0]
    # Reset the agent's portfolio at the beginning of each episode

    done = False
    for t in range(len(test_df) - 1):
        if done:
            print("Done with testing")
            break

        # CURRICULUM 1
        action = trading_agent.get_action(state)
        next_state = trading_agent.get_state(t + 1, test_df)
        reward = trading_agent.trade(t, action, test_df, test_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
        balance += reward
        done = balance < test_close["Close"].iloc[t]
        state = next_state


        # CURRICULUM 2
        # action = trading_agent.get_action(state, cash_balance)
        # next_state = trading_agent.get_state(t + 1, test_df)
        # reward = trading_agent.trade(t, action, test_df, test_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
        # eth_held, cash_held, new_portfolio_value, max_ether_held_so_far  = trading_agent.portfolio
        # cash_balance = cash_held  # update cash balance
        # portfolio_value_usd = new_portfolio_value  # update portfolio value
        # if t != 0:  # if not the first trade
        #         done = cash_balance <= 10 and eth_held <= 0.001
        # state = next_state

        # CURRICULUM 1
        testing_mem["Actions"].append(int(action))
        testing_mem["Inventory Size"].append(len(trading_agent.inventory))
        testing_mem["Portfolio Value"].append(float(balance + test_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)) - INITIAL_INVESTMENT)
        testing_mem["Realized Profit"].append(float(balance - INITIAL_INVESTMENT))
        testing_mem["Reward"].append(float(reward))
        testing_mem["Done"].append(bool(done))

        if t % 1 == 0:
            print(f"Time step {t} / {len(test_df)}   |   Inventory Size: {len(trading_agent.inventory)}  |  Portfolio Value: {round(testing_mem['Portfolio Value'][t], 3)}   |  Action: {int(action)}  |  Reward: {round(reward, 3)}")

        # CURRICULUM 2
        # testing_mem["Actions"].append(int(action))
        # testing_mem["Eth Held"].append(float(eth_held))
        # testing_mem["Cash Held"].append(round(float(cash_balance),2))
        # testing_mem["Portfolio Value"].append(float(portfolio_value_usd))
        # testing_mem["Reward"].append(float(reward))
        # testing_mem["Done"].append(bool(done))

        # if t % 1 == 0:
        #     print(f"Time step {t} / {len(test_df)}   |   Eth Held: {round(testing_mem['Eth Held'][t], 7)}  |  Cash Held: {round(testing_mem['Cash Held'][t], 2)}  |  Portfolio Value: {round(testing_mem['Portfolio Value'][t], 3)}   |  Action: {int(action)}  |  Reward: {round(reward, 3)}")
    balance += train_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)

    with open('Output/testing_scores.out', 'a') as f:
        f.write(f"TESTING (runtime: {time() - t0})   |  Portfolio Value is {round(testing_mem['Portfolio Value'][-1], 3)}\n")

    # save the testing memory to a json file
    testing_mem_file = "Output/testing_mem.json"
    with open(testing_mem_file, 'w') as f:
        json.dump(testing_mem, f)

if __name__ == "__main__":
    
    INITIAL_INVESTMENT = 10000
    NUM_EPISODES = 10
    START_DATE = "2017-01-01-00-00"
    END_DATE = "2020-01-01-00-00"
    TESTING_SPLIT = "2022-01-01-00:00:00" # formatting is different here because of how historic_crypto indexes dataframes

    train_df, test_df, train_close, test_close = get_precollected_data(split_ratio=0.8)
    trading_agent = Agent(train_df.shape, NUM_EPISODES)
    
    # Load the model only once before starting the loop if it exists
    if os.path.exists("Output/online_model/model.pt"):
        print("Loading the model")
        trading_agent.load_model()
    else:
        print("No model found, training from scratch")

    main(trading_agent, train_df, test_df, train_close, test_close)
    trading_agent.save_model()
    print("model saved")
# Out:
# Pre-collected data loaded successfully.
# NaN values dropped.
# Data split.
# Train data saved.
# Test data saved.
# Loading the model
# loaded model from:  Output\online_model
# loaded model from:  Output\target_model
#
# ===== Episode 1 / 10 =====
# Time step 0 / 22923   |   Portfolio Value: 0.0   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 1 / 22923   |   Portfolio Value: -0.51   |   Inventory: 0   |   Reward: -0.5099999999999909   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 2 / 22923   |   Portfolio Value: -0.51   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 3 / 22923   |   Portfolio Value: 1.0   |   Inventory: 0   |   Reward: 1.509999999999991   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 4 / 22923   |   Portfolio Value: 1.0   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 5 / 22923   |   Portfolio Value: -0.17   |   Inventory: 1   |   Reward: -0.1   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 6 / 22923   |   Portfolio Value: 0.03   |   Inventory: 0   |   Reward: -0.8700000000000045   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 7 / 22923   |   Portfolio Value: 0.03   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 8 / 22923   |   Portfolio Value: -0.76   |   Inventory: 2   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 9 / 22923   |   Portfolio Value: -0.46   |   Inventory: 1   |   Reward: 0.15000000000000568   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 10 / 22923   |   Portfolio Value: -0.06   |   Inventory: 2   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 11 / 22923   |   Portfolio Value: -1.28   |   Inventory: 3   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 12 / 22923   |   Portfolio Value: -1.55   |   Inventory: 4   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 13 / 22923   |   Portfolio Value: -2.17   |   Inventory: 4   |   Reward: -0.1   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 14 / 22923   |   Portfolio Value: 5.49   |   Inventory: 4   |   Reward: -0.1   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 15 / 22923   |   Portfolio Value: 18.77   |   Inventory: 5   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 16 / 22923   |   Portfolio Value: 40.32   |   Inventory: 4   |   Reward: 4.310000000000002   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 17 / 22923   |   Portfolio Value: 31.72   |   Inventory: 3   |   Reward: 7.289999999999992   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 18 / 22923   |   Portfolio Value: 33.13   |   Inventory: 4   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 19 / 22923   |   Portfolio Value: 29.33   |   Inventory: 5   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 20 / 22923   |   Portfolio Value: 29.98   |   Inventory: 4   |   Reward: 0.13000000000002387   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 21 / 22923   |   Portfolio Value: 34.86   |   Inventory: 3   |   Reward: 0.4000000000000057   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 22 / 22923   |   Portfolio Value: 33.87   |   Inventory: 2   |   Reward: 7.740000000000009   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 23 / 22923   |   Portfolio Value: 24.83   |   Inventory: 1   |   Reward: 2.609999999999985   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 24 / 22923   |   Portfolio Value: 25.28   |   Inventory: 2   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 25 / 22923   |   Portfolio Value: 24.02   |   Inventory: 1   |   Reward: -0.6299999999999955   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 26 / 22923   |   Portfolio Value: 21.04   |   Inventory: 0   |   Reward: -0.7900000000000205   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 27 / 22923   |   Portfolio Value: 21.04   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 28 / 22923   |   Portfolio Value: 22.96   |   Inventory: 0   |   Reward: 1.9199999999999875   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 29 / 22923   |   Portfolio Value: 22.96   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 30 / 22923   |   Portfolio Value: 22.89   |   Inventory: 0   |   Reward: -0.06999999999999318   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 31 / 22923   |   Portfolio Value: 22.79   |   Inventory: 0   |   Reward: -0.1   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 32 / 22923   |   Portfolio Value: 22.79   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 33 / 22923   |   Portfolio Value: 23.01   |   Inventory: 2   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 34 / 22923   |   Portfolio Value: 18.87   |   Inventory: 1   |   Reward: -2.069999999999993   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 35 / 22923   |   Portfolio Value: 19.37   |   Inventory: 0   |   Reward: -1.3499999999999943   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 36 / 22923   |   Portfolio Value: 19.37   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 37 / 22923   |   Portfolio Value: 18.36   |   Inventory: 0   |   Reward: -1.0100000000000193   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 38 / 22923   |   Portfolio Value: 18.36   |   Inventory: 1   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 39 / 22923   |   Portfolio Value: 19.37   |   Inventory: 2   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 40 / 22923   |   Portfolio Value: 16.03   |   Inventory: 3   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 41 / 22923   |   Portfolio Value: 11.5   |   Inventory: 4   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 42 / 22923   |   Portfolio Value: 21.86   |   Inventory: 5   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 43 / 22923   |   Portfolio Value: 11.86   |   Inventory: 4   |   Reward: -2.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 44 / 22923   |   Portfolio Value: 25.54   |   Inventory: 3   |   Reward: 4.009999999999991   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 45 / 22923   |   Portfolio Value: 30.52   |   Inventory: 4   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 46 / 22923   |   Portfolio Value: 31.72   |   Inventory: 5   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 47 / 22923   |   Portfolio Value: 33.52   |   Inventory: 6   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 48 / 22923   |   Portfolio Value: 29.38   |   Inventory: 5   |   Reward: -0.6899999999999977   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 49 / 22923   |   Portfolio Value: 28.53   |   Inventory: 6   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 50 / 22923   |   Portfolio Value: 41.91   |   Inventory: 7   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 51 / 22923   |   Portfolio Value: 35.68   |   Inventory: 8   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 52 / 22923   |   Portfolio Value: 24.72   |   Inventory: 9   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 53 / 22923   |   Portfolio Value: 31.56   |   Inventory: 8   |   Reward: 0.7599999999999909   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 54 / 22923   |   Portfolio Value: 30.6   |   Inventory: 7   |   Reward: -0.7300000000000182   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 55 / 22923   |   Portfolio Value: 28.99   |   Inventory: 8   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 56 / 22923   |   Portfolio Value: 18.75   |   Inventory: 9   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 57 / 22923   |   Portfolio Value: -11.67   |   Inventory: 10   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 58 / 22923   |   Portfolio Value: 2.23   |   Inventory: 9   |   Reward: 1.3899999999999864   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 59 / 22923   |   Portfolio Value: 13.39   |   Inventory: 10   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 60 / 22923   |   Portfolio Value: 5.99   |   Inventory: 11   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 61 / 22923   |   Portfolio Value: -13.7   |   Inventory: 12   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 0
# Time step 62 / 22923   |   Portfolio Value: -76.34   |   Inventory: 11   |   Reward: -5.219999999999999   |   Epsilon: 1.0   |   MSE Loss: 0
# c:\Users\ericb\anaconda3\envs\ML_Torch\lib\site-packages\ipykernel_launcher.py:92: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
# Time step 63 / 22923   |   Portfolio Value: -87.67   |   Inventory: 12   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 125.31033325195312
# Time step 64 / 22923   |   Portfolio Value: -88.85   |   Inventory: 12   |   Reward: -0.1   |   Epsilon: 1.0   |   MSE Loss: 103.64810180664062
# Time step 65 / 22923   |   Portfolio Value: -67.97   |   Inventory: 13   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 79.25863647460938
# Time step 66 / 22923   |   Portfolio Value: -69.79   |   Inventory: 12   |   Reward: -0.13999999999998636   |   Epsilon: 1.0   |   MSE Loss: 148.6024169921875
# Time step 67 / 22923   |   Portfolio Value: -102.31   |   Inventory: 13   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 60.382511138916016
# Time step 68 / 22923   |   Portfolio Value: -36.66   |   Inventory: 14   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 41.37024688720703
# Time step 69 / 22923   |   Portfolio Value: -62.0   |   Inventory: 13   |   Reward: -1.8100000000000023   |   Epsilon: 1.0   |   MSE Loss: 64.71099853515625
# Time step 70 / 22923   |   Portfolio Value: -68.5   |   Inventory: 14   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 78.45501708984375
# Time step 71 / 22923   |   Portfolio Value: -51.14   |   Inventory: 15   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 52.509029388427734
# Time step 72 / 22923   |   Portfolio Value: -79.34   |   Inventory: 16   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 30.755146026611328
# Time step 73 / 22923   |   Portfolio Value: -83.98   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 1.0   |   MSE Loss: 21.282032012939453
# Time step 74 / 22923   |   Portfolio Value: -49.13   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 18.072341918945312
# Time step 75 / 22923   |   Portfolio Value: -62.37   |   Inventory: 18   |   Reward: -0.1   |   Epsilon: 0.9999   |   MSE Loss: 29.143463134765625
# Time step 76 / 22923   |   Portfolio Value: -61.83   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 29.209209442138672
# Time step 77 / 22923   |   Portfolio Value: -96.13   |   Inventory: 19   |   Reward: -0.1   |   Epsilon: 0.9999   |   MSE Loss: 13.847185134887695
# Time step 78 / 22923   |   Portfolio Value: -145.15   |   Inventory: 18   |   Reward: -4.3799999999999955   |   Epsilon: 0.9999   |   MSE Loss: 26.292152404785156
# Time step 79 / 22923   |   Portfolio Value: -143.35   |   Inventory: 17   |   Reward: -4.97999999999999   |   Epsilon: 0.9999   |   MSE Loss: 29.94841194152832
# Time step 80 / 22923   |   Portfolio Value: -169.7   |   Inventory: 16   |   Reward: -4.480000000000018   |   Epsilon: 0.9999   |   MSE Loss: 69.76980590820312
# Time step 81 / 22923   |   Portfolio Value: -174.98   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 23.873918533325195
# Time step 82 / 22923   |   Portfolio Value: -148.97   |   Inventory: 16   |   Reward: 1.5300000000000011   |   Epsilon: 0.9999   |   MSE Loss: 203.88259887695312
# Time step 83 / 22923   |   Portfolio Value: -142.41   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 41.11457824707031
# Time step 84 / 22923   |   Portfolio Value: -146.83   |   Inventory: 16   |   Reward: -0.2599999999999909   |   Epsilon: 0.9999   |   MSE Loss: 18.754779815673828
# Time step 85 / 22923   |   Portfolio Value: -165.65   |   Inventory: 16   |   Reward: -0.1   |   Epsilon: 0.9999   |   MSE Loss: 35.74114990234375
# Time step 86 / 22923   |   Portfolio Value: -153.97   |   Inventory: 15   |   Reward: -3.8600000000000136   |   Epsilon: 0.9999   |   MSE Loss: 38.4830322265625
# Time step 87 / 22923   |   Portfolio Value: -181.42   |   Inventory: 14   |   Reward: -7.569999999999993   |   Epsilon: 0.9999   |   MSE Loss: 53.19414520263672
# Time step 88 / 22923   |   Portfolio Value: -157.76   |   Inventory: 15   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 45.37177658081055
# Time step 89 / 22923   |   Portfolio Value: -147.71   |   Inventory: 16   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 19.253353118896484
# Time step 90 / 22923   |   Portfolio Value: -69.15   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 22.498199462890625
# Time step 91 / 22923   |   Portfolio Value: -69.93   |   Inventory: 17   |   Reward: -0.1   |   Epsilon: 0.9999   |   MSE Loss: 15.592695236206055
# Time step 92 / 22923   |   Portfolio Value: -55.65   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 26.863107681274414
# Time step 93 / 22923   |   Portfolio Value: -68.61   |   Inventory: 17   |   Reward: -0.7199999999999989   |   Epsilon: 0.9999   |   MSE Loss: 29.996036529541016
# Time step 94 / 22923   |   Portfolio Value: -98.36   |   Inventory: 16   |   Reward: -1.670000000000016   |   Epsilon: 0.9999   |   MSE Loss: 28.568899154663086
# Time step 95 / 22923   |   Portfolio Value: -150.14   |   Inventory: 16   |   Reward: -0.1   |   Epsilon: 0.9999   |   MSE Loss: 29.113079071044922
# Time step 96 / 22923   |   Portfolio Value: -258.62   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 35.68429946899414
# Time step 97 / 22923   |   Portfolio Value: -258.45   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9999   |   MSE Loss: 14.565183639526367
# Time step 98 / 22923   |   Portfolio Value: -259.71   |   Inventory: 17   |   Reward: -0.06999999999999318   |   Epsilon: 0.9998   |   MSE Loss: 18.08758544921875
# Time step 99 / 22923   |   Portfolio Value: -275.01   |   Inventory: 16   |   Reward: -0.960000000000008   |   Epsilon: 0.9998   |   MSE Loss: 11.905618667602539
# Time step 100 / 22923   |   Portfolio Value: -269.25   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 31.807804107666016
# Time step 101 / 22923   |   Portfolio Value: -253.2   |   Inventory: 17   |   Reward: -0.1   |   Epsilon: 0.9998   |   MSE Loss: 11.638154983520508
# Time step 102 / 22923   |   Portfolio Value: -254.32   |   Inventory: 17   |   Reward: -0.1   |   Epsilon: 0.9998   |   MSE Loss: 9.4072904586792
# Time step 103 / 22923   |   Portfolio Value: -249.22   |   Inventory: 16   |   Reward: 1.1899999999999977   |   Epsilon: 0.9998   |   MSE Loss: 14.664630889892578
# Time step 104 / 22923   |   Portfolio Value: -222.82   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 20.629892349243164
# Time step 105 / 22923   |   Portfolio Value: -207.69   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 24.570621490478516
# Time step 106 / 22923   |   Portfolio Value: -226.87   |   Inventory: 18   |   Reward: -0.1   |   Epsilon: 0.9998   |   MSE Loss: 19.716407775878906
# Time step 107 / 22923   |   Portfolio Value: -228.13   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 31.690000534057617
# Time step 108 / 22923   |   Portfolio Value: -218.82   |   Inventory: 18   |   Reward: 0.4899999999999807   |   Epsilon: 0.9998   |   MSE Loss: 31.401256561279297
# Time step 109 / 22923   |   Portfolio Value: -217.74   |   Inventory: 17   |   Reward: -0.5800000000000125   |   Epsilon: 0.9998   |   MSE Loss: 33.26746368408203
# Time step 110 / 22923   |   Portfolio Value: -113.63   |   Inventory: 17   |   Reward: -0.1   |   Epsilon: 0.9998   |   MSE Loss: 41.2812385559082
# Time step 111 / 22923   |   Portfolio Value: -74.53   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 20.42093276977539
# Time step 112 / 22923   |   Portfolio Value: -201.43   |   Inventory: 17   |   Reward: -7.049999999999983   |   Epsilon: 0.9998   |   MSE Loss: 28.292827606201172
# Time step 113 / 22923   |   Portfolio Value: -172.87   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 11.32464599609375
# Time step 114 / 22923   |   Portfolio Value: -174.49   |   Inventory: 17   |   Reward: -0.09000000000000341   |   Epsilon: 0.9998   |   MSE Loss: 21.059864044189453
# Time step 115 / 22923   |   Portfolio Value: -159.7   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 9.930054664611816
# Time step 116 / 22923   |   Portfolio Value: -91.3   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 11.213174819946289
# Time step 117 / 22923   |   Portfolio Value: -71.64   |   Inventory: 19   |   Reward: -0.1   |   Epsilon: 0.9998   |   MSE Loss: 19.481367111206055
# Time step 118 / 22923   |   Portfolio Value: -106.6   |   Inventory: 18   |   Reward: -0.8000000000000114   |   Epsilon: 0.9998   |   MSE Loss: 62.81597137451172
# Time step 119 / 22923   |   Portfolio Value: -69.7   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9998   |   MSE Loss: 12.079721450805664
# Time step 120 / 22923   |   Portfolio Value: 48.0   |   Inventory: 19   |   Reward: -0.1   |   Epsilon: 0.9998   |   MSE Loss: 44.3432502746582
# Time step 121 / 22923   |   Portfolio Value: 52.18   |   Inventory: 18   |   Reward: 6.4199999999999875   |   Epsilon: 0.9997   |   MSE Loss: 16.949718475341797
# Time step 122 / 22923   |   Portfolio Value: 52.0   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 39.02206039428711
# Time step 123 / 22923   |   Portfolio Value: 43.07   |   Inventory: 18   |   Reward: -0.46999999999999886   |   Epsilon: 0.9997   |   MSE Loss: 31.941097259521484
# Time step 124 / 22923   |   Portfolio Value: 22.37   |   Inventory: 17   |   Reward: 9.840000000000003   |   Epsilon: 0.9997   |   MSE Loss: 18.646472930908203
# Time step 125 / 22923   |   Portfolio Value: 32.23   |   Inventory: 16   |   Reward: 14.570000000000022   |   Epsilon: 0.9997   |   MSE Loss: 31.32309341430664
# Time step 126 / 22923   |   Portfolio Value: 37.67   |   Inventory: 15   |   Reward: 10.380000000000024   |   Epsilon: 0.9997   |   MSE Loss: 108.7235107421875
# Time step 127 / 22923   |   Portfolio Value: 20.87   |   Inventory: 16   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 36.568992614746094
# Time step 128 / 22923   |   Portfolio Value: 36.55   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 21.469207763671875
# Time step 129 / 22923   |   Portfolio Value: 43.52   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 10.21725082397461
# Time step 130 / 22923   |   Portfolio Value: 46.22   |   Inventory: 17   |   Reward: 0.15000000000000568   |   Epsilon: 0.9997   |   MSE Loss: 23.03729820251465
# Time step 131 / 22923   |   Portfolio Value: 47.75   |   Inventory: 16   |   Reward: 0.6500000000000057   |   Epsilon: 0.9997   |   MSE Loss: 11.43393325805664
# Time step 132 / 22923   |   Portfolio Value: 75.27   |   Inventory: 17   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 8.071788787841797
# Time step 133 / 22923   |   Portfolio Value: 0.13   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 16.683284759521484
# Time step 134 / 22923   |   Portfolio Value: 15.43   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 12.868492126464844
# Time step 135 / 22923   |   Portfolio Value: 19.04   |   Inventory: 18   |   Reward: 0.18999999999999773   |   Epsilon: 0.9997   |   MSE Loss: 37.832820892333984
# Time step 136 / 22923   |   Portfolio Value: 22.64   |   Inventory: 17   |   Reward: 1.2399999999999807   |   Epsilon: 0.9997   |   MSE Loss: 24.817001342773438
# Time step 137 / 22923   |   Portfolio Value: 31.99   |   Inventory: 18   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 34.302406311035156
# Time step 138 / 22923   |   Portfolio Value: 18.57   |   Inventory: 18   |   Reward: -0.1   |   Epsilon: 0.9997   |   MSE Loss: 46.72050476074219
# Time step 139 / 22923   |   Portfolio Value: -33.81   |   Inventory: 19   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 21.26987075805664
# Time step 140 / 22923   |   Portfolio Value: -25.83   |   Inventory: 20   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 18.94107437133789
# Time step 141 / 22923   |   Portfolio Value: -14.03   |   Inventory: 21   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 20.557968139648438
# Time step 142 / 22923   |   Portfolio Value: 0.25   |   Inventory: 22   |   Reward: 0.0   |   Epsilon: 0.9997   |   MSE Loss: 17.08132553100586
# Time step 143 / 22923   |   Portfolio Value: -14.27   |   Inventory: 21   |   Reward: -0.6599999999999966   |   Epsilon: 0.9997   |   MSE Loss: 13.722497940063477
# Time step 144 / 22923   |   Portfolio Value: -72.65   |   Inventory: 22   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 21.331899642944336
# Time step 145 / 22923   |   Portfolio Value: -115.55   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 12.022634506225586
# Time step 146 / 22923   |   Portfolio Value: -122.22   |   Inventory: 22   |   Reward: -0.29000000000002046   |   Epsilon: 0.9996   |   MSE Loss: 15.554584503173828
# Time step 147 / 22923   |   Portfolio Value: -105.94   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 18.549829483032227
# Time step 148 / 22923   |   Portfolio Value: -98.81   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 15.956242561340332
# Time step 149 / 22923   |   Portfolio Value: -96.41   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 10.325019836425781
# Time step 150 / 22923   |   Portfolio Value: -135.01   |   Inventory: 25   |   Reward: -0.1   |   Epsilon: 0.9996   |   MSE Loss: 11.732416152954102
# Time step 151 / 22923   |   Portfolio Value: -74.11   |   Inventory: 25   |   Reward: -0.1   |   Epsilon: 0.9996   |   MSE Loss: 17.396446228027344
# Time step 152 / 22923   |   Portfolio Value: -56.86   |   Inventory: 24   |   Reward: 1.5900000000000034   |   Epsilon: 0.9996   |   MSE Loss: 15.300253868103027
# Time step 153 / 22923   |   Portfolio Value: -64.3   |   Inventory: 23   |   Reward: 1.3799999999999955   |   Epsilon: 0.9996   |   MSE Loss: 22.375274658203125
# Time step 154 / 22923   |   Portfolio Value: -56.12   |   Inventory: 23   |   Reward: -0.1   |   Epsilon: 0.9996   |   MSE Loss: 30.50042724609375
# Time step 155 / 22923   |   Portfolio Value: -48.07   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 17.590665817260742
# Time step 156 / 22923   |   Portfolio Value: -83.35   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 14.109968185424805
# Time step 157 / 22923   |   Portfolio Value: -69.35   |   Inventory: 24   |   Reward: 0.5600000000000023   |   Epsilon: 0.9996   |   MSE Loss: 23.625308990478516
# Time step 158 / 22923   |   Portfolio Value: -85.19   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 15.724878311157227
# Time step 159 / 22923   |   Portfolio Value: -66.94   |   Inventory: 24   |   Reward: 0.7299999999999898   |   Epsilon: 0.9996   |   MSE Loss: 5.107632160186768
# Time step 160 / 22923   |   Portfolio Value: -2.62   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 17.767475128173828
# Time step 161 / 22923   |   Portfolio Value: -10.47   |   Inventory: 25   |   Reward: -0.1   |   Epsilon: 0.9996   |   MSE Loss: 12.32650089263916
# Time step 162 / 22923   |   Portfolio Value: 0.78   |   Inventory: 24   |   Reward: 0.13999999999998636   |   Epsilon: 0.9996   |   MSE Loss: 14.189210891723633
# Time step 163 / 22923   |   Portfolio Value: 14.94   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 8.733287811279297
# Time step 164 / 22923   |   Portfolio Value: -25.56   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 11.205229759216309
# Time step 165 / 22923   |   Portfolio Value: -20.88   |   Inventory: 25   |   Reward: 0.18000000000000682   |   Epsilon: 0.9996   |   MSE Loss: 5.346449375152588
# Time step 166 / 22923   |   Portfolio Value: -35.63   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9996   |   MSE Loss: 10.938949584960938
# Time step 167 / 22923   |   Portfolio Value: 1.03   |   Inventory: 25   |   Reward: 1.4099999999999966   |   Epsilon: 0.9996   |   MSE Loss: 9.714859962463379
# Time step 168 / 22923   |   Portfolio Value: 100.28   |   Inventory: 24   |   Reward: 3.3499999999999943   |   Epsilon: 0.9995   |   MSE Loss: 25.591712951660156
# Time step 169 / 22923   |   Portfolio Value: 68.36   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 17.854928970336914
# Time step 170 / 22923   |   Portfolio Value: 101.61   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 4.006499290466309
# Time step 171 / 22923   |   Portfolio Value: 71.71   |   Inventory: 25   |   Reward: -1.1500000000000057   |   Epsilon: 0.9995   |   MSE Loss: 16.983570098876953
# Time step 172 / 22923   |   Portfolio Value: 68.46   |   Inventory: 24   |   Reward: 0.04999999999998295   |   Epsilon: 0.9995   |   MSE Loss: 12.90875244140625
# Time step 173 / 22923   |   Portfolio Value: 41.58   |   Inventory: 23   |   Reward: 3.519999999999982   |   Epsilon: 0.9995   |   MSE Loss: 7.927357196807861
# Time step 174 / 22923   |   Portfolio Value: 29.62   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 21.98009490966797
# Time step 175 / 22923   |   Portfolio Value: 46.8   |   Inventory: 24   |   Reward: -0.1   |   Epsilon: 0.9995   |   MSE Loss: 14.31581974029541
# Time step 176 / 22923   |   Portfolio Value: 32.88   |   Inventory: 23   |   Reward: 0.13999999999998636   |   Epsilon: 0.9995   |   MSE Loss: 12.335774421691895
# Time step 177 / 22923   |   Portfolio Value: 12.41   |   Inventory: 22   |   Reward: 4.650000000000006   |   Epsilon: 0.9995   |   MSE Loss: 23.38152313232422
# Time step 178 / 22923   |   Portfolio Value: -232.45   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 9.933552742004395
# Time step 179 / 22923   |   Portfolio Value: -266.03   |   Inventory: 22   |   Reward: -1.460000000000008   |   Epsilon: 0.9995   |   MSE Loss: 28.149845123291016
# Time step 180 / 22923   |   Portfolio Value: -292.65   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 25.673418045043945
# Time step 181 / 22923   |   Portfolio Value: -294.72   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 16.002634048461914
# Time step 182 / 22923   |   Portfolio Value: -290.88   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 23.127233505249023
# Time step 183 / 22923   |   Portfolio Value: -280.38   |   Inventory: 24   |   Reward: 0.4200000000000159   |   Epsilon: 0.9995   |   MSE Loss: 20.222440719604492
# Time step 184 / 22923   |   Portfolio Value: -254.94   |   Inventory: 23   |   Reward: 1.6400000000000148   |   Epsilon: 0.9995   |   MSE Loss: 39.670833587646484
# Time step 185 / 22923   |   Portfolio Value: -239.76   |   Inventory: 22   |   Reward: 2.210000000000008   |   Epsilon: 0.9995   |   MSE Loss: 19.94019889831543
# Time step 186 / 22923   |   Portfolio Value: -267.26   |   Inventory: 21   |   Reward: -9.689999999999998   |   Epsilon: 0.9995   |   MSE Loss: 10.338993072509766
# Time step 187 / 22923   |   Portfolio Value: -260.43   |   Inventory: 21   |   Reward: -0.1   |   Epsilon: 0.9995   |   MSE Loss: 32.178375244140625
# Time step 188 / 22923   |   Portfolio Value: -241.11   |   Inventory: 20   |   Reward: -11.199999999999989   |   Epsilon: 0.9995   |   MSE Loss: 15.349700927734375
# Time step 189 / 22923   |   Portfolio Value: -231.31   |   Inventory: 21   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 15.139208793640137
# Time step 190 / 22923   |   Portfolio Value: -281.29   |   Inventory: 22   |   Reward: 0.0   |   Epsilon: 0.9995   |   MSE Loss: 8.980573654174805
# Time step 191 / 22923   |   Portfolio Value: -260.61   |   Inventory: 21   |   Reward: 0.9400000000000261   |   Epsilon: 0.9994   |   MSE Loss: 10.282123565673828
# Time step 192 / 22923   |   Portfolio Value: -278.46   |   Inventory: 20   |   Reward: -2.2900000000000205   |   Epsilon: 0.9994   |   MSE Loss: 21.058414459228516
# Time step 193 / 22923   |   Portfolio Value: -255.96   |   Inventory: 20   |   Reward: -0.1   |   Epsilon: 0.9994   |   MSE Loss: 9.807330131530762
# Time step 194 / 22923   |   Portfolio Value: -274.56   |   Inventory: 21   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 37.26678466796875
# Time step 195 / 22923   |   Portfolio Value: -252.09   |   Inventory: 22   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 15.648591995239258
# Time step 196 / 22923   |   Portfolio Value: -200.39   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 19.208602905273438
# Time step 197 / 22923   |   Portfolio Value: -213.04   |   Inventory: 22   |   Reward: -0.549999999999983   |   Epsilon: 0.9994   |   MSE Loss: 10.443755149841309
# Time step 198 / 22923   |   Portfolio Value: -199.28   |   Inventory: 22   |   Reward: -0.1   |   Epsilon: 0.9994   |   MSE Loss: 11.102802276611328
# Time step 199 / 22923   |   Portfolio Value: -227.32   |   Inventory: 22   |   Reward: -0.1   |   Epsilon: 0.9994   |   MSE Loss: 5.40252685546875
# Time step 200 / 22923   |   Portfolio Value: -216.1   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 9.69089126586914
# Time step 201 / 22923   |   Portfolio Value: -240.48   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 19.620010375976562
# Time step 202 / 22923   |   Portfolio Value: -240.48   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 14.106988906860352
# Time step 203 / 22923   |   Portfolio Value: -206.44   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 9.38083267211914
# Time step 204 / 22923   |   Portfolio Value: -220.6   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 17.94359588623047
# Time step 205 / 22923   |   Portfolio Value: -234.6   |   Inventory: 24   |   Reward: -0.5600000000000023   |   Epsilon: 0.9994   |   MSE Loss: 21.597206115722656
# Time step 206 / 22923   |   Portfolio Value: -251.16   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 11.734580039978027
# Time step 207 / 22923   |   Portfolio Value: -240.16   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 5.630311012268066
# Time step 208 / 22923   |   Portfolio Value: -253.94   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 8.803145408630371
# Time step 209 / 22923   |   Portfolio Value: -238.92   |   Inventory: 27   |   Reward: -0.1   |   Epsilon: 0.9994   |   MSE Loss: 13.164590835571289
# Time step 210 / 22923   |   Portfolio Value: -238.92   |   Inventory: 26   |   Reward: 0.5600000000000023   |   Epsilon: 0.9994   |   MSE Loss: 11.530853271484375
# Time step 211 / 22923   |   Portfolio Value: -241.52   |   Inventory: 25   |   Reward: -0.06999999999999318   |   Epsilon: 0.9994   |   MSE Loss: 6.630399227142334
# Time step 212 / 22923   |   Portfolio Value: -246.52   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9994   |   MSE Loss: 11.95742416381836
# Time step 213 / 22923   |   Portfolio Value: -293.58   |   Inventory: 25   |   Reward: -1.8100000000000023   |   Epsilon: 0.9994   |   MSE Loss: 5.54573917388916
# Time step 214 / 22923   |   Portfolio Value: -247.58   |   Inventory: 24   |   Reward: 0.19999999999998863   |   Epsilon: 0.9994   |   MSE Loss: 10.793590545654297
# Time step 215 / 22923   |   Portfolio Value: -163.1   |   Inventory: 23   |   Reward: 1.8799999999999955   |   Epsilon: 0.9993   |   MSE Loss: 5.116373062133789
# Time step 216 / 22923   |   Portfolio Value: -190.57   |   Inventory: 23   |   Reward: -0.1   |   Epsilon: 0.9993   |   MSE Loss: 10.694686889648438
# Time step 217 / 22923   |   Portfolio Value: -116.97   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 8.283502578735352
# Time step 218 / 22923   |   Portfolio Value: -127.29   |   Inventory: 23   |   Reward: -0.4299999999999784   |   Epsilon: 0.9993   |   MSE Loss: 5.377325057983398
# Time step 219 / 22923   |   Portfolio Value: -138.33   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 7.369722366333008
# Time step 220 / 22923   |   Portfolio Value: -128.59   |   Inventory: 24   |   Reward: -0.1   |   Epsilon: 0.9993   |   MSE Loss: 7.372973442077637
# Time step 221 / 22923   |   Portfolio Value: -158.83   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 7.823611259460449
# Time step 222 / 22923   |   Portfolio Value: -170.08   |   Inventory: 24   |   Reward: -0.44999999999998863   |   Epsilon: 0.9993   |   MSE Loss: 7.2707366943359375
# Time step 223 / 22923   |   Portfolio Value: -153.28   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 12.085918426513672
# Time step 224 / 22923   |   Portfolio Value: -183.78   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 8.849639892578125
# Time step 225 / 22923   |   Portfolio Value: -241.24   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 4.143017768859863
# Time step 226 / 22923   |   Portfolio Value: -229.63   |   Inventory: 26   |   Reward: 0.4300000000000068   |   Epsilon: 0.9993   |   MSE Loss: 5.566041946411133
# Time step 227 / 22923   |   Portfolio Value: -252.25   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 3.9371542930603027
# Time step 228 / 22923   |   Portfolio Value: -211.48   |   Inventory: 26   |   Reward: 1.509999999999991   |   Epsilon: 0.9993   |   MSE Loss: 5.202258110046387
# Time step 229 / 22923   |   Portfolio Value: -226.04   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 5.411624908447266
# Time step 230 / 22923   |   Portfolio Value: -238.46   |   Inventory: 26   |   Reward: -0.46000000000000796   |   Epsilon: 0.9993   |   MSE Loss: 7.299349308013916
# Time step 231 / 22923   |   Portfolio Value: -224.68   |   Inventory: 25   |   Reward: -1.6299999999999955   |   Epsilon: 0.9993   |   MSE Loss: 7.721145153045654
# Time step 232 / 22923   |   Portfolio Value: -189.03   |   Inventory: 25   |   Reward: -0.1   |   Epsilon: 0.9993   |   MSE Loss: 8.765146255493164
# Time step 233 / 22923   |   Portfolio Value: -214.78   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 5.050727844238281
# Time step 234 / 22923   |   Portfolio Value: -208.54   |   Inventory: 25   |   Reward: 0.23999999999998067   |   Epsilon: 0.9993   |   MSE Loss: 14.988417625427246
# Time step 235 / 22923   |   Portfolio Value: -218.79   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9993   |   MSE Loss: 8.829461097717285
# Time step 236 / 22923   |   Portfolio Value: -155.09   |   Inventory: 25   |   Reward: 2.450000000000017   |   Epsilon: 0.9993   |   MSE Loss: 3.1563987731933594
# Time step 237 / 22923   |   Portfolio Value: -179.19   |   Inventory: 25   |   Reward: -0.1   |   Epsilon: 0.9993   |   MSE Loss: 8.63901138305664
# Time step 238 / 22923   |   Portfolio Value: -173.94   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 6.042485237121582
# Time step 239 / 22923   |   Portfolio Value: -183.04   |   Inventory: 25   |   Reward: -0.35000000000002274   |   Epsilon: 0.9992   |   MSE Loss: 4.305171966552734
# Time step 240 / 22923   |   Portfolio Value: -205.89   |   Inventory: 25   |   Reward: -0.1   |   Epsilon: 0.9992   |   MSE Loss: 7.216692924499512
# Time step 241 / 22923   |   Portfolio Value: -252.89   |   Inventory: 24   |   Reward: -4.060000000000002   |   Epsilon: 0.9992   |   MSE Loss: 9.589374542236328
# Time step 242 / 22923   |   Portfolio Value: -301.95   |   Inventory: 24   |   Reward: -0.1   |   Epsilon: 0.9992   |   MSE Loss: 3.530686616897583
# Time step 243 / 22923   |   Portfolio Value: -285.01   |   Inventory: 24   |   Reward: -0.1   |   Epsilon: 0.9992   |   MSE Loss: 5.209873199462891
# Time step 244 / 22923   |   Portfolio Value: -284.05   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 5.034045696258545
# Time step 245 / 22923   |   Portfolio Value: -275.8   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 4.5311760902404785
# Time step 246 / 22923   |   Portfolio Value: -251.88   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 8.428919792175293
# Time step 247 / 22923   |   Portfolio Value: -247.56   |   Inventory: 28   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 3.7715659141540527
# Time step 248 / 22923   |   Portfolio Value: -252.32   |   Inventory: 27   |   Reward: -0.17000000000001592   |   Epsilon: 0.9992   |   MSE Loss: 3.3596842288970947
# Time step 249 / 22923   |   Portfolio Value: -255.56   |   Inventory: 28   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 3.2901058197021484
# Time step 250 / 22923   |   Portfolio Value: -243.52   |   Inventory: 27   |   Reward: 0.4299999999999784   |   Epsilon: 0.9992   |   MSE Loss: 3.728682518005371
# Time step 251 / 22923   |   Portfolio Value: -218.51   |   Inventory: 27   |   Reward: -0.1   |   Epsilon: 0.9992   |   MSE Loss: 4.319077014923096
# Time step 252 / 22923   |   Portfolio Value: -216.89   |   Inventory: 28   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 4.367462158203125
# Time step 253 / 22923   |   Portfolio Value: -219.41   |   Inventory: 29   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 3.0822606086730957
# Time step 254 / 22923   |   Portfolio Value: -201.72   |   Inventory: 28   |   Reward: 0.6100000000000136   |   Epsilon: 0.9992   |   MSE Loss: 3.911407470703125
# Time step 255 / 22923   |   Portfolio Value: -118.28   |   Inventory: 27   |   Reward: 3.5   |   Epsilon: 0.9992   |   MSE Loss: 7.473349571228027
# Time step 256 / 22923   |   Portfolio Value: -132.86   |   Inventory: 26   |   Reward: 4.25   |   Epsilon: 0.9992   |   MSE Loss: 5.814743995666504
# Time step 257 / 22923   |   Portfolio Value: -146.64   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 12.980650901794434
# Time step 258 / 22923   |   Portfolio Value: -138.27   |   Inventory: 26   |   Reward: 0.3100000000000023   |   Epsilon: 0.9992   |   MSE Loss: 4.867610931396484
# Time step 259 / 22923   |   Portfolio Value: -159.07   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9992   |   MSE Loss: 19.0651798248291
# Time step 260 / 22923   |   Portfolio Value: -211.99   |   Inventory: 26   |   Reward: -1.960000000000008   |   Epsilon: 0.9992   |   MSE Loss: 12.14523983001709
# Time step 261 / 22923   |   Portfolio Value: -191.97   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 13.86217975616455
# Time step 262 / 22923   |   Portfolio Value: -182.52   |   Inventory: 28   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 6.146704196929932
# Time step 263 / 22923   |   Portfolio Value: -195.4   |   Inventory: 29   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 7.098395347595215
# Time step 264 / 22923   |   Portfolio Value: -107.82   |   Inventory: 30   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 3.8308286666870117
# Time step 265 / 22923   |   Portfolio Value: -115.92   |   Inventory: 31   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 7.6336669921875
# Time step 266 / 22923   |   Portfolio Value: -137.31   |   Inventory: 30   |   Reward: -0.6900000000000261   |   Epsilon: 0.9991   |   MSE Loss: 7.063250541687012
# Time step 267 / 22923   |   Portfolio Value: -134.01   |   Inventory: 29   |   Reward: -0.8499999999999943   |   Epsilon: 0.9991   |   MSE Loss: 7.532129287719727
# Time step 268 / 22923   |   Portfolio Value: -137.3   |   Inventory: 29   |   Reward: -0.1   |   Epsilon: 0.9991   |   MSE Loss: 9.208227157592773
# Time step 269 / 22923   |   Portfolio Value: -121.35   |   Inventory: 28   |   Reward: 2.609999999999985   |   Epsilon: 0.9991   |   MSE Loss: 5.226330757141113
# Time step 270 / 22923   |   Portfolio Value: -93.63   |   Inventory: 27   |   Reward: 3.140000000000015   |   Epsilon: 0.9991   |   MSE Loss: 3.504542350769043
# Time step 271 / 22923   |   Portfolio Value: -133.15   |   Inventory: 27   |   Reward: -0.1   |   Epsilon: 0.9991   |   MSE Loss: 5.768769264221191
# Time step 272 / 22923   |   Portfolio Value: -115.6   |   Inventory: 26   |   Reward: 2.680000000000007   |   Epsilon: 0.9991   |   MSE Loss: 7.634946823120117
# Time step 273 / 22923   |   Portfolio Value: -100.78   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 6.564886093139648
# Time step 274 / 22923   |   Portfolio Value: -94.57   |   Inventory: 26   |   Reward: 0.22999999999998977   |   Epsilon: 0.9991   |   MSE Loss: 3.19413423538208
# Time step 275 / 22923   |   Portfolio Value: -107.05   |   Inventory: 25   |   Reward: 5.960000000000008   |   Epsilon: 0.9991   |   MSE Loss: 9.685983657836914
# Time step 276 / 22923   |   Portfolio Value: -36.05   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 9.445074081420898
# Time step 277 / 22923   |   Portfolio Value: -10.57   |   Inventory: 25   |   Reward: 0.9799999999999898   |   Epsilon: 0.9991   |   MSE Loss: 2.6569294929504395
# Time step 278 / 22923   |   Portfolio Value: -27.57   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 8.78144359588623
# Time step 279 / 22923   |   Portfolio Value: 3.89   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.9991   |   MSE Loss: 12.896711349487305
# Time step 280 / 22923   |   Portfolio Value: -38.06   |   Inventory: 27   |   Reward: -0.1   |   Epsilon: 0.9991   |   MSE Loss: 3.3485145568847656
# Time step 281 / 22923   |   Portfolio Value: -25.1   |   Inventory: 26   |   Reward: -1.0699999999999932   |   Epsilon: 0.9991   |   MSE Loss: 1.709567904472351
# Time step 282 / 22923   |   Portfolio Value: -45.38   |   Inventory: 25   |   Reward: -0.6400000000000148   |   Epsilon: 0.9991   |   MSE Loss: 5.153867721557617
# Time step 283 / 22923   |   Portfolio Value: -41.38   |   Inventory: 24   |   Reward: 8.949999999999989   |   Epsilon: 0.9991   |   MSE Loss: 21.302379608154297
# Time step 284 / 22923   |   Portfolio Value: -41.38   |   Inventory: 23   |   Reward: 3.0   |   Epsilon: 0.9991   |   MSE Loss: 10.846305847167969
# Time step 285 / 22923   |   Portfolio Value: -28.73   |   Inventory: 22   |   Reward: 6.950000000000017   |   Epsilon: 0.999   |   MSE Loss: 10.357826232910156
# Time step 286 / 22923   |   Portfolio Value: -27.85   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 9.656122207641602
# Time step 287 / 22923   |   Portfolio Value: 29.88   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 4.497195243835449
# Time step 288 / 22923   |   Portfolio Value: -27.72   |   Inventory: 23   |   Reward: -2.3999999999999773   |   Epsilon: 0.999   |   MSE Loss: 12.637280464172363
# Time step 289 / 22923   |   Portfolio Value: -80.62   |   Inventory: 22   |   Reward: -2.1899999999999977   |   Epsilon: 0.999   |   MSE Loss: 9.929823875427246
# Time step 290 / 22923   |   Portfolio Value: -67.42   |   Inventory: 23   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 10.683187484741211
# Time step 291 / 22923   |   Portfolio Value: -77.54   |   Inventory: 24   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 2.7409892082214355
# Time step 292 / 22923   |   Portfolio Value: -88.82   |   Inventory: 25   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 3.191897392272949
# Time step 293 / 22923   |   Portfolio Value: -102.57   |   Inventory: 26   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 5.064237594604492
# Time step 294 / 22923   |   Portfolio Value: -94.25   |   Inventory: 27   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 6.584979057312012
# Time step 295 / 22923   |   Portfolio Value: -80.31   |   Inventory: 27   |   Reward: -0.1   |   Epsilon: 0.999   |   MSE Loss: 4.2312469482421875
# Time step 296 / 22923   |   Portfolio Value: -105.96   |   Inventory: 28   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 4.3330583572387695
# Time step 297 / 22923   |   Portfolio Value: -101.2   |   Inventory: 29   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 9.8019380569458
# Time step 298 / 22923   |   Portfolio Value: -105.26   |   Inventory: 30   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 8.411572456359863
# Time step 299 / 22923   |   Portfolio Value: -85.16   |   Inventory: 31   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 6.487984657287598
# Time step 300 / 22923   |   Portfolio Value: -74.1   |   Inventory: 31   |   Reward: -0.1   |   Epsilon: 0.999   |   MSE Loss: 4.128392219543457
# Time step 301 / 22923   |   Portfolio Value: -80.3   |   Inventory: 32   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 4.072600364685059
# Time step 302 / 22923   |   Portfolio Value: -104.3   |   Inventory: 33   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 8.079347610473633
# Time step 303 / 22923   |   Portfolio Value: -84.17   |   Inventory: 34   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 6.523078918457031
# Time step 304 / 22923   |   Portfolio Value: -72.27   |   Inventory: 35   |   Reward: 0.0   |   Epsilon: 0.999   |   MSE Loss: 8.422505378723145
# Time step 305 / 22923   |   Portfolio Value: -49.87   |   Inventory: 34   |   Reward: 0.6400000000000148   |   Epsilon: 0.999   |   MSE Loss: 3.1874237060546875
# Time step 306 / 22923   |   Portfolio Value: -34.57   |   Inventory: 33   |   Reward: 1.4399999999999977   |   Epsilon: 0.999   |   MSE Loss: 3.1188929080963135
# Time step 307 / 22923   |   Portfolio Value: -4.87   |   Inventory: 32   |   Reward: 2.950000000000017   |   Epsilon: 0.999   |   MSE Loss: 6.035876274108887
# Time step 308 / 22923   |   Portfolio Value: 41.43   |   Inventory: 32   |   Reward: -0.1   |   Epsilon: 0.9989   |   MSE Loss: 7.843578338623047
# Time step 309 / 22923   |   Portfolio Value: 31.19   |   Inventory: 33   |   Reward: 0.0   |   Epsilon: 0.9989   |   MSE Loss: 8.157869338989258
# Time step 310 / 22923   |   Portfolio Value: 34.82   |   Inventory: 34   |   Reward: 0.0   |   Epsilon: 0.9989   |   MSE Loss: 4.173366546630859
# Time step 311 / 22923   |   Portfolio Value: 42.3   |   Inventory: 33   |   Reward: 0.21999999999999886   |   Epsilon: 0.9989   |   MSE Loss: 6.202991962432861
# Time step 312 / 22923   |   Portfolio Value: 7.65   |   Inventory: 32   |   Reward: -0.7199999999999989   |   Epsilon: 0.9989   |   MSE Loss: 5.8234758377075195
# Time step 313 / 22923   |   Portfolio Value: 24.61   |   Inventory: 31   |   Reward: 3.140000000000015   |   Epsilon: 0.9989   |   MSE Loss: 5.043731689453125
# Time step 314 / 22923   |   Portfolio Value: 12.52   |   Inventory: 30   |   Reward: 2.9099999999999966   |   Epsilon: 0.9989   |   MSE Loss: 4.392787456512451
# Time step 315 / 22923   |   Portfolio Value: -5.78   |   Inventory: 29   |   Reward: 2.969999999999999   |   Epsilon: 0.9989   |   MSE Loss: 3.7147228717803955
# Time step 316 / 22923   |   Portfolio Value: 4.95   |   Inventory: 30   |   Reward: 0.0   |   Epsilon: 0.9989   |   MSE Loss: 5.356146335601807
# Time step 317 / 22923   |   Portfolio Value: 13.65   |   Inventory: 29   |   Reward: 0.28999999999999204   |   Epsilon: 0.9989   |   MSE Loss: 3.656003475189209
# Time step 318 / 22923   |   Portfolio Value: 119.5   |   Inventory: 28   |   Reward: 7.140000000000015   |   Epsilon: 0.9989   |   MSE Loss: 4.02972936630249
# Time step 319 / 22923   |   Portfolio Value: 153.94   |   Inventory: 29   |   Reward: 0.0   |   Epsilon: 0.9989   |   MSE Loss: 4.842460632324219
# ...
# Time step 2574 / 22923   |   Portfolio Value: -1907.51   |   Inventory: 82   |   Reward: -0.05000000000001137   |   Epsilon: 0.9893   |   MSE Loss: 2.4020299911499023
# Time step 2575 / 22923   |   Portfolio Value: -1888.65   |   Inventory: 81   |   Reward: 0.7199999999999989   |   Epsilon: 0.9893   |   MSE Loss: 2.084108591079712
# Time step 2576 / 22923   |   Portfolio Value: -1909.71   |   Inventory: 80   |   Reward: 14.5   |   Epsilon: 0.9893   |   MSE Loss: 1.9538459777832031
# Time step 2577 / 22923   |   Portfolio Value: -1860.91   |   Inventory: 81   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.0420966148376465
# Time step 2578 / 22923   |   Portfolio Value: -1799.35   |   Inventory: 82   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 2.7735755443573
# Time step 2579 / 22923   |   Portfolio Value: -1622.23   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.6100724935531616
# Time step 2580 / 22923   |   Portfolio Value: -1627.21   |   Inventory: 82   |   Reward: -0.060000000000002274   |   Epsilon: 0.9892   |   MSE Loss: 2.1083860397338867
# Time step 2581 / 22923   |   Portfolio Value: -1600.97   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 3.217369556427002
# Time step 2582 / 22923   |   Portfolio Value: -1504.69   |   Inventory: 84   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.8919175863265991
# Time step 2583 / 22923   |   Portfolio Value: -1484.53   |   Inventory: 85   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.5085134506225586
# Time step 2584 / 22923   |   Portfolio Value: -1470.08   |   Inventory: 86   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 2.2098546028137207
# Time step 2585 / 22923   |   Portfolio Value: -1448.58   |   Inventory: 85   |   Reward: 0.25   |   Epsilon: 0.9892   |   MSE Loss: 1.5570425987243652
# Time step 2586 / 22923   |   Portfolio Value: -1519.13   |   Inventory: 84   |   Reward: -0.4099999999999966   |   Epsilon: 0.9892   |   MSE Loss: 3.4096062183380127
# Time step 2587 / 22923   |   Portfolio Value: -1506.53   |   Inventory: 85   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.2632006406784058
# Time step 2588 / 22923   |   Portfolio Value: -1429.18   |   Inventory: 86   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.5247001647949219
# Time step 2589 / 22923   |   Portfolio Value: -1527.22   |   Inventory: 85   |   Reward: -1.1400000000000148   |   Epsilon: 0.9892   |   MSE Loss: 2.6020383834838867
# Time step 2590 / 22923   |   Portfolio Value: -1579.17   |   Inventory: 85   |   Reward: -0.1   |   Epsilon: 0.9892   |   MSE Loss: 1.7593971490859985
# Time step 2591 / 22923   |   Portfolio Value: -1517.97   |   Inventory: 84   |   Reward: -0.12000000000000455   |   Epsilon: 0.9892   |   MSE Loss: 2.8120641708374023
# Time step 2592 / 22923   |   Portfolio Value: -1589.47   |   Inventory: 84   |   Reward: -0.1   |   Epsilon: 0.9892   |   MSE Loss: 1.0483784675598145
# Time step 2593 / 22923   |   Portfolio Value: -1470.19   |   Inventory: 83   |   Reward: 0.4300000000000068   |   Epsilon: 0.9892   |   MSE Loss: 1.739701271057129
# Time step 2594 / 22923   |   Portfolio Value: -1471.02   |   Inventory: 82   |   Reward: 1.5800000000000125   |   Epsilon: 0.9892   |   MSE Loss: 2.5197322368621826
# Time step 2595 / 22923   |   Portfolio Value: -1522.68   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 3.0531299114227295
# Time step 2596 / 22923   |   Portfolio Value: -1528.49   |   Inventory: 82   |   Reward: -0.06999999999999318   |   Epsilon: 0.9892   |   MSE Loss: 1.6777281761169434
# Time step 2597 / 22923   |   Portfolio Value: -1516.19   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.2576696872711182
# Time step 2598 / 22923   |   Portfolio Value: -1665.59   |   Inventory: 84   |   Reward: 0.0   |   Epsilon: 0.9892   |   MSE Loss: 1.93863844871521
# Time step 2599 / 22923   |   Portfolio Value: -1721.87   |   Inventory: 83   |   Reward: -0.6700000000000159   |   Epsilon: 0.9892   |   MSE Loss: 1.9077001810073853
# Time step 2600 / 22923   |   Portfolio Value: -1717.72   |   Inventory: 82   |   Reward: -2.4199999999999875   |   Epsilon: 0.9891   |   MSE Loss: 1.2414829730987549
# Time step 2601 / 22923   |   Portfolio Value: -1571.76   |   Inventory: 81   |   Reward: 2.8100000000000023   |   Epsilon: 0.9891   |   MSE Loss: 1.0116791725158691
# Time step 2602 / 22923   |   Portfolio Value: -1572.57   |   Inventory: 82   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 1.479616403579712
# Time step 2603 / 22923   |   Portfolio Value: -1536.49   |   Inventory: 81   |   Reward: 0.4399999999999977   |   Epsilon: 0.9891   |   MSE Loss: 2.0645015239715576
# Time step 2604 / 22923   |   Portfolio Value: -1429.57   |   Inventory: 82   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 0.6918322443962097
# Time step 2605 / 22923   |   Portfolio Value: -1480.41   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.7531235218048096
# Time step 2606 / 22923   |   Portfolio Value: -1228.92   |   Inventory: 82   |   Reward: 3.030000000000001   |   Epsilon: 0.9891   |   MSE Loss: 0.9660618305206299
# Time step 2607 / 22923   |   Portfolio Value: -1165.78   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 1.2692856788635254
# Time step 2608 / 22923   |   Portfolio Value: -1204.79   |   Inventory: 82   |   Reward: -0.46999999999999886   |   Epsilon: 0.9891   |   MSE Loss: 1.2613294124603271
# Time step 2609 / 22923   |   Portfolio Value: -1205.61   |   Inventory: 83   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 0.9211633205413818
# Time step 2610 / 22923   |   Portfolio Value: -1224.7   |   Inventory: 84   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.7090940475463867
# Time step 2611 / 22923   |   Portfolio Value: -1196.98   |   Inventory: 85   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.6437160968780518
# Time step 2612 / 22923   |   Portfolio Value: -1201.23   |   Inventory: 86   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.7083864212036133
# Time step 2613 / 22923   |   Portfolio Value: -1204.67   |   Inventory: 87   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 1.2345023155212402
# Time step 2614 / 22923   |   Portfolio Value: -1294.28   |   Inventory: 86   |   Reward: -1.0300000000000011   |   Epsilon: 0.9891   |   MSE Loss: 1.4575761556625366
# Time step 2615 / 22923   |   Portfolio Value: -1308.9   |   Inventory: 87   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 1.0883729457855225
# Time step 2616 / 22923   |   Portfolio Value: -1365.45   |   Inventory: 88   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 1.4844295978546143
# Time step 2617 / 22923   |   Portfolio Value: -1270.41   |   Inventory: 89   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.5446393489837646
# Time step 2618 / 22923   |   Portfolio Value: -1242.82   |   Inventory: 88   |   Reward: 0.3100000000000023   |   Epsilon: 0.9891   |   MSE Loss: 2.4457285404205322
# Time step 2619 / 22923   |   Portfolio Value: -1220.82   |   Inventory: 89   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.4377715587615967
# Time step 2620 / 22923   |   Portfolio Value: -1061.51   |   Inventory: 90   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 0.8895827531814575
# Time step 2621 / 22923   |   Portfolio Value: -981.41   |   Inventory: 91   |   Reward: 0.0   |   Epsilon: 0.9891   |   MSE Loss: 2.33612060546875
# Time step 2622 / 22923   |   Portfolio Value: -880.5   |   Inventory: 91   |   Reward: -0.1   |   Epsilon: 0.9891   |   MSE Loss: 1.4894130229949951
# Time step 2623 / 22923   |   Portfolio Value: -969.68   |   Inventory: 90   |   Reward: 0.12999999999999545   |   Epsilon: 0.9891   |   MSE Loss: 1.7982513904571533
# Time step 2624 / 22923   |   Portfolio Value: -920.18   |   Inventory: 91   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.7651464939117432
# Time step 2625 / 22923   |   Portfolio Value: -1114.92   |   Inventory: 92   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.8077175617218018
# Time step 2626 / 22923   |   Portfolio Value: -1164.6   |   Inventory: 93   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 2.430325508117676
# Time step 2627 / 22923   |   Portfolio Value: -1093.92   |   Inventory: 94   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.0679999589920044
# Time step 2628 / 22923   |   Portfolio Value: -1161.6   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.6887905597686768
# Time step 2629 / 22923   |   Portfolio Value: -1272.75   |   Inventory: 94   |   Reward: -1.170000000000016   |   Epsilon: 0.989   |   MSE Loss: 2.038522720336914
# Time step 2630 / 22923   |   Portfolio Value: -1227.63   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 2.2524333000183105
# Time step 2631 / 22923   |   Portfolio Value: -1132.63   |   Inventory: 94   |   Reward: 1.0   |   Epsilon: 0.989   |   MSE Loss: 0.8702800869941711
# Time step 2632 / 22923   |   Portfolio Value: -1250.13   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.2600047588348389
# Time step 2633 / 22923   |   Portfolio Value: -1216.88   |   Inventory: 94   |   Reward: 0.3499999999999943   |   Epsilon: 0.989   |   MSE Loss: 1.1922047138214111
# Time step 2634 / 22923   |   Portfolio Value: -1249.88   |   Inventory: 94   |   Reward: -0.1   |   Epsilon: 0.989   |   MSE Loss: 1.3122113943099976
# Time step 2635 / 22923   |   Portfolio Value: -1248.0   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 2.7062318325042725
# Time step 2636 / 22923   |   Portfolio Value: -1338.35   |   Inventory: 95   |   Reward: -0.1   |   Epsilon: 0.989   |   MSE Loss: 2.3905348777770996
# Time step 2637 / 22923   |   Portfolio Value: -1170.2   |   Inventory: 96   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 2.069369316101074
# Time step 2638 / 22923   |   Portfolio Value: -1112.6   |   Inventory: 95   |   Reward: 0.5999999999999943   |   Epsilon: 0.989   |   MSE Loss: 0.2620176076889038
# Time step 2639 / 22923   |   Portfolio Value: -1108.8   |   Inventory: 94   |   Reward: 1.460000000000008   |   Epsilon: 0.989   |   MSE Loss: 1.3292224407196045
# Time step 2640 / 22923   |   Portfolio Value: -1105.04   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.6791294813156128
# Time step 2641 / 22923   |   Portfolio Value: -1254.29   |   Inventory: 95   |   Reward: -0.1   |   Epsilon: 0.989   |   MSE Loss: 1.3135442733764648
# Time step 2642 / 22923   |   Portfolio Value: -1270.44   |   Inventory: 94   |   Reward: -1.7399999999999807   |   Epsilon: 0.989   |   MSE Loss: 3.2571604251861572
# Time step 2643 / 22923   |   Portfolio Value: -1262.92   |   Inventory: 93   |   Reward: -1.8000000000000114   |   Epsilon: 0.989   |   MSE Loss: 2.2720353603363037
# Time step 2644 / 22923   |   Portfolio Value: -1301.98   |   Inventory: 94   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 2.312835216522217
# Time step 2645 / 22923   |   Portfolio Value: -1244.64   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.989   |   MSE Loss: 1.9790477752685547
# Time step 2646 / 22923   |   Portfolio Value: -1296.89   |   Inventory: 94   |   Reward: -0.549999999999983   |   Epsilon: 0.989   |   MSE Loss: 1.4185926914215088
# Time step 2647 / 22923   |   Portfolio Value: -1334.49   |   Inventory: 93   |   Reward: -0.3400000000000034   |   Epsilon: 0.9889   |   MSE Loss: 2.3888039588928223
# Time step 2648 / 22923   |   Portfolio Value: -1415.4   |   Inventory: 92   |   Reward: -2.670000000000016   |   Epsilon: 0.9889   |   MSE Loss: 0.922976553440094
# Time step 2649 / 22923   |   Portfolio Value: -1523.96   |   Inventory: 93   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 2.147481918334961
# Time step 2650 / 22923   |   Portfolio Value: -1512.8   |   Inventory: 94   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.1165605783462524
# Time step 2651 / 22923   |   Portfolio Value: -1558.86   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.241330623626709
# Time step 2652 / 22923   |   Portfolio Value: -1570.26   |   Inventory: 96   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.9435155391693115
# Time step 2653 / 22923   |   Portfolio Value: -1523.22   |   Inventory: 95   |   Reward: 0.4899999999999807   |   Epsilon: 0.9889   |   MSE Loss: 2.8931832313537598
# Time step 2654 / 22923   |   Portfolio Value: -1527.97   |   Inventory: 96   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 2.4669294357299805
# Time step 2655 / 22923   |   Portfolio Value: -1636.45   |   Inventory: 95   |   Reward: -1.1299999999999955   |   Epsilon: 0.9889   |   MSE Loss: 1.9199914932250977
# Time step 2656 / 22923   |   Portfolio Value: -1562.35   |   Inventory: 94   |   Reward: -0.030000000000001137   |   Epsilon: 0.9889   |   MSE Loss: 2.182136058807373
# Time step 2657 / 22923   |   Portfolio Value: -1655.41   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.0283385515213013
# Time step 2658 / 22923   |   Portfolio Value: -1599.46   |   Inventory: 95   |   Reward: -0.1   |   Epsilon: 0.9889   |   MSE Loss: 0.6575812697410583
# Time step 2659 / 22923   |   Portfolio Value: -1591.96   |   Inventory: 95   |   Reward: -0.1   |   Epsilon: 0.9889   |   MSE Loss: 1.4491807222366333
# Time step 2660 / 22923   |   Portfolio Value: -1593.86   |   Inventory: 94   |   Reward: 0.6500000000000057   |   Epsilon: 0.9889   |   MSE Loss: 1.264981746673584
# Time step 2661 / 22923   |   Portfolio Value: -1547.8   |   Inventory: 93   |   Reward: -0.37000000000000455   |   Epsilon: 0.9889   |   MSE Loss: 0.56892991065979
# Time step 2662 / 22923   |   Portfolio Value: -1485.49   |   Inventory: 94   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.9129811525344849
# Time step 2663 / 22923   |   Portfolio Value: -1551.29   |   Inventory: 95   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 2.0225212574005127
# Time step 2664 / 22923   |   Portfolio Value: -1500.94   |   Inventory: 96   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.6652119159698486
# Time step 2665 / 22923   |   Portfolio Value: -1459.66   |   Inventory: 97   |   Reward: 0.0   |   Epsilon: 0.9889   |   MSE Loss: 1.7287263870239258
# Time step 2666 / 22923   |   Portfolio Value: -1438.32   |   Inventory: 96   |   Reward: 0.21999999999999886   |   Epsilon: 0.9889   |   MSE Loss: 1.740371584892273
# Time step 2667 / 22923   |   Portfolio Value: -1437.36   |   Inventory: 95   |   Reward: 0.660000000000025   |   Epsilon: 0.9889   |   MSE Loss: 2.2451086044311523
# Time step 2668 / 22923   |   Portfolio Value: -1537.11   |   Inventory: 94   |   Reward: 0.14000000000001478   |   Epsilon: 0.9889   |   MSE Loss: 1.4694173336029053
# Time step 2669 / 22923   |   Portfolio Value: -1577.53   |   Inventory: 93   |   Reward: -0.9900000000000091   |   Epsilon: 0.9889   |   MSE Loss: 1.9632000923156738
# Time step 2670 / 22923   |   Portfolio Value: -1609.15   |   Inventory: 92   |   Reward: -0.9099999999999966   |   Epsilon: 0.9889   |   MSE Loss: 2.59120512008667
# Time step 2671 / 22923   |   Portfolio Value: -1708.51   |   Inventory: 93   |   Reward: 0.0   |   Epsilon: 0.9888   |   MSE Loss: 1.4215772151947021
# Time step 2672 / 22923   |   Portfolio Value: -1827.55   |   Inventory: 94   |   Reward: 0.0   |   Epsilon: 0.9888   |   MSE Loss: 2.7246408462524414
# Time step 2673 / 22923   |   Portfolio Value: -1748.59   |   Inventory: 93   |   Reward: 0.8400000000000034   |   Epsilon: 0.9888   |   MSE Loss: 1.225017786026001
# Time step 2674 / 22923   |   Portfolio Value: -1795.19   |   Inventory: 93   |   Reward: -0.1   |   Epsilon: 0.9888   |   MSE Loss: 2.047102928161621
# Time step 2675 / 22923   |   Portfolio Value: -1796.12   |   Inventory: 94   |   Reward: 0.0   |   Epsilon: 0.9888   |   MSE Loss: 1.8991535902023315

# %%
import matplotlib.pyplot as plt

train_df, test_df, train_close, test_close = get_precollected_data(split_ratio=0.8)

def plot_portfolio_value(data, title, eth_price, filename):
    plt.figure(figsize=(20, 12))
    plt.plot(eth_price["Close"][::50], label="ETH Price")
    # for i in range(40, len(data)):
    #     plt.plot(data[i]["Portfolio Value"], label="Portfolio Value")
    plt.plot(data[len(data)-1]["Portfolio Value"][::50], label="Portfolio Value")
    plt.xlabel("Time Steps")
    plt.ylabel("Value")
    plt.legend()
    plt.title(title)
    plt.savefig(filename)
    

def plot_portfolio_value_test(data, title, eth_price, filename):
    plt.figure(figsize=(20, 12))
    plt.plot(eth_price["Close"][::10], label="ETH Price")
    plt.plot(data["Portfolio Value"][::10], label="Portfolio Value")
    plt.xlabel("Time Steps")
    plt.ylabel("Value")
    plt.legend()
    plt.title(title)
    plt.savefig(filename)

def plot_inventory_held(data, title, filename):
    plt.figure(figsize=(12, 6))
    plt.plot(data["Inventory Size"][::10], label="Inventory Held")
    plt.xlabel("Time Steps")
    plt.ylabel("Amount")
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.savefig(filename)

def plot_actions(data, title, filename):
    plt.figure(figsize=(12, 6))
    plt.plot(data["Actions"][::10], label="Actions")
    plt.xlabel("Time Steps")
    plt.ylabel("Action")
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.savefig(filename)

# Visualize the data
# You can change the index to visualize a specific training episode

with open ("Output/episode_mem.json", "r") as f:
    episode_data = json.load(f)

with open ("Output/testing_mem.json", "r") as f:
    testing_data = json.load(f)

# look at last episode
selected_episode = len(episode_data) - 1


# plot_portfolio_value(episode_data, f"Portfolio Value for Episode {selected_episode}", train_close, "Output/episode_portfolio.png")
plot_portfolio_value(episode_data, f"Portfolio Value for Training", train_close, "Output/episode_portfolio.png")
# plot_inventory_held(episode_data[selected_episode], f"Inventory Held for Episode {selected_episode}", "Output/episode_inventory.png")
# plot_actions(episode_data[selected_episode], f"Actions for Episode {selected_episode}", "Output/episode_actions.png")

plot_portfolio_value_test(testing_data, f"Portfolio Value for Testing", test_close, "Output/testing_portfolio.png")
# plot_inventory_held(testing_data, f"Inventory Held for Testing", "Output/testing_inventory.png")
# plot_actions(testing_data, f"Actions for Testing", "Output/testing_actions.png")
# Out:
# Pre-collected data loaded successfully.
# NaN values dropped.
# Data split.
# Train data saved.
# Test data saved.
