# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR
from time import time
import json
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData
import yfinance as yf
import os

# %%
print("PyTorch version " + torch.__version__)
print("Num GPUs Available: ", torch.cuda.device_count())
print(torch.cuda.is_available())
# Out:
# PyTorch version 1.13.1
# Num GPUs Available:  1
# True

# %%
class DDDQN(torch.nn.Module):
    def __init__(self, input_features, window_size):
        super().__init__()
        self.input_size = input_features * window_size  # input size
        # The use of LeakyReLU activation functions can help alleviate the vanishing gradient problem
        self.leaky_relu = torch.nn.LeakyReLU(negative_slope=0.1) 
        
        # Dueling DQN architecture
        self.d1 = torch.nn.Linear(self.input_size, 256)  # input layer
        self.bn1 = torch.nn.BatchNorm1d(256)  # batch normalization  used to normalize the input layer by adjusting and scaling the activations
        self.d2 = torch.nn.Linear(256, 512)  # hidden layer
        self.bn2 = torch.nn.BatchNorm1d(512)  # batch normalization used to normalize the input layer by adjusting and scaling the activations
        self.drop1 = torch.nn.Dropout(0.5)  # dropout layer used to prevent overfitting
        self.d3 = torch.nn.Linear(512, 512)  # hidden layer
        self.bn3 = torch.nn.BatchNorm1d(512)  # batch normalization used to normalize the input layer by adjusting and scaling the activations
        self.drop2 = torch.nn.Dropout(0.5)  # dropout layer used to prevent overfitting
        self.d4 = torch.nn.Linear(512, 256)  # hidden layer
        self.bn4 = torch.nn.BatchNorm1d(256)    # batch normalization used to normalize the input layer by adjusting and scaling the activations
        self.drop3 = torch.nn.Dropout(0.3)  # dropout layer used to prevent overfitting
        self.dv1 = torch.nn.Linear(256, 128)  # value hidden layer
        self.da1 = torch.nn.Linear(256, 128)  # actions hidden layer
        self.dv2 = torch.nn.Linear(128, 1)  # value output
        self.da2 = torch.nn.Linear(128, 9)  # actions output

    # forward propagation
    def forward(self, input_data):
        input_data = input_data.reshape(input_data.size(0), -1)  # Flatten the input tensor
        x = self.leaky_relu(self.d1(input_data))  # activation function
        x = self.bn1(x)  # batch normalization
        x = x.view(x.size(0), -1)  # equivalent to Flatten()
        x = self.leaky_relu(self.d2(x))  # activation function
        x = self.bn2(x)  # batch normalization
        x = self.drop1(x)  # dropout
        x = self.leaky_relu(self.d3(x))  # activation function
        x = self.bn3(x)  # batch normalization
        x = self.drop2(x)  # dropout
        x = self.leaky_relu(self.d4(x))   # activation function
        x = self.bn4(x)  # batch normalization
        x = self.drop3(x)  # dropout
        v = self.leaky_relu(self.dv1(x))  # value function
        a = self.leaky_relu(self.da1(x))  # actions function
        v = self.dv2(v)     # value output
        a = self.da2(a)   # actions output
        Q = v + (a - torch.mean(a, dim=1, keepdim=True)) # dueling Q values
        return Q   # return Q values
    
    # advantage function is used to calculate the advantage of taking each action at each state
    # processes the input state through the common layers and then the advantage stream layers.
    # used for debugging or analysis purposes.
    def advantage(self, state):
        # Common processing
        x = self.leaky_relu(self.d1(state))
        x = self.bn1(x)
        x = self.leaky_relu(self.d2(x))
        x = self.bn2(x)
        x = self.drop1(x)
        x = self.leaky_relu(self.d3(x))
        x = self.bn3(x)
        x = self.drop2(x)
        x = self.leaky_relu(self.d4(x))
        x = self.bn4(x)
        x = self.drop3(x)

        # Advantage stream processing
        a = self.leaky_relu(self.da1(x))  # actions function 
        a = self.da2(a) # actions output

        return a  # return advantage values

# %%
import numpy as np
import torch

# The sumtree is used to store the priorities of the experiences it receives and to sample the experiences based on their priorities.
class SumTree:
    def __init__(self, capacity):
        self.capacity = capacity   # capacity of the sumtree
        self.tree = np.zeros(2 * capacity - 1) # stores the priorities
        self.data = np.zeros(capacity, dtype=object)  # stores the experiences
        self.write = 0  # pointer to the next experience to be stored
        self.n_entries = 0  # number of experiences stored

    def _propagate(self, idx, change): # propagate the change in the priority value up the tree
        parent = (idx - 1) // 2  # parent node
        self.tree[parent] += change  # update the priority value
        if parent != 0:  # if the parent node is not the root node
            self._propagate(parent, change)  # propagate the change in the priority value up the tree

    def _retrieve(self, idx, s):  # retrieve the experience based on the priority value
        left = 2 * idx + 1  # left node
        right = left + 1  # right node
        if left >= len(self.tree):  # if the left node is a leaf node
            return idx  # return the index of the leaf node
        if s <= self.tree[left]:  # if the priority value is less than or equal to the priority value of the left node
            return self._retrieve(left, s)  # retrieve the experience from the left node
        else: # if the priority value is greater than the priority value of the left node
            return self._retrieve(right, s - self.tree[left])  # retrieve the experience from the right node

    def total(self):  # return the total priority value of the sumtree
        return self.tree[0]  # return the priority value of the root node

    def add(self, data, p):  # add the experience and its priority value to the sumtree
        idx = self.write + self.capacity - 1  # index of the leaf node
        self.data[self.write] = data  # store the experience
        self.update(idx, p)  # update the priority value of the leaf node
        self.write += 1  # increment the pointer to the next experience to be stored
        if self.write >= self.capacity:  # if the pointer to the next experience to be stored exceeds the capacity of the sumtree
            self.write = 0  # reset the pointer to the next experience to be stored
        if self.n_entries < self.capacity:   # if the number of experiences stored is less than the capacity of the sumtree
            self.n_entries += 1  # increment the number of experiences stored

    def update(self, idx, p): # update the priority value of the leaf node
        change = p - self.tree[idx] # change in the priority value
        self.tree[idx] = p # update the priority value
        self._propagate(idx, change) # propagate the change in the priority value up the tree

    def get(self, s): # retrieve the experience based on the priority value
        idx = self._retrieve(0, s)  # retrieve the experience
        dataIdx = idx - self.capacity + 1 # index of the experience
        return idx, self.tree[idx], self.data[dataIdx]  # return the index of the experience, the priority value of the experience, and the experience

# The prioritized experience replay buffer is used to store the experiences and sample the experiences based on their priorities.
class PrioritizedExpReplay():    
    def __init__(self, num_features, window_size, device, buffer_size=1000000, alpha=0.6, beta=0.4): # initialize the prioritized experience replay buffer
        self.tree = SumTree(buffer_size) # initialize the sumtree
        self.alpha = alpha # initialize the alpha value which is used to control the amount of prioritization
        self.beta = beta    # initialize the beta value which is used to control the amount of importance sampling
        self.device = device    # initialize the device (GPU)
        self.buffer_size = buffer_size # initialize the capacity of the sumtree
        self.window_size = window_size # initialize the window size
        self.num_features = num_features    # initialize the number of features

    def add_exp(self, state, action, reward, next_state, done):
        max_priority = np.max(self.tree.tree[-self.tree.capacity:])
        if max_priority == 0:
            max_priority = 1
        exp = (state, action, reward, next_state, done)
        self.tree.add(exp, max_priority ** self.alpha)

    def sample_exp(self, batch_size=64):
        batch = []
        idxs = []
        segment = self.tree.total() / batch_size
        priorities = []

        for i in range(batch_size):
            a = segment * i
            b = segment * (i + 1)
            s = np.random.uniform(a, b)
            idx, p, exp = self.tree.get(s)
            priorities.append(p)
            batch.append(exp)
            idxs.append(idx)

        sampling_probabilities = np.array(priorities) / self.tree.total()
        is_weights = np.power(self.tree.n_entries * sampling_probabilities, -self.beta)
        is_weights /= np.max(is_weights)

        
        states, actions, rewards, next_states, dones = zip(*batch)
        
        states = torch.tensor(states, dtype=torch.float32).to(self.device)
        actions = torch.tensor(actions, dtype=torch.int64).to(self.device)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(self.device)
        next_states = torch.tensor(next_states, dtype=torch.float32).to(self.device)
        dones = torch.tensor(dones, dtype=torch.bool).to(self.device)
        is_weights = torch.tensor(is_weights, dtype=torch.float32).to(self.device)
        
        return states, actions, rewards, next_states, dones, idxs, is_weights

    def update_priorities(self, idxs, td_errors):
        priorities = np.abs(td_errors) + 1e-5
        for idx, priority in zip(idxs, priorities):
            self.tree.update(idx, priority ** self.alpha)

# %%
class Agent():

    # Initializes the agent with various parameters such as window_size, gamma, number of episodes, learning rate, minimum epsilon, and update interval. 
    # It also initializes the device, portfolio, epsilon, training step counter, memory, batch size, online and target networks, optimizer, scheduler, 
    # and the holding time.
    def __init__(self, data_shape, num_episodes, window_size=30, gamma=0.99, update_interval=30, lr=0.001, min_epsilon=0.02):
        
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.window_size = window_size  # number of previous prices to use as state
        self.data_shape = data_shape  # [num_features, window_size]
        self.portfolio = [0, 0, 0, 0]  # [total eth, cash_held, total_portfolio_value (eth value + cash held - initial investment), max ether held so far]
        self.inventory = [] 
        self.gamma = gamma  # discount factor for future rewards
        self.num_episodes = num_episodes    # number of episodes
        self.epsilon = 1.0  # exploration rate
        self.min_epsilon = min_epsilon   # minimum exploration rate
        self.update_interval = update_interval  # number of steps between target network updates
        self.trainstep = 0
        # self.memory = ExpReplay(self.window_size, data_shape[1], self.device)        
        self.memory = PrioritizedExpReplay(self.window_size, data_shape[1], self.device)
        self.batch_size = 64
        self.online_net = DDDQN(self.data_shape[1], window_size).to(self.device)
        self.target_net = DDDQN(self.data_shape[1], window_size).to(self.device)
        self.target_net.load_state_dict(self.online_net.state_dict())
        self.holding_time = 0 # Number of timesteps for which the agent has held the position
        initial_learning_rate = lr
        decay_steps = self.num_episodes * self.data_shape[0] // 10  # You can adjust the divisor to control the decay rate
        decay_rate = 0.9  # You can adjust this value to control the decay rate
        self.optimizer = optim.Adam(self.online_net.parameters(), lr=initial_learning_rate)
        self.scheduler = ExponentialLR(self.optimizer, gamma=decay_rate)
        self.criterion = nn.MSELoss()

    # CURRICULUM TRAINING PART 1 and 2
    def get_action(self, state):
            state_numpy = np.array(state)
            state_tensor = torch.FloatTensor(state_numpy).to(self.device).unsqueeze(0)
            # create a random number between 0 and 1 and compare it to epsilon for our epsilon-greedy algorithm
            if np.random.rand() <= self.epsilon:
                # Select a random action out of the list of available actions
                if len(self.inventory) > 0:  # if we have inventory to sell
                    return np.random.choice([0, 1, 2, 3, 4, 5, 6, 7, 8])
                else:
                    return np.random.choice([4, 5, 6, 7, 8])  # we can only buy or hold
            else:
                with torch.no_grad():
                    self.online_net.eval()
                    actions = self.online_net(state_tensor)
                    # actions = self.online_net.advantage(state_tensor)
                    self.online_net.train()

                    if len(self.inventory) > 0:
                        action = torch.argmax(actions[0, :]).item()
                    else: # if we don't have inventory to sell, we remove that action option
                        action = torch.argmax(actions[0, 4:]).item() + 4
                    return action
                
    # CURRICULUM TRAINING PART 2
    def get_action_curriculum_3(self, state, balance):
            state_numpy = np.array(state)
            state_tensor = torch.FloatTensor(state_numpy).to(self.device).unsqueeze(0)
            # create a random number between 0 and 1 and compare it to epsilon for our epsilon-greedy algorithm
            if np.random.rand() <= self.epsilon:
                # Select a random action out of the list of available actions
                if len(self.inventory) > 0 and balance >= 0:  # if we have inventory to sell and balance is greater than 10
                    return np.random.choice([0, 1, 2, 3, 4, 5, 6, 7, 8])
                elif len(self.inventory) > 0 and balance <= 0: # if we have inventory to sell and balance is less than 10
                    return np.random.choice([0, 1, 2, 3, 4])  # we can only sell or hold
                elif len(self.inventory) == 0 and balance >= 0: # if we don't have inventory to sell and balance is greater than 10
                    return np.random.choice([4, 5, 6, 7, 8])  # we can only buy or hold
                else: # if we don't have inventory to sell and balance is less than 10
                    return 4 # we can only hold

            else:
                with torch.no_grad():
                    self.online_net.eval()
                    actions = self.online_net(state_tensor)
                    # actions = self.online_net.advantage(state_tensor)
                    self.online_net.train()

                    if len(self.inventory) > 0 and balance >= 0:
                        action = torch.argmax(actions[0, :]).item()
                    elif len(self.inventory) > 0 and balance <= 0:
                        action = torch.argmax(actions[0, :5]).item()
                    elif len(self.inventory) == 0 and balance >= 0:
                        action = torch.argmax(actions[0, 4:]).item() + 4
                    else:
                        action = 4
                    return action

    # # CURRICULUM TRAINING PART 2
    # # Takes the current state and cash balance as inputs and returns an action based on epsilon-greedy exploration strategy.
    # # It returns an action between 0 and 8, depending on the random number generated and the current portfolio status.
    # def get_action(self, state, cash_balance):
    #     eth_held = self.portfolio[0]
    #     cash_held = self.portfolio[1]
    #     total_portfolio_value = self.portfolio[2]
    #     max_eth_held = self.portfolio[3]
    #     state_numpy = np.array(state)
    #     state_tensor = torch.FloatTensor(state_numpy).to(self.device).unsqueeze(0)
    #     if np.random.rand() <= self.epsilon:
    #         # print("Random action based on epsilon")
    #         if eth_held > 0.001 and cash_balance >= 10 and len(self.inventory) > 0:# if we have ether and cash
    #             # print("we have ether and cash so our options are [0, 1, 2, 3, 4, 5, 6, 7, 8]")
    #             return np.random.choice([0, 1, 2, 3, 4, 5, 6, 7, 8])  # we can perform any action
    #         elif eth_held > 0.001 and cash_balance < 10:  # if we have ether but no cash
    #             # print("we have ether but no cash so our options are [0, 1, 2, 3, 4]")
    #             return np.random.choice([0, 1, 2, 3, 4])  # we can only sell or hold
    #         elif eth_held <= 0.001 and cash_balance >= 10:  # if we have cash but no ether
    #             # print("we have cash but no ether so our options are [4, 5, 6, 7, 8]")
    #             return np.random.choice([4, 5, 6, 7, 8])  # we can only buy or hold
    #         else:
    #             # print("we have neither cash nor ether so our only option is 4")
    #             action = 4  # hold
    #             return action
    #     else:
    #         # print("Action based on neural network output")
    #         with torch.no_grad():
    #             self.online_net.eval()
    #             actions = self.online_net(state_tensor)
    #             self.online_net.train()
    #             # print(f"Neural network output: {actions}")
                
    #             if eth_held > 0.001 and cash_balance >= 10:
    #                 # print("we have ether and cash so our options are [0, 1, 2, 3, 4, 5, 6, 7, 8]")
    #                 action = torch.argmax(actions[0, :]).item()
    #             elif eth_held > 0.001 and cash_balance < 10:
    #                 # print("we have ether but no cash so our options are [0, 1, 2, 3, 4]")
    #                 action = torch.argmax(actions[0, :5]).item()
    #             elif eth_held <= 0.001 and cash_balance >= 10:
    #                 # print("we have cash but no ether so our options are [4, 5, 6, 7, 8]")
    #                 action = torch.argmax(actions[0, 4:]).item() + 4
    #             else:
    #                 # print("we have neither cash nor ether so our only option is 4")
    #                 action = 4
        
    #     # print(f"Selected action: {action}")
    #     return action



    #  This method softly updates the target network by blending the weights of the online network and target network using the parameter tau.
    def update_target(self, tau=0.001):
        for target_param, online_param in zip(self.target_net.parameters(), self.online_net.parameters()):
            target_param.data.copy_(tau * online_param.data + (1.0 - tau) * target_param.data)

    #  Linearly decays the epsilon value from its initial value to the minimum epsilon value over the course of the total training steps.
    def update_epsilon(self):
        if self.epsilon > self.min_epsilon:
            # b = self.min_epsilon**(1/(self.num_episodes*self.data_shape[0]))
            # self.epsilon = b**self.trainstep # exponential decay
            self.epsilon -= (1.0 - self.min_epsilon) / (self.num_episodes * self.data_shape[0])   # linear decay

    # Trains the online network using the samples from the prioritized experience replay memory. 
    # It updates the target network periodically based on the update_interval. 
    # It also calculates the loss, applies the importance sampling weights, and updates the priorities in the buffer.
    def train(self):
        if self.memory.tree.n_entries < self.batch_size:
            return

        if self.trainstep % self.update_interval == 0:
            self.update_target()

        states, actions, rewards, next_states, dones, idxs, is_weights = self.memory.sample_exp(self.batch_size)

        q_next_state_online_net = self.online_net(next_states)
        q_next_state_target_net = self.target_net(next_states)

        max_action = torch.argmax(q_next_state_online_net, dim=1).to(self.device)

        batch_index = torch.arange(self.batch_size, dtype=torch.int64).to(self.device)

        q_predicted = self.online_net(states)
        q_target = q_predicted.clone().detach()

        q_target[batch_index, actions] = rewards + self.gamma * q_next_state_target_net[batch_index, max_action] * dones

        td_errors = q_target - q_predicted
        td_errors = td_errors.detach().cpu().numpy()
        td_errors = td_errors[np.arange(self.batch_size), actions.cpu().numpy()]

        # Update priorities in the buffer
        self.memory.update_priorities(idxs, td_errors)

        # loss = self.criterion(q_predicted, q_target)
        # loss *= is_weights  # Apply importance sampling weights
        # loss = loss.mean()

        loss = self.criterion(q_predicted, q_target).view(-1, 1)
        loss = (loss * is_weights).mean()

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.update_epsilon()
        self.trainstep += 1
        return loss.item()

    # This method is called to save the model parameters of the online and target networks in the Output folder.
    def save_model(self):
        import os

        output_directory = "Output"
        online_model_directory = os.path.join(output_directory, "online_model")
        target_model_directory = os.path.join(output_directory, "target_model")

        os.makedirs(online_model_directory, exist_ok=True)
        os.makedirs(target_model_directory, exist_ok=True)

        torch.save(self.online_net.state_dict(), os.path.join(online_model_directory, 'model.pt'))
        torch.save(self.target_net.state_dict(), os.path.join(target_model_directory, 'model.pt'))

    # This method is called to load the model parameters of the online and target networks from the Output folder.
    def load_model(self):
        import os

        output_directory = "Output"
        online_model_directory = os.path.join(output_directory, "online_model")
        print("loaded model from: ", online_model_directory)
        target_model_directory = os.path.join(output_directory, "target_model")
        print("loaded model from: ", target_model_directory)


        self.online_net.load_state_dict(torch.load(os.path.join(online_model_directory, 'model.pt')))
        self.target_net.load_state_dict(torch.load(os.path.join(target_model_directory, 'model.pt')))

    # This method is called to calculate the reward for the sell action.
    # def calculate_sell_reward(self, t, eth_df, eth_close_price_unscaled, amount_to_sell, initial_investment, trading_fee_rate):
    #     ether_held, cash_held, previous_portfolio_value, max_ether_held_so_far = self.portfolio

    #     unscaled_close_price = eth_close_price_unscaled["Close"].iloc[t]
    #     value_of_eth_sold = unscaled_close_price * amount_to_sell
    #     trading_fee = value_of_eth_sold * trading_fee_rate
    #     cash_received = value_of_eth_sold - trading_fee
    #     new_cash_held = cash_held + cash_received
    #     new_ether_held = ether_held - amount_to_sell

    #     # Calculate portfolio value
    #     # new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price) - initial_investment
    #     new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price)
    #     # Calculate the reward based on the change in portfolio value
    #     reward = (new_portfolio_value - previous_portfolio_value) / initial_investment

    #     # Update portfolio
    #     self.portfolio = [new_ether_held, new_cash_held, new_portfolio_value, max_ether_held_so_far]

    #     # Add a bonus if the portfolio value is greater than the initial investment
    #     if new_portfolio_value > initial_investment:
    #         bonus = min((new_portfolio_value - initial_investment) / initial_investment, 0.5)
    #         reward = reward * (1 + bonus)

    #     return reward

    # # This method is called to calculate the reward for the buy action.
    # def calculate_buy_reward(self, t, eth_df, eth_close_price_unscaled, eth_to_buy, cash_spent, initial_investment):
    #     ether_held, cash_held, previous_portfolio_value, max_ether_held_so_far = self.portfolio

    #     unscaled_close_price = eth_close_price_unscaled["Close"].iloc[t]
    #     eth_received = eth_to_buy  # trading fee is already accounted for in the amount of ETH to buy
    #     new_cash_held = cash_held - cash_spent
    #     new_ether_held = ether_held + eth_received
    #     # Calculate portfolio value
    #     # new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price) - initial_investment
    #     new_portfolio_value = new_cash_held + (new_ether_held * unscaled_close_price)
    #     # Calculate the reward based on the change in portfolio value
    #     # reward = (new_portfolio_value - previous_portfolio_value) / initial_investment
    #     reward_eth_held = (new_ether_held - max_ether_held_so_far) / (new_ether_held + max_ether_held_so_far)

    #     if new_ether_held > max_ether_held_so_far:
    #         max_ether_held_so_far = new_ether_held
        
    #     # Combine the rewards
    #     reward = reward_eth_held

    #     # Update portfolio
    #     self.portfolio = [new_ether_held, new_cash_held, new_portfolio_value, max_ether_held_so_far]

    #     # Add a bonus if the portfolio value is greater than the initial investment
    #     if new_portfolio_value > initial_investment:
    #         bonus = min((new_portfolio_value - initial_investment) / initial_investment, 0.5)
    #         reward = reward * (1 + bonus)

    #     return reward

    # # Takes an action and updates the portfolio accordingly. 
    # # It calculates the reward for the action and applies a penalty if the agent doesn't have enough 
    # # Ethereum or cash balance to perform the requested action.
    # def trade(self, t, action, eth_df, eth_df_unscaled, initial_investment, trading_fee_rate):
    #     reward = 0
    #     eth_held, cash_balance, previous_portfolio_value, max_ether_held_so_far = self.portfolio
    #     sell_percentages = [0.25, 0.5, 0.75, 1.0]
    #     buy_percentages = [0.25, 0.5, 0.75, 1.0]

    #     # SELL
    #     if action >= 0 and action <= 3:
    #         print("SELL with action: ", action)
    #         # Reset holding time when selling
    #         self.holding_time = 0
    #         sell_percentage = sell_percentages[action]
    #         amount_to_sell = eth_held * sell_percentage

    #         while amount_to_sell > 0 and eth_held > 0.001:

    #             reward = self.calculate_sell_reward(t, eth_df, eth_df_unscaled, amount_to_sell, initial_investment, trading_fee_rate)

    #             eth_held, cash_balance, current_portfolio_value, max_ether_held_so_far = self.portfolio  # Update portfolio after selling
    #             amount_to_sell = 0
    #     # HOLD
    #     elif action == 4:
    #         print("HOLD with action: ", action)
    #         # self.portfolio[2] = cash_balance + (eth_held * eth_df_unscaled["Close"].iloc[t]) - initial_investment
    #         self.portfolio[2] = cash_balance + (eth_held * eth_df_unscaled["Close"].iloc[t])
    #         # Increment holding time when holding
    #         self.holding_time += 1
    #         # Apply a holding time reward
    #         reward = -0.01 * self.holding_time
    #     # BUY
    #     elif action >= 5:
    #         print("BUY with action: ", action)
    #         # Reset holding time when buying
    #         self.holding_time = 0
    #         buy_percentage = buy_percentages[action - 5]
    #         money_to_spend = (cash_balance * buy_percentage)
    #         trading_fee = money_to_spend * trading_fee_rate
    #         eth_to_buy = (money_to_spend - trading_fee) / eth_df_unscaled["Close"].iloc[t]
    #         cash_spent = eth_to_buy * eth_df_unscaled["Close"].iloc[t]

    #         reward = self.calculate_buy_reward(t, eth_df, eth_df_unscaled, eth_to_buy, cash_spent, initial_investment)

    #     return reward
    
    def trade(self, t, action, eth_df, eth_df_unscaled, initial_investment, trading_fee_rate):
        eth_held, balance, previous_portfolio_value, max_ether_held_so_far = self.portfolio
        reward = 0
        if action >= 0 and action <= 3:
            # reward = eth_df_unscaled["Close"].iloc[t] - self.inventory.pop(0) # this sells the oldest bought eth
            reward = eth_df_unscaled["Close"].iloc[t] - self.inventory.pop() # this sells the most recently bought eth (worth a shot)
            self.portfolio[1] += reward
        elif action == 4:
            reward = -0.1
            pass
        elif action >= 5 and balance >= eth_df_unscaled["Close"].iloc[t]:
            self.inventory.append(eth_df_unscaled["Close"].iloc[t])
        return reward
    
    def trade_curriculum_2(self, t, action, eth_df, eth_df_unscaled, initial_investment, trading_fee_rate):
        eth_held, balance, previous_portfolio_value, max_ether_held_so_far = self.portfolio
        buy_percentages = [0.25, 0.5, 0.75, 1.0]
        reward = 0
        if action >= 0 and action <= 3:  # SELL
            previous_eth_bought, previous_price_paid = self.inventory.pop()
            profit = (previous_eth_bought * eth_df_unscaled["Close"].iloc[t]) * (1 - trading_fee_rate)
            self.portfolio[1] += profit
            reward = profit - previous_price_paid
            print("ETH sold: ", previous_eth_bought, "For: ", profit, "Profit: ", reward)
        elif action == 4:  # HOLD
            reward = -0.1
        elif action >= 5 and balance >=  eth_df_unscaled["Close"].iloc[t]:  # BUY
            # amount of cash spent accounting for trading fee
            cash_spent = (balance * buy_percentages[action - 5]) * (1 - trading_fee_rate)
            eth_to_buy = cash_spent / eth_df_unscaled["Close"].iloc[t]
            self.portfolio[0] += eth_to_buy
            print("ETH bought: ", eth_to_buy, "Cash spent: ", cash_spent)
            self.inventory.append((eth_to_buy, cash_spent))
        return reward
    
    def trade_curriculum_3(self, t, action, eth_df, eth_df_unscaled, initial_investment, trading_fee_rate):
        eth_held, balance, previous_portfolio_value, max_ether_held_so_far = self.portfolio
        buy_percentages = [0.25, 0.5, 0.75, 1.0]
        reward = 0
        if action >= 0 and action <= 3:  # SELL
            previous_eth_bought, previous_price_paid = self.inventory.pop()
            reward = ((eth_df_unscaled["Close"].iloc[t] * previous_eth_bought) * (1 - trading_fee_rate)) - previous_price_paid
            self.portfolio[0] = sum([i[0] for i in self.inventory])  # this takes the first element of each tuple in the inventory list and sums them
            self.portfolio[1] += reward
            self.portfolio[2] = self.portfolio[0] * eth_df_unscaled["Close"].iloc[t] + self.portfolio[1]
        elif action == 4:  # HOLD
            reward = -0.1
        elif action >= 5:  # BUY
            # amount of cash spent accounting for trading fee
            cash_spent = (balance * buy_percentages[action - 5]) * (1 - trading_fee_rate)
            eth_to_buy = cash_spent / eth_df_unscaled["Close"].iloc[t]
            self.inventory.append((eth_to_buy, cash_spent))
            self.portfolio[0] = sum([i[0] for i in self.inventory])  # this takes the first element of each tuple in the inventory list and sums them
            self.portfolio[1] -= cash_spent
            self.portfolio[2] = self.portfolio[0] * eth_df_unscaled["Close"].iloc[t] + self.portfolio[1]

    def get_state(self, t, eth_df):
        num_rows = t - self.window_size + 1
        if num_rows >= 0:
            window = eth_df.iloc[num_rows : t + 1]
        else:
            repeated_first_row = pd.concat([pd.DataFrame(np.repeat(eth_df.iloc[[0]].values, -num_rows, axis=0), columns=eth_df.columns)])
            new_data = eth_df.iloc[0 : t + 1]
            window = pd.concat([repeated_first_row, new_data], ignore_index=True)  # prevents us from sampling data that doesn't exist at the start.
        return window.values

# %%
def get_crypto_data(start_date, end_date, split_date):
    try:
        train = pd.read_csv("Datasets/train_eth.csv", index_col=0)
        test = pd.read_csv("Datasets/test_eth.csv", index_col=0)
    except:
        df = HistoricalData('ETH-USD', 3600, start_date, end_date).retrieve_data()  # 3600 is the interval in seconds which is 1 hour
        split_row = df.index.get_loc(split_date)
        cols = df.columns.tolist()
        df = pd.DataFrame(MinMaxScaler().fit_transform(df), columns=cols)
        train = df[:split_row]
        test = df[split_row:]
        train.to_csv("Datasets/train_eth.csv")
        test.to_csv("Datasets/test_eth.csv")
    return train, test

# %%
def get_crypto_data(start_date, end_date):
    historic_data_df = HistoricalData('ETH-USD', 21600, start_date, end_date).retrieve_data()  # 3600 is the interval in seconds which is 1 hour
    cols = historic_data_df.columns.tolist()
    historic_data_df = pd.DataFrame(MinMaxScaler().fit_transform(historic_data_df), columns=cols)
    historic_data_df.to_csv("Datasets/train_eth.csv")
    return historic_data_df

# %%
# pre-collected data
def get_precollected_data(split_ratio=0.8):
    # try:
    # historic_data = pd.read_csv("Datasets/eth_historical_data_simple.csv", index_col=0)
    historic_data = pd.read_csv("Datasets/eth_combined_hourly_daily.csv", index_col=0)
    print('Pre-collected data loaded successfully.')
    # convert date to datetime if it isn't the index
    if historic_data.index.name != 'Date':
        historic_data['Date'] = pd.to_datetime(historic_data['Date'], infer_datetime_format=True)
        print('Date converted to datetime.')
        # set date as index
        historic_data = historic_data.set_index('Date')
        print('Date set as index.')
    # drop nan values
    historic_data = historic_data.dropna()
    print('NaN values dropped.')
    cols = historic_data.columns.tolist()
    train_unscaled, test_unscaled = train_test_split(historic_data, train_size=split_ratio,shuffle=False)
    train_scaled = pd.DataFrame(MinMaxScaler().fit_transform(train_unscaled), columns=cols)
    test_scaled = pd.DataFrame(MinMaxScaler().fit_transform(test_unscaled), columns=cols)
    print('Data split.')
    # set the index to the date
    train_unscaled = pd.DataFrame(train_unscaled,  columns=cols)
    test_unscaled = pd.DataFrame(test_unscaled,  columns=cols)
    # convert train_unscaled and test_unscaled to df with only the Open, High, Low, and Close column
    train_unscaled = train_unscaled[['Low', 'High', 'Open', 'Close', 'Yesterday_Open', 'Yesterday_High', 'Yesterday_Low', 'Yesterday_Close']]
    test_unscaled = test_unscaled[['Low', 'High', 'Open', 'Close', 'Yesterday_Open', 'Yesterday_High', 'Yesterday_Low', 'Yesterday_Close']]

    train_unscaled.to_csv("Output/train_unscaled.csv")
    train_scaled.to_csv("Output/train_scaled.csv")
    print('Train data saved.')
    test_unscaled.to_csv("Output/test_unscaled.csv")
    test_scaled.to_csv("Output/test_scaled.csv")
    print('Test data saved.')
    return train_scaled, test_scaled, train_unscaled, test_unscaled
        
    # except:
    #     # throw error
    #     print("No pre-collected data found. Please run the data collection script first.")
    #     exit()

# %%
# historic_data = pd.read_csv("Datasets/eth_historical_data_simple.csv", index_col=0)
historic_data = pd.read_csv("Datasets/eth_combined_hourly_daily.csv", index_col=0)
historic_data.head()
# Out:
#                    Low    High    Open   Close       Volume  Yesterday_Open  \
# Date
# 7/20/2019 0:00  220.78  224.49  221.30  221.57  7137.372100        226.6577
# 7/20/2019 1:00  219.98  222.15  221.57  221.06  3254.139090        226.6577
# 7/20/2019 2:00  221.15  226.66  221.16  225.69  4862.143208        226.6577
# 7/20/2019 3:00  225.62  229.00  225.62  227.20  5270.123232        226.6577
# 7/20/2019 4:00  226.56  228.94  227.20  228.36  3139.452682        226.6577
#
#                 Yesterday_High  Yesterday_Low  Yesterday_Close  \
# Date
# 7/20/2019 0:00      226.940475     215.838242        221.33342
# 7/20/2019 1:00      226.940475     215.838242        221.33342
# 7/20/2019 2:00      226.940475     215.838242        221.33342
# 7/20/2019 3:00      226.940475     215.838242        221.33342
# 7/20/2019 4:00      226.940475     215.838242        221.33342
#
#                 Yesterday_Volume  ...  Yesterday_Volume_USDC  \
# Date                              ...
# 7/20/2019 0:00        7606433131  ...            123323972.0
# 7/20/2019 1:00        7606433131  ...            123323972.0
# 7/20/2019 2:00        7606433131  ...            123323972.0
# 7/20/2019 3:00        7606433131  ...            123323972.0
# 7/20/2019 4:00        7606433131  ...            123323972.0
#
#                 Yesterday_VolumeDelta_USDC  Yesterday_7day_Past_Mean_Price  \
# Date
# 7/20/2019 0:00                 -46731557.0                      226.483728
# 7/20/2019 1:00                 -46731557.0                      226.483728
# 7/20/2019 2:00                 -46731557.0                      226.483728
# 7/20/2019 3:00                 -46731557.0                      226.483728
# 7/20/2019 4:00                 -46731557.0                      226.483728
#
#                 Yesterday_Yesterday_Volume  Yesterday_3day_Past_Mean_Volume  \
# Date
# 7/20/2019 0:00                  9327816059                       8773998943
# 7/20/2019 1:00                  9327816059                       8773998943
# 7/20/2019 2:00                  9327816059                       8773998943
# 7/20/2019 3:00                  9327816059                       8773998943
# 7/20/2019 4:00                  9327816059                       8773998943
#
#                 Yesterday_7day_Past_Mean_Volume  Yesterday_Yesterday_Vol_USDT  \
# Date
# 7/20/2019 0:00                       8625351483                  2.660702e+10
# 7/20/2019 1:00                       8625351483                  2.660702e+10
# 7/20/2019 2:00                       8625351483                  2.660702e+10
# 7/20/2019 3:00                       8625351483                  2.660702e+10
# 7/20/2019 4:00                       8625351483                  2.660702e+10
#
#                 Yesterday_3day_Past_Mean_Vol_USDT  \
# Date
# 7/20/2019 0:00                       2.550249e+10
# 7/20/2019 1:00                       2.550249e+10
# 7/20/2019 2:00                       2.550249e+10
# 7/20/2019 3:00                       2.550249e+10
# 7/20/2019 4:00                       2.550249e+10
#
#                 Yesterday_7day_Past_Mean_Vol_USDT  Yesterday_RSI
# Date
# 7/20/2019 0:00                       2.516096e+10      37.863434
# 7/20/2019 1:00                       2.516096e+10      37.863434
# 7/20/2019 2:00                       2.516096e+10      37.863434
# 7/20/2019 3:00                       2.516096e+10      37.863434
# 7/20/2019 4:00                       2.516096e+10      37.863434
#
# [5 rows x 48 columns]

# %%
def main(trading_agent, train_df, test_df, train_close, test_close):

    # # CURRICULUM 1
    episode_mem = [{"Actions": [], "Inventory Size": [], "Portfolio Value": [], "Realized Profit": [], "Reward": [], "Done": [], "Epsilon": [], "MSE Loss": []} for i in range(NUM_EPISODES)]
    # # CURRICULUM 3
    # # episode_mem = [{"Actions": [], "Eth Held": [], "Cash Held": [], "Portfolio Value": [], "Reward": [], "Done": [], "Epsilon": [], "MSE Loss": []} for i in range(NUM_EPISODES)]
    t0 = time()

    # ######################## Training ########################
    for s in range(NUM_EPISODES):
        print(f"\n===== Episode {s + 1} / {NUM_EPISODES} =====")
        trading_agent.inventory = []
        state = trading_agent.get_state(0, train_df)
        balance = INITIAL_INVESTMENT
        # portfolio_value_usd = INITIAL_INVESTMENT
        portfolio_value_usd = 0
        # Reset the agent's portfolio at the beginning of each episode
        trading_agent.portfolio = [0 , INITIAL_INVESTMENT, portfolio_value_usd, 0]

        done = False
        for t in range(len(train_df) - 1):
            if done:
                break

            # CURRICULUM 1
            action = trading_agent.get_action(state)
            next_state = trading_agent.get_state(t + 1, train_df)
            reward = trading_agent.trade(t, action, train_df, train_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
            balance += reward
            done = balance < train_close["Close"].iloc[t]  # if we run out of money to buy, consider the episode "done"
            trading_agent.memory.add_exp(state, action, reward, next_state, done)
            loss = trading_agent.train()

            # # CURRICULUM 2
            # action = trading_agent.get_action(state)
            # next_state = trading_agent.get_state(t + 1, train_df)
            # reward = trading_agent.trade_curriculum_2(t, action, train_df, train_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
            # balance += reward
            # done = balance < train_close["Close"].iloc[t]
            # trading_agent.memory.add_exp(state, action, reward, next_state, done)
            # loss = trading_agent.train()

            # # CURRICULUM 3
            # action = trading_agent.get_action(state)
            # next_state = trading_agent.get_state(t + 1, train_df)
            # reward = trading_agent.trade_curriculum_2(t, action, train_df, train_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
            # balance += reward
            # trading_agent.portfolio[1] = balance
            # eth_held, balance, portfolio_value, maximum_eth_held = trading_agent.portfolio  # update portfolio value
            # if t != 0:  # if not the first trade
            #     done = balance <= 10 and eth_held <= 0.001
            # trading_agent.memory.add_exp(state, action, reward, next_state, done)
            # loss = trading_agent.train()
            
            if not loss:
                loss = 0
            state = next_state
            
            # CURRICULUM 1
            episode_mem[s]["Actions"].append(int(action))
            episode_mem[s]["Inventory Size"].append(len(trading_agent.inventory))
            episode_mem[s]["Portfolio Value"].append(float(balance + train_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)) - INITIAL_INVESTMENT)
            episode_mem[s]["Realized Profit"].append(float(balance - INITIAL_INVESTMENT))
            episode_mem[s]["Reward"].append(float(reward))
            episode_mem[s]["Done"].append(bool(done))
            episode_mem[s]["Epsilon"].append(trading_agent.epsilon)
            episode_mem[s]["MSE Loss"].append(loss)

            # # CURRICULUM 2
            # episode_mem[s]["Actions"].append(int(action))
            # episode_mem[s]["Inventory Size"].append(len(trading_agent.inventory))
            # episode_mem[s]["Portfolio Value"].append(float(balance + train_close["Close"].iloc[t] * sum([i[0] for i in trading_agent.inventory]) - sum([i[1] for i in trading_agent.inventory]) - INITIAL_INVESTMENT))
            # episode_mem[s]["Realized Profit"].append(float(balance - INITIAL_INVESTMENT))
            # episode_mem[s]["Reward"].append(float(reward))
            # episode_mem[s]["Done"].append(bool(done))
            # episode_mem[s]["Epsilon"].append(trading_agent.epsilon)
            # episode_mem[s]["MSE Loss"].append(loss)

            if t % 1 == 0:
                print(f"Time step {t} / {len(train_df)}   |   Portfolio Value: {round(episode_mem[s]['Portfolio Value'][t], 3)}   |   Inventory: {len(trading_agent.inventory)}   |   Action: {int(action)}  |   Reward: {float(reward)}   |   Balance: {round(balance, 2)}   |   Epsilon: {round(trading_agent.epsilon, 3)}   |   Loss: {round(loss, 3)}   |   Done: {done}   |   Time Elapsed: {round(time() - t0, 2)}s")
            
        # if we have leftover inventory at the end of the episode, calculate its value by selling them all at the current market rate
        # CURRICULUM 1
        balance += train_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)
        # CURRICULUM 2
        # balance += train_close["Close"].iloc[t] * sum([i[0] for i in trading_agent.inventory]) - sum([i[1] for i in trading_agent.inventory])


        print(f"Total Profit: {round(balance - INITIAL_INVESTMENT, 2)}")

            # # CURRICULUM 3
            # episode_mem[s]["Actions"].append(int(action))
            # episode_mem[s]["Eth Held"].append(float(eth_held))
            # episode_mem[s]["Cash Held"].append(round(float(balance), 2))
            # episode_mem[s]["Portfolio Value"].append(float(portfolio_value))
            # episode_mem[s]["Reward"].append(float(reward))
            # episode_mem[s]["Done"].append(bool(done))
            # episode_mem[s]["Epsilon"].append(trading_agent.epsilon)
            # episode_mem[s]["MSE Loss"].append(float(loss))

            # if t % 1 == 0:
            #     print(f"Time step {t} / {len(train_df)}   |  Eth: {round(episode_mem[s]['Eth Held'][t], 7)}  |  Cash: {round(episode_mem[s]['Cash Held'][t], 2)}  |  Portfolio Value: {round(episode_mem[s]['Portfolio Value'][t], 3)}  |   MSE: {round(episode_mem[s]['MSE Loss'][t], 3)}  |  Reward: {round(episode_mem[s]['Reward'][t], 3)}  |  Action: {int(episode_mem[s]['Actions'][t])}  |  Epsilon: {round(trading_agent.epsilon, 3)}")

    
    with open('Output/training_scores.out', 'a') as f:
        f.write(f"EPISODE {s} (runtime: {time() - t0})   | Portfolio Value is {round(episode_mem[s]['Portfolio Value'][-1], 3)} Epsilon is {round(trading_agent.epsilon, 3)}   |   MSE Loss is {round(episode_mem[s]['MSE Loss'][-1], 3)}\n")
    # Save the episode memory to a json file, if one exists, add a number to the end of the file name
    episode_mem_file = "Output/episode_mem.json"

    with open(episode_mem_file, 'w') as f:
        json.dump(episode_mem, f)

######################## Testing ########################
    t0 = time()
    # CURRICULUM 1
    testing_mem = {"Actions": [], "Inventory Size": [], "Portfolio Value": [], "Realized Profit": [], "Reward": [], "Done": []}
    # CURRICULUM 3
    # testing_mem = {"Actions": [], "Eth Held": [], "Cash Held": [], "Portfolio Value": [], "Reward": [], "Done": []}
    trading_agent.epsilon = 0
    trading_agent.inventory = [] # inventory reset
    state = trading_agent.get_state(0, test_df)
    balance = INITIAL_INVESTMENT
    # portfolio_value_usd = INITIAL_INVESTMENT
    portfolio_value_usd = 0
    # Reset the agent's portfolio at the beginning of each episode
    trading_agent.portfolio = [0 , INITIAL_INVESTMENT, portfolio_value_usd, 0]
    # Reset the agent's portfolio at the beginning of each episode

    done = False
    for t in range(len(test_df) - 1):
        if done:
            print("Done with testing")
            break

        # CURRICULUM 1
        action = trading_agent.get_action(state)
        next_state = trading_agent.get_state(t + 1, test_df)
        reward = trading_agent.trade(t, action, test_df, test_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
        balance += reward
        done = balance < test_close["Close"].iloc[t]
        state = next_state

        # # CURRICULUM 2
        # action = trading_agent.get_action(state)
        # next_state = trading_agent.get_state(t + 1, test_df)
        # reward = trading_agent.trade_curriculum_2(t, action, test_df, test_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
        # balance += reward
        # done = balance < train_close["Close"].iloc[t]
        # state = next_state


        # CURRICULUM 3
        # action = trading_agent.get_action(state, cash_balance)
        # next_state = trading_agent.get_state(t + 1, test_df)
        # reward = trading_agent.trade(t, action, test_df, test_close, INITIAL_INVESTMENT, trading_fee_rate = 0.05)
        # eth_held, cash_held, new_portfolio_value, max_ether_held_so_far  = trading_agent.portfolio
        # cash_balance = cash_held  # update cash balance
        # portfolio_value_usd = new_portfolio_value  # update portfolio value
        # if t != 0:  # if not the first trade
        #         done = cash_balance <= 10 and eth_held <= 0.001
        # state = next_state

        # CURRICULUM 1
        testing_mem["Actions"].append(int(action))
        testing_mem["Inventory Size"].append(len(trading_agent.inventory))
        testing_mem["Portfolio Value"].append(float(balance + test_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)) - INITIAL_INVESTMENT)
        testing_mem["Realized Profit"].append(float(balance - INITIAL_INVESTMENT))
        testing_mem["Reward"].append(float(reward))
        testing_mem["Done"].append(bool(done))

        # # CURRICULUM 2
        # testing_mem["Actions"].append(int(action))
        # testing_mem["Inventory Size"].append(len(trading_agent.inventory))
        # testing_mem["Portfolio Value"].append(float(balance + train_close["Close"].iloc[t] * sum([i[0] for i in trading_agent.inventory]) - sum([i[1] for i in trading_agent.inventory]) - INITIAL_INVESTMENT))
        # testing_mem["Realized Profit"].append(float(balance - INITIAL_INVESTMENT))
        # testing_mem["Reward"].append(float(reward))
        # testing_mem["Done"].append(bool(done))

        if t % 1 == 0:
            print(f"Time step {t} / {len(test_df)}   |   Inventory Size: {len(trading_agent.inventory)}  |  Portfolio Value: {round(testing_mem['Portfolio Value'][t], 3)}   |  Action: {int(action)}  |  Reward: {round(reward, 3)}")

        # CURRICULUM 3
        # testing_mem["Actions"].append(int(action))
        # testing_mem["Eth Held"].append(float(eth_held))
        # testing_mem["Cash Held"].append(round(float(cash_balance),2))
        # testing_mem["Portfolio Value"].append(float(portfolio_value_usd))
        # testing_mem["Reward"].append(float(reward))
        # testing_mem["Done"].append(bool(done))

        # if t % 1 == 0:
        #     print(f"Time step {t} / {len(test_df)}   |   Eth Held: {round(testing_mem['Eth Held'][t], 7)}  |  Cash Held: {round(testing_mem['Cash Held'][t], 2)}  |  Portfolio Value: {round(testing_mem['Portfolio Value'][t], 3)}   |  Action: {int(action)}  |  Reward: {round(reward, 3)}")
    
    # CURRICULUM 1
    balance += train_close["Close"].iloc[t] * len(trading_agent.inventory) - sum(trading_agent.inventory)
    # CURRICULUM 2
    # balance += train_close["Close"].iloc[t] * sum([i[0] for i in trading_agent.inventory]) - sum([i[1] for i in trading_agent.inventory])

    print(f"Total Profit: {round(balance - INITIAL_INVESTMENT, 2)}")

    with open('Output/testing_scores.out', 'a') as f:
        f.write(f"TESTING (runtime: {time() - t0})   |  Portfolio Value is {round(testing_mem['Portfolio Value'][-1], 3)}\n")

    # save the testing memory to a json file
    testing_mem_file = "Output/testing_mem.json"
    with open(testing_mem_file, 'w') as f:
        json.dump(testing_mem, f)

if __name__ == "__main__":
    
    INITIAL_INVESTMENT = 10000
    NUM_EPISODES = 100
    START_DATE = "2017-01-01-00-00"
    END_DATE = "2020-01-01-00-00"
    TESTING_SPLIT = "2022-01-01-00:00:00" # formatting is different here because of how historic_crypto indexes dataframes

    train_df, test_df, train_close, test_close = get_precollected_data(split_ratio=0.8)
    trading_agent = Agent(train_df.shape, NUM_EPISODES)
    
    # Load the model only once before starting the loop if it exists
    if os.path.exists("Output/online_model/model.pt"):
        print("Loading the model")
        trading_agent.load_model()
    else:
        print("No model found, training from scratch")

    main(trading_agent, train_df, test_df, train_close, test_close)
    trading_agent.save_model()
    print("model saved")
# Out:
# Pre-collected data loaded successfully.
# NaN values dropped.
# Data split.
# Train data saved.
# Test data saved.
# Loading the model
# loaded model from:  Output\online_model
# loaded model from:  Output\target_model
#
# ===== Episode 1 / 100 =====
# Time step 0 / 22923   |   Portfolio Value: 0.0   |   Inventory: 1   |   Action: 6  |   Reward: 0.0   |   Balance: 10000   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.0s
# Time step 1 / 22923   |   Portfolio Value: -0.51   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 10000   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.0s
# Time step 2 / 22923   |   Portfolio Value: 8.75   |   Inventory: 1   |   Action: 2  |   Reward: 4.6299999999999955   |   Balance: 10004.63   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 3 / 22923   |   Portfolio Value: 10.16   |   Inventory: 1   |   Action: 4  |   Reward: -0.1   |   Balance: 10004.53   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 4 / 22923   |   Portfolio Value: 11.32   |   Inventory: 2   |   Action: 5  |   Reward: 0.0   |   Balance: 10004.53   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 5 / 22923   |   Portfolio Value: 9.18   |   Inventory: 3   |   Action: 5  |   Reward: 0.0   |   Balance: 10004.53   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 6 / 22923   |   Portfolio Value: 9.78   |   Inventory: 4   |   Action: 6  |   Reward: 0.0   |   Balance: 10004.53   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 7 / 22923   |   Portfolio Value: 5.9   |   Inventory: 5   |   Action: 8  |   Reward: 0.0   |   Balance: 10004.53   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 8 / 22923   |   Portfolio Value: 1.95   |   Inventory: 4   |   Action: 1  |   Reward: -0.7900000000000205   |   Balance: 10003.74   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 9 / 22923   |   Portfolio Value: 2.55   |   Inventory: 5   |   Action: 7  |   Reward: 0.0   |   Balance: 10003.74   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 10 / 22923   |   Portfolio Value: 4.55   |   Inventory: 4   |   Action: 2  |   Reward: 0.4000000000000057   |   Balance: 10004.14   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.01s
# Time step 11 / 22923   |   Portfolio Value: 2.11   |   Inventory: 5   |   Action: 6  |   Reward: 0.0   |   Balance: 10004.14   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 12 / 22923   |   Portfolio Value: 1.66   |   Inventory: 6   |   Action: 8  |   Reward: 0.0   |   Balance: 10004.14   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 13 / 22923   |   Portfolio Value: 0.88   |   Inventory: 7   |   Action: 6  |   Reward: 0.0   |   Balance: 10004.14   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 14 / 22923   |   Portfolio Value: 14.46   |   Inventory: 8   |   Action: 7  |   Reward: 0.0   |   Balance: 10004.14   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 15 / 22923   |   Portfolio Value: 41.02   |   Inventory: 7   |   Action: 1  |   Reward: 3.3200000000000216   |   Balance: 10007.46   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 16 / 22923   |   Portfolio Value: 71.19   |   Inventory: 8   |   Action: 7  |   Reward: 0.0   |   Balance: 10007.46   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 17 / 22923   |   Portfolio Value: 53.89   |   Inventory: 8   |   Action: 4  |   Reward: -0.1   |   Balance: 10007.36   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 18 / 22923   |   Portfolio Value: 57.55   |   Inventory: 8   |   Action: 4  |   Reward: -0.1   |   Balance: 10007.26   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.02s
# Time step 19 / 22923   |   Portfolio Value: 49.95   |   Inventory: 7   |   Action: 2  |   Reward: -2.630000000000024   |   Balance: 10004.63   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 20 / 22923   |   Portfolio Value: 50.86   |   Inventory: 6   |   Action: 1  |   Reward: 7.070000000000022   |   Balance: 10011.7   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 21 / 22923   |   Portfolio Value: 58.18   |   Inventory: 5   |   Action: 1  |   Reward: 8.159999999999997   |   Balance: 10019.86   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 22 / 22923   |   Portfolio Value: 56.53   |   Inventory: 4   |   Action: 2  |   Reward: 7.740000000000009   |   Balance: 10027.6   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 23 / 22923   |   Portfolio Value: 38.45   |   Inventory: 5   |   Action: 6  |   Reward: 0.0   |   Balance: 10027.6   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 24 / 22923   |   Portfolio Value: 40.7   |   Inventory: 6   |   Action: 7  |   Reward: 0.0   |   Balance: 10027.6   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 25 / 22923   |   Portfolio Value: 36.92   |   Inventory: 5   |   Action: 3  |   Reward: -0.6299999999999955   |   Balance: 10026.97   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 26 / 22923   |   Portfolio Value: 22.02   |   Inventory: 6   |   Action: 6  |   Reward: 0.0   |   Balance: 10026.97   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.03s
# Time step 27 / 22923   |   Portfolio Value: 13.86   |   Inventory: 5   |   Action: 2  |   Reward: -1.3599999999999852   |   Balance: 10025.61   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 28 / 22923   |   Portfolio Value: 23.46   |   Inventory: 6   |   Action: 7  |   Reward: 0.0   |   Balance: 10025.61   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 29 / 22923   |   Portfolio Value: 16.92   |   Inventory: 5   |   Action: 1  |   Reward: -1.0900000000000034   |   Balance: 10024.52   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 30 / 22923   |   Portfolio Value: 16.57   |   Inventory: 4   |   Action: 3  |   Reward: -3.759999999999991   |   Balance: 10020.76   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 31 / 22923   |   Portfolio Value: 19.29   |   Inventory: 3   |   Action: 3  |   Reward: -1.6800000000000068   |   Balance: 10019.08   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 32 / 22923   |   Portfolio Value: 23.61   |   Inventory: 2   |   Action: 2  |   Reward: -0.03999999999999204   |   Balance: 10019.04   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 33 / 22923   |   Portfolio Value: 24.05   |   Inventory: 3   |   Action: 7  |   Reward: 0.0   |   Balance: 10019.04   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 34 / 22923   |   Portfolio Value: 17.84   |   Inventory: 2   |   Action: 0  |   Reward: -2.069999999999993   |   Balance: 10016.97   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 35 / 22923   |   Portfolio Value: 18.84   |   Inventory: 1   |   Action: 1  |   Reward: -2.460000000000008   |   Balance: 10014.51   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 36 / 22923   |   Portfolio Value: 16.68   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 10014.51   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 37 / 22923   |   Portfolio Value: 14.66   |   Inventory: 1   |   Action: 0  |   Reward: -1.0100000000000193   |   Balance: 10013.5   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 38 / 22923   |   Portfolio Value: 13.41   |   Inventory: 0   |   Action: 0  |   Reward: -0.09000000000000341   |   Balance: 10013.41   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 39 / 22923   |   Portfolio Value: 13.41   |   Inventory: 1   |   Action: 6  |   Reward: 0.0   |   Balance: 10013.41   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 40 / 22923   |   Portfolio Value: 11.74   |   Inventory: 0   |   Action: 0  |   Reward: -1.670000000000016   |   Balance: 10011.74   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 41 / 22923   |   Portfolio Value: 11.74   |   Inventory: 1   |   Action: 8  |   Reward: 0.0   |   Balance: 10011.74   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 42 / 22923   |   Portfolio Value: 14.33   |   Inventory: 2   |   Action: 5  |   Reward: 0.0   |   Balance: 10011.74   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 43 / 22923   |   Portfolio Value: 10.23   |   Inventory: 2   |   Action: 4  |   Reward: -0.1   |   Balance: 10011.64   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 44 / 22923   |   Portfolio Value: 17.07   |   Inventory: 1   |   Action: 0  |   Reward: 1.4199999999999875   |   Balance: 10013.06   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.04s
# Time step 45 / 22923   |   Portfolio Value: 18.73   |   Inventory: 2   |   Action: 8  |   Reward: 0.0   |   Balance: 10013.06   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 46 / 22923   |   Portfolio Value: 19.33   |   Inventory: 1   |   Action: 3  |   Reward: 0.30000000000001137   |   Balance: 10013.36   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 47 / 22923   |   Portfolio Value: 19.59   |   Inventory: 1   |   Action: 4  |   Reward: -0.1   |   Balance: 10013.26   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 48 / 22923   |   Portfolio Value: 18.9   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 10013.26   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 49 / 22923   |   Portfolio Value: 18.56   |   Inventory: 1   |   Action: 1  |   Reward: -0.1699999999999875   |   Balance: 10013.09   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 50 / 22923   |   Portfolio Value: 20.79   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 10013.09   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 51 / 22923   |   Portfolio Value: 19.01   |   Inventory: 3   |   Action: 7  |   Reward: 0.0   |   Balance: 10013.09   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 52 / 22923   |   Portfolio Value: 14.9   |   Inventory: 2   |   Action: 0  |   Reward: -1.3700000000000045   |   Balance: 10011.72   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 53 / 22923   |   Portfolio Value: 16.32   |   Inventory: 2   |   Action: 4  |   Reward: -0.1   |   Balance: 10011.62   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 54 / 22923   |   Portfolio Value: 15.98   |   Inventory: 2   |   Action: 4  |   Reward: -0.1   |   Balance: 10011.52   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 55 / 22923   |   Portfolio Value: 15.52   |   Inventory: 3   |   Action: 6  |   Reward: 0.0   |   Balance: 10011.52   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 56 / 22923   |   Portfolio Value: 11.68   |   Inventory: 2   |   Action: 3  |   Reward: -1.2800000000000011   |   Balance: 10010.24   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 57 / 22923   |   Portfolio Value: 4.92   |   Inventory: 3   |   Action: 8  |   Reward: 0.0   |   Balance: 10010.24   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 58 / 22923   |   Portfolio Value: 9.09   |   Inventory: 2   |   Action: 2  |   Reward: 1.3899999999999864   |   Balance: 10011.63   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 59 / 22923   |   Portfolio Value: 11.57   |   Inventory: 1   |   Action: 1  |   Reward: -3.8799999999999955   |   Balance: 10007.75   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 60 / 22923   |   Portfolio Value: 10.83   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 10007.75   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 61 / 22923   |   Portfolio Value: 7.25   |   Inventory: 3   |   Action: 7  |   Reward: 0.0   |   Balance: 10007.75   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# Time step 62 / 22923   |   Portfolio Value: -8.41   |   Inventory: 4   |   Action: 6  |   Reward: 0.0   |   Balance: 10007.75   |   Epsilon: 1.0   |   Loss: 0   |   Done: False   |   Time Elapsed: 0.05s
# c:\Users\ericb\anaconda3\envs\ML_Torch\lib\site-packages\ipykernel_launcher.py:92: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
# Time step 63 / 22923   |   Portfolio Value: -12.53   |   Inventory: 3   |   Action: 2  |   Reward: -1.0300000000000011   |   Balance: 10006.72   |   Epsilon: 1.0   |   Loss: 260.202   |   Done: False   |   Time Elapsed: 0.9s
# Time step 64 / 22923   |   Portfolio Value: -12.8   |   Inventory: 2   |   Action: 1  |   Reward: -6.340000000000003   |   Balance: 10000.38   |   Epsilon: 1.0   |   Loss: 166.447   |   Done: False   |   Time Elapsed: 0.93s
# Time step 65 / 22923   |   Portfolio Value: -9.32   |   Inventory: 3   |   Action: 6  |   Reward: 0.0   |   Balance: 10000.38   |   Epsilon: 1.0   |   Loss: 121.844   |   Done: False   |   Time Elapsed: 0.95s
# Time step 66 / 22923   |   Portfolio Value: -9.74   |   Inventory: 4   |   Action: 7  |   Reward: 0.0   |   Balance: 10000.38   |   Epsilon: 1.0   |   Loss: 175.379   |   Done: False   |   Time Elapsed: 0.97s
# Time step 67 / 22923   |   Portfolio Value: -20.58   |   Inventory: 3   |   Action: 3  |   Reward: -2.710000000000008   |   Balance: 9997.67   |   Epsilon: 1.0   |   Loss: 147.705   |   Done: False   |   Time Elapsed: 0.99s
# Time step 68 / 22923   |   Portfolio Value: -5.43   |   Inventory: 2   |   Action: 2  |   Reward: 2.1999999999999886   |   Balance: 9999.87   |   Epsilon: 1.0   |   Loss: 139.019   |   Done: False   |   Time Elapsed: 1.01s
# Time step 69 / 22923   |   Portfolio Value: -9.15   |   Inventory: 2   |   Action: 4  |   Reward: -0.1   |   Balance: 9999.77   |   Epsilon: 1.0   |   Loss: 101.303   |   Done: False   |   Time Elapsed: 1.03s
# Time step 70 / 22923   |   Portfolio Value: -10.15   |   Inventory: 1   |   Action: 0  |   Reward: -6.5   |   Balance: 9993.27   |   Epsilon: 1.0   |   Loss: 77.605   |   Done: False   |   Time Elapsed: 1.05s
# Time step 71 / 22923   |   Portfolio Value: -9.01   |   Inventory: 1   |   Action: 4  |   Reward: -0.1   |   Balance: 9993.17   |   Epsilon: 1.0   |   Loss: 55.902   |   Done: False   |   Time Elapsed: 1.08s
# Time step 72 / 22923   |   Portfolio Value: -10.89   |   Inventory: 0   |   Action: 3  |   Reward: -4.060000000000002   |   Balance: 9989.11   |   Epsilon: 1.0   |   Loss: 75.163   |   Done: False   |   Time Elapsed: 1.1s
# Time step 73 / 22923   |   Portfolio Value: -10.89   |   Inventory: 1   |   Action: 6  |   Reward: 0.0   |   Balance: 9989.11   |   Epsilon: 1.0   |   Loss: 100.097   |   Done: False   |   Time Elapsed: 1.12s
# Time step 74 / 22923   |   Portfolio Value: -8.94   |   Inventory: 1   |   Action: 4  |   Reward: -0.1   |   Balance: 9989.01   |   Epsilon: 1.0   |   Loss: 90.283   |   Done: False   |   Time Elapsed: 1.14s
# Time step 75 / 22923   |   Portfolio Value: -9.67   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 9989.01   |   Epsilon: 1.0   |   Loss: 36.163   |   Done: False   |   Time Elapsed: 1.16s
# Time step 76 / 22923   |   Portfolio Value: -9.61   |   Inventory: 3   |   Action: 6  |   Reward: 0.0   |   Balance: 9989.01   |   Epsilon: 1.0   |   Loss: 64.253   |   Done: False   |   Time Elapsed: 1.18s
# Time step 77 / 22923   |   Portfolio Value: -15.01   |   Inventory: 4   |   Action: 5  |   Reward: 0.0   |   Balance: 9989.01   |   Epsilon: 1.0   |   Loss: 30.906   |   Done: False   |   Time Elapsed: 1.21s
# Time step 78 / 22923   |   Portfolio Value: -25.33   |   Inventory: 5   |   Action: 8  |   Reward: 0.0   |   Balance: 9989.01   |   Epsilon: 1.0   |   Loss: 53.409   |   Done: False   |   Time Elapsed: 1.23s
# Time step 79 / 22923   |   Portfolio Value: -24.83   |   Inventory: 4   |   Action: 2  |   Reward: 0.09999999999999432   |   Balance: 9989.11   |   Epsilon: 1.0   |   Loss: 31.982   |   Done: False   |   Time Elapsed: 1.26s
# Time step 80 / 22923   |   Portfolio Value: -31.13   |   Inventory: 4   |   Action: 4  |   Reward: -0.1   |   Balance: 9989.01   |   Epsilon: 1.0   |   Loss: 24.688   |   Done: False   |   Time Elapsed: 1.28s
# Time step 81 / 22923   |   Portfolio Value: -32.45   |   Inventory: 3   |   Action: 0  |   Reward: -4.359999999999985   |   Balance: 9984.65   |   Epsilon: 1.0   |   Loss: 31.578   |   Done: False   |   Time Elapsed: 1.3s
# Time step 82 / 22923   |   Portfolio Value: -27.86   |   Inventory: 4   |   Action: 7  |   Reward: 0.0   |   Balance: 9984.65   |   Epsilon: 1.0   |   Loss: 48.347   |   Done: False   |   Time Elapsed: 1.32s
# Time step 83 / 22923   |   Portfolio Value: -26.22   |   Inventory: 3   |   Action: 1  |   Reward: 0.4099999999999966   |   Balance: 9985.06   |   Epsilon: 1.0   |   Loss: 26.307   |   Done: False   |   Time Elapsed: 1.35s
# Time step 84 / 22923   |   Portfolio Value: -27.0   |   Inventory: 2   |   Action: 3  |   Reward: -4.47999999999999   |   Balance: 9980.58   |   Epsilon: 1.0   |   Loss: 19.68   |   Done: False   |   Time Elapsed: 1.37s
# Time step 85 / 22923   |   Portfolio Value: -29.34   |   Inventory: 1   |   Action: 2  |   Reward: -5.6200000000000045   |   Balance: 9974.96   |   Epsilon: 1.0   |   Loss: 40.186   |   Done: False   |   Time Elapsed: 1.39s
# Time step 86 / 22923   |   Portfolio Value: -28.61   |   Inventory: 0   |   Action: 2  |   Reward: -3.5700000000000216   |   Balance: 9971.39   |   Epsilon: 1.0   |   Loss: 51.965   |   Done: False   |   Time Elapsed: 1.41s
# Time step 87 / 22923   |   Portfolio Value: -28.61   |   Inventory: 1   |   Action: 5  |   Reward: 0.0   |   Balance: 9971.39   |   Epsilon: 1.0   |   Loss: 57.075   |   Done: False   |   Time Elapsed: 1.44s
# Time step 88 / 22923   |   Portfolio Value: -26.92   |   Inventory: 0   |   Action: 0  |   Reward: 1.6899999999999977   |   Balance: 9973.08   |   Epsilon: 1.0   |   Loss: 42.191   |   Done: False   |   Time Elapsed: 1.47s
# Time step 89 / 22923   |   Portfolio Value: -26.92   |   Inventory: 1   |   Action: 6  |   Reward: 0.0   |   Balance: 9973.08   |   Epsilon: 1.0   |   Loss: 46.075   |   Done: False   |   Time Elapsed: 1.49s
# Time step 90 / 22923   |   Portfolio Value: -22.01   |   Inventory: 0   |   Action: 3  |   Reward: 4.910000000000025   |   Balance: 9977.99   |   Epsilon: 1.0   |   Loss: 30.709   |   Done: False   |   Time Elapsed: 1.51s
# Time step 91 / 22923   |   Portfolio Value: -22.01   |   Inventory: 1   |   Action: 8  |   Reward: 0.0   |   Balance: 9977.99   |   Epsilon: 1.0   |   Loss: 20.785   |   Done: False   |   Time Elapsed: 1.53s
# Time step 92 / 22923   |   Portfolio Value: -21.27   |   Inventory: 1   |   Action: 4  |   Reward: -0.1   |   Balance: 9977.89   |   Epsilon: 1.0   |   Loss: 79.906   |   Done: False   |   Time Elapsed: 1.55s
# Time step 93 / 22923   |   Portfolio Value: -21.99   |   Inventory: 0   |   Action: 1  |   Reward: 0.12000000000000455   |   Balance: 9978.01   |   Epsilon: 1.0   |   Loss: 31.183   |   Done: False   |   Time Elapsed: 1.58s
# Time step 94 / 22923   |   Portfolio Value: -22.09   |   Inventory: 0   |   Action: 4  |   Reward: -0.1   |   Balance: 9977.91   |   Epsilon: 1.0   |   Loss: 15.068   |   Done: False   |   Time Elapsed: 1.6s
# Time step 95 / 22923   |   Portfolio Value: -22.19   |   Inventory: 0   |   Action: 4  |   Reward: -0.1   |   Balance: 9977.81   |   Epsilon: 1.0   |   Loss: 46.696   |   Done: False   |   Time Elapsed: 1.62s
# Time step 96 / 22923   |   Portfolio Value: -22.19   |   Inventory: 1   |   Action: 6  |   Reward: 0.0   |   Balance: 9977.81   |   Epsilon: 1.0   |   Loss: 50.102   |   Done: False   |   Time Elapsed: 1.64s
# Time step 97 / 22923   |   Portfolio Value: -22.18   |   Inventory: 2   |   Action: 7  |   Reward: 0.0   |   Balance: 9977.81   |   Epsilon: 1.0   |   Loss: 31.384   |   Done: False   |   Time Elapsed: 1.66s
# Time step 98 / 22923   |   Portfolio Value: -22.32   |   Inventory: 1   |   Action: 2  |   Reward: -0.06999999999999318   |   Balance: 9977.74   |   Epsilon: 1.0   |   Loss: 51.117   |   Done: False   |   Time Elapsed: 1.68s
# Time step 99 / 22923   |   Portfolio Value: -23.22   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 9977.74   |   Epsilon: 1.0   |   Loss: 34.622   |   Done: False   |   Time Elapsed: 1.7s
# Time step 100 / 22923   |   Portfolio Value: -22.5   |   Inventory: 3   |   Action: 6  |   Reward: 0.0   |   Balance: 9977.74   |   Epsilon: 1.0   |   Loss: 24.505   |   Done: False   |   Time Elapsed: 1.72s
# Time step 101 / 22923   |   Portfolio Value: -19.65   |   Inventory: 2   |   Action: 2  |   Reward: 0.9499999999999886   |   Balance: 9978.69   |   Epsilon: 1.0   |   Loss: 32.418   |   Done: False   |   Time Elapsed: 1.75s
# Time step 102 / 22923   |   Portfolio Value: -19.77   |   Inventory: 3   |   Action: 7  |   Reward: 0.0   |   Balance: 9978.69   |   Epsilon: 1.0   |   Loss: 54.086   |   Done: False   |   Time Elapsed: 1.77s
# Time step 103 / 22923   |   Portfolio Value: -18.87   |   Inventory: 2   |   Action: 1  |   Reward: 0.30000000000001137   |   Balance: 9978.99   |   Epsilon: 1.0   |   Loss: 43.855   |   Done: False   |   Time Elapsed: 1.79s
# Time step 104 / 22923   |   Portfolio Value: -15.57   |   Inventory: 1   |   Action: 0  |   Reward: 3.1999999999999886   |   Balance: 9982.19   |   Epsilon: 1.0   |   Loss: 23.916   |   Done: False   |   Time Elapsed: 1.81s
# Time step 105 / 22923   |   Portfolio Value: -14.78   |   Inventory: 1   |   Action: 4  |   Reward: -0.1   |   Balance: 9982.09   |   Epsilon: 1.0   |   Loss: 36.481   |   Done: False   |   Time Elapsed: 1.83s
# Time step 106 / 22923   |   Portfolio Value: -15.84   |   Inventory: 2   |   Action: 8  |   Reward: 0.0   |   Balance: 9982.09   |   Epsilon: 1.0   |   Loss: 19.395   |   Done: False   |   Time Elapsed: 1.85s
# Time step 107 / 22923   |   Portfolio Value: -15.98   |   Inventory: 1   |   Action: 1  |   Reward: -0.06999999999999318   |   Balance: 9982.02   |   Epsilon: 1.0   |   Loss: 34.822   |   Done: False   |   Time Elapsed: 1.88s
# Time step 108 / 22923   |   Portfolio Value: -15.49   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 9982.02   |   Epsilon: 1.0   |   Loss: 23.381   |   Done: False   |   Time Elapsed: 1.9s
# Time step 109 / 22923   |   Portfolio Value: -15.37   |   Inventory: 3   |   Action: 7  |   Reward: 0.0   |   Balance: 9982.02   |   Epsilon: 1.0   |   Loss: 23.027   |   Done: False   |   Time Elapsed: 1.92s
# Time step 110 / 22923   |   Portfolio Value: 3.02   |   Inventory: 4   |   Action: 7  |   Reward: 0.0   |   Balance: 9982.02   |   Epsilon: 1.0   |   Loss: 27.714   |   Done: False   |   Time Elapsed: 1.94s
# Time step 111 / 22923   |   Portfolio Value: 12.12   |   Inventory: 4   |   Action: 4  |   Reward: -0.1   |   Balance: 9981.92   |   Epsilon: 1.0   |   Loss: 43.36   |   Done: False   |   Time Elapsed: 1.96s
# Time step 112 / 22923   |   Portfolio Value: -16.08   |   Inventory: 3   |   Action: 3  |   Reward: -4.75   |   Balance: 9977.17   |   Epsilon: 1.0   |   Loss: 37.054   |   Done: False   |   Time Elapsed: 1.98s
# Time step 113 / 22923   |   Portfolio Value: -11.04   |   Inventory: 2   |   Action: 0  |   Reward: 3.0600000000000023   |   Balance: 9980.23   |   Epsilon: 1.0   |   Loss: 27.353   |   Done: False   |   Time Elapsed: 2.0s
# Time step 114 / 22923   |   Portfolio Value: -11.22   |   Inventory: 1   |   Action: 2  |   Reward: 3.030000000000001   |   Balance: 9983.26   |   Epsilon: 1.0   |   Loss: 43.323   |   Done: False   |   Time Elapsed: 2.02s
# Time step 115 / 22923   |   Portfolio Value: -10.35   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 9983.26   |   Epsilon: 1.0   |   Loss: 148.93   |   Done: False   |   Time Elapsed: 2.04s
# Time step 116 / 22923   |   Portfolio Value: -2.85   |   Inventory: 2   |   Action: 4  |   Reward: -0.1   |   Balance: 9983.16   |   Epsilon: 1.0   |   Loss: 103.069   |   Done: False   |   Time Elapsed: 2.06s
# Time step 117 / 22923   |   Portfolio Value: -0.77   |   Inventory: 3   |   Action: 5  |   Reward: 0.0   |   Balance: 9983.16   |   Epsilon: 1.0   |   Loss: 83.79   |   Done: False   |   Time Elapsed: 2.09s
# Time step 118 / 22923   |   Portfolio Value: -6.29   |   Inventory: 2   |   Action: 1  |   Reward: -1.8400000000000034   |   Balance: 9981.32   |   Epsilon: 1.0   |   Loss: 12.312   |   Done: False   |   Time Elapsed: 2.11s
# Time step 119 / 22923   |   Portfolio Value: -2.19   |   Inventory: 3   |   Action: 5  |   Reward: 0.0   |   Balance: 9981.32   |   Epsilon: 1.0   |   Loss: 23.671   |   Done: False   |   Time Elapsed: 2.13s
# Time step 120 / 22923   |   Portfolio Value: 16.41   |   Inventory: 4   |   Action: 6  |   Reward: 0.0   |   Balance: 9981.32   |   Epsilon: 1.0   |   Loss: 57.012   |   Done: False   |   Time Elapsed: 2.15s
# Time step 121 / 22923   |   Portfolio Value: 17.29   |   Inventory: 3   |   Action: 0  |   Reward: 0.21999999999999886   |   Balance: 9981.54   |   Epsilon: 1.0   |   Loss: 52.48   |   Done: False   |   Time Elapsed: 2.17s
# Time step 122 / 22923   |   Portfolio Value: 17.16   |   Inventory: 3   |   Action: 4  |   Reward: -0.1   |   Balance: 9981.44   |   Epsilon: 1.0   |   Loss: 27.282   |   Done: False   |   Time Elapsed: 2.19s
# Time step 123 / 22923   |   Portfolio Value: 15.75   |   Inventory: 2   |   Action: 2  |   Reward: 5.939999999999998   |   Balance: 9987.38   |   Epsilon: 1.0   |   Loss: 69.741   |   Done: False   |   Time Elapsed: 2.22s
# Time step 124 / 22923   |   Portfolio Value: 13.45   |   Inventory: 3   |   Action: 5  |   Reward: 0.0   |   Balance: 9987.38   |   Epsilon: 1.0   |   Loss: 25.847   |   Done: False   |   Time Elapsed: 2.24s
# Time step 125 / 22923   |   Portfolio Value: 15.19   |   Inventory: 4   |   Action: 8  |   Reward: 0.0   |   Balance: 9987.38   |   Epsilon: 1.0   |   Loss: 21.276   |   Done: False   |   Time Elapsed: 2.26s
# Time step 126 / 22923   |   Portfolio Value: 16.55   |   Inventory: 3   |   Action: 0  |   Reward: 0.3400000000000034   |   Balance: 9987.72   |   Epsilon: 1.0   |   Loss: 71.846   |   Done: False   |   Time Elapsed: 2.28s
# Time step 127 / 22923   |   Portfolio Value: 13.19   |   Inventory: 4   |   Action: 8  |   Reward: 0.0   |   Balance: 9987.72   |   Epsilon: 1.0   |   Loss: 52.206   |   Done: False   |   Time Elapsed: 2.3s
# Time step 128 / 22923   |   Portfolio Value: 17.11   |   Inventory: 5   |   Action: 6  |   Reward: 0.0   |   Balance: 9987.72   |   Epsilon: 1.0   |   Loss: 39.85   |   Done: False   |   Time Elapsed: 2.32s
# Time step 129 / 22923   |   Portfolio Value: 19.16   |   Inventory: 4   |   Action: 1  |   Reward: 0.4099999999999966   |   Balance: 9988.13   |   Epsilon: 1.0   |   Loss: 32.797   |   Done: False   |   Time Elapsed: 2.34s
# Time step 130 / 22923   |   Portfolio Value: 19.76   |   Inventory: 5   |   Action: 8  |   Reward: 0.0   |   Balance: 9988.13   |   Epsilon: 1.0   |   Loss: 37.052   |   Done: False   |   Time Elapsed: 2.36s
# Time step 131 / 22923   |   Portfolio Value: 20.21   |   Inventory: 4   |   Action: 2  |   Reward: 0.09000000000000341   |   Balance: 9988.22   |   Epsilon: 1.0   |   Loss: 15.981   |   Done: False   |   Time Elapsed: 2.38s
# Time step 132 / 22923   |   Portfolio Value: 27.09   |   Inventory: 3   |   Action: 1  |   Reward: 3.3499999999999943   |   Balance: 9991.57   |   Epsilon: 1.0   |   Loss: 23.479   |   Done: False   |   Time Elapsed: 2.4s
# Time step 133 / 22923   |   Portfolio Value: 13.83   |   Inventory: 2   |   Action: 1  |   Reward: -1.2699999999999818   |   Balance: 9990.3   |   Epsilon: 1.0   |   Loss: 23.226   |   Done: False   |   Time Elapsed: 2.43s
# Time step 134 / 22923   |   Portfolio Value: 15.53   |   Inventory: 3   |   Action: 7  |   Reward: 0.0   |   Balance: 9990.3   |   Epsilon: 1.0   |   Loss: 68.832   |   Done: False   |   Time Elapsed: 2.45s
# Time step 135 / 22923   |   Portfolio Value: 16.1   |   Inventory: 4   |   Action: 5  |   Reward: 0.0   |   Balance: 9990.3   |   Epsilon: 1.0   |   Loss: 57.082   |   Done: False   |   Time Elapsed: 2.47s
# Time step 136 / 22923   |   Portfolio Value: 16.9   |   Inventory: 5   |   Action: 7  |   Reward: 0.0   |   Balance: 9990.3   |   Epsilon: 1.0   |   Loss: 30.998   |   Done: False   |   Time Elapsed: 2.49s
# Time step 137 / 22923   |   Portfolio Value: 19.65   |   Inventory: 4   |   Action: 0  |   Reward: 0.5500000000000114   |   Balance: 9990.85   |   Epsilon: 1.0   |   Loss: 8.338   |   Done: False   |   Time Elapsed: 2.51s
# Time step 138 / 22923   |   Portfolio Value: 16.69   |   Inventory: 3   |   Action: 0  |   Reward: 0.009999999999990905   |   Balance: 9990.86   |   Epsilon: 1.0   |   Loss: 20.557   |   Done: False   |   Time Elapsed: 2.54s
# Time step 139 / 22923   |   Portfolio Value: 7.96   |   Inventory: 4   |   Action: 7  |   Reward: 0.0   |   Balance: 9990.86   |   Epsilon: 1.0   |   Loss: 22.126   |   Done: False   |   Time Elapsed: 2.56s
# Time step 140 / 22923   |   Portfolio Value: 9.64   |   Inventory: 5   |   Action: 8  |   Reward: 0.0   |   Balance: 9990.86   |   Epsilon: 1.0   |   Loss: 25.639   |   Done: False   |   Time Elapsed: 2.58s
# Time step 141 / 22923   |   Portfolio Value: 12.59   |   Inventory: 4   |   Action: 3  |   Reward: 0.5900000000000034   |   Balance: 9991.45   |   Epsilon: 1.0   |   Loss: 51.747   |   Done: False   |   Time Elapsed: 2.6s
# Time step 142 / 22923   |   Portfolio Value: 15.31   |   Inventory: 5   |   Action: 5  |   Reward: 0.0   |   Balance: 9991.45   |   Epsilon: 1.0   |   Loss: 24.493   |   Done: False   |   Time Elapsed: 2.62s
# Time step 143 / 22923   |   Portfolio Value: 12.01   |   Inventory: 6   |   Action: 7  |   Reward: 0.0   |   Balance: 9991.45   |   Epsilon: 1.0   |   Loss: 17.75   |   Done: False   |   Time Elapsed: 2.65s
# Time step 144 / 22923   |   Portfolio Value: -4.67   |   Inventory: 5   |   Action: 3  |   Reward: -2.780000000000001   |   Balance: 9988.67   |   Epsilon: 1.0   |   Loss: 63.405   |   Done: False   |   Time Elapsed: 2.67s
# Time step 145 / 22923   |   Portfolio Value: -14.42   |   Inventory: 6   |   Action: 6  |   Reward: 0.0   |   Balance: 9988.67   |   Epsilon: 1.0   |   Loss: 16.879   |   Done: False   |   Time Elapsed: 2.69s
# Time step 146 / 22923   |   Portfolio Value: -16.16   |   Inventory: 7   |   Action: 7  |   Reward: 0.0   |   Balance: 9988.67   |   Epsilon: 1.0   |   Loss: 37.776   |   Done: False   |   Time Elapsed: 2.71s
# Time step 147 / 22923   |   Portfolio Value: -11.08   |   Inventory: 7   |   Action: 4  |   Reward: -0.1   |   Balance: 9988.57   |   Epsilon: 1.0   |   Loss: 21.581   |   Done: False   |   Time Elapsed: 2.73s
# Time step 148 / 22923   |   Portfolio Value: -8.91   |   Inventory: 6   |   Action: 3  |   Reward: 1.0500000000000114   |   Balance: 9989.62   |   Epsilon: 1.0   |   Loss: 11.04   |   Done: False   |   Time Elapsed: 2.76s
# Time step 149 / 22923   |   Portfolio Value: -8.31   |   Inventory: 7   |   Action: 5  |   Reward: 0.0   |   Balance: 9989.62   |   Epsilon: 1.0   |   Loss: 26.409   |   Done: False   |   Time Elapsed: 2.78s
# Time step 150 / 22923   |   Portfolio Value: -19.09   |   Inventory: 8   |   Action: 8  |   Reward: 0.0   |   Balance: 9989.62   |   Epsilon: 1.0   |   Loss: 19.453   |   Done: False   |   Time Elapsed: 2.8s
# Time step 151 / 22923   |   Portfolio Value: 0.43   |   Inventory: 7   |   Action: 3  |   Reward: 2.4399999999999977   |   Balance: 9992.06   |   Epsilon: 1.0   |   Loss: 30.66   |   Done: False   |   Time Elapsed: 2.82s
# Time step 152 / 22923   |   Portfolio Value: 5.26   |   Inventory: 6   |   Action: 1  |   Reward: 1.5900000000000034   |   Balance: 9993.65   |   Epsilon: 1.0   |   Loss: 26.166   |   Done: False   |   Time Elapsed: 2.84s
# Time step 153 / 22923   |   Portfolio Value: 3.4   |   Inventory: 7   |   Action: 7  |   Reward: 0.0   |   Balance: 9993.65   |   Epsilon: 1.0   |   Loss: 53.647   |   Done: False   |   Time Elapsed: 2.86s
# Time step 154 / 22923   |   Portfolio Value: 5.92   |   Inventory: 8   |   Action: 8  |   Reward: 0.0   |   Balance: 9993.65   |   Epsilon: 1.0   |   Loss: 15.299   |   Done: False   |   Time Elapsed: 2.88s
# Time step 155 / 22923   |   Portfolio Value: 8.72   |   Inventory: 9   |   Action: 8  |   Reward: 0.0   |   Balance: 9993.65   |   Epsilon: 1.0   |   Loss: 15.814   |   Done: False   |   Time Elapsed: 2.9s
# Time step 156 / 22923   |   Portfolio Value: -4.61   |   Inventory: 9   |   Action: 4  |   Reward: -0.1   |   Balance: 9993.55   |   Epsilon: 1.0   |   Loss: 22.679   |   Done: False   |   Time Elapsed: 2.92s
# Time step 157 / 22923   |   Portfolio Value: 0.33   |   Inventory: 9   |   Action: 4  |   Reward: -0.1   |   Balance: 9993.45   |   Epsilon: 1.0   |   Loss: 30.589   |   Done: False   |   Time Elapsed: 2.94s
# Time step 158 / 22923   |   Portfolio Value: -5.61   |   Inventory: 8   |   Action: 0  |   Reward: -1.5699999999999932   |   Balance: 9991.88   |   Epsilon: 1.0   |   Loss: 14.989   |   Done: False   |   Time Elapsed: 2.96s
# Time step 159 / 22923   |   Portfolio Value: 0.23   |   Inventory: 9   |   Action: 7  |   Reward: 0.0   |   Balance: 9991.88   |   Epsilon: 1.0   |   Loss: 15.735   |   Done: False   |   Time Elapsed: 2.99s
# Time step 160 / 22923   |   Portfolio Value: 24.35   |   Inventory: 8   |   Action: 1  |   Reward: 2.680000000000007   |   Balance: 9994.56   |   Epsilon: 1.0   |   Loss: 33.613   |   Done: False   |   Time Elapsed: 3.01s
# Time step 161 / 22923   |   Portfolio Value: 21.77   |   Inventory: 8   |   Action: 4  |   Reward: -0.1   |   Balance: 9994.46   |   Epsilon: 1.0   |   Loss: 14.282   |   Done: False   |   Time Elapsed: 3.03s
# Time step 162 / 22923   |   Portfolio Value: 25.37   |   Inventory: 7   |   Action: 0  |   Reward: 2.329999999999984   |   Balance: 9996.79   |   Epsilon: 1.0   |   Loss: 32.751   |   Done: False   |   Time Elapsed: 3.05s
# Time step 163 / 22923   |   Portfolio Value: 29.5   |   Inventory: 8   |   Action: 6  |   Reward: 0.0   |   Balance: 9996.79   |   Epsilon: 1.0   |   Loss: 34.382   |   Done: False   |   Time Elapsed: 3.07s
# Time step 164 / 22923   |   Portfolio Value: 16.54   |   Inventory: 9   |   Action: 5  |   Reward: 0.0   |   Balance: 9996.79   |   Epsilon: 1.0   |   Loss: 18.701   |   Done: False   |   Time Elapsed: 3.09s
# Time step 165 / 22923   |   Portfolio Value: 18.16   |   Inventory: 10   |   Action: 5  |   Reward: 0.0   |   Balance: 9996.79   |   Epsilon: 1.0   |   Loss: 66.804   |   Done: False   |   Time Elapsed: 3.11s
# Time step 166 / 22923   |   Portfolio Value: 12.26   |   Inventory: 9   |   Action: 3  |   Reward: -0.5900000000000034   |   Balance: 9996.2   |   Epsilon: 1.0   |   Loss: 20.593   |   Done: False   |   Time Elapsed: 3.13s
# Time step 167 / 22923   |   Portfolio Value: 24.95   |   Inventory: 10   |   Action: 6  |   Reward: 0.0   |   Balance: 9996.2   |   Epsilon: 1.0   |   Loss: 27.259   |   Done: False   |   Time Elapsed: 3.15s
# Time step 168 / 22923   |   Portfolio Value: 64.65   |   Inventory: 9   |   Action: 3  |   Reward: 3.969999999999999   |   Balance: 10000.17   |   Epsilon: 1.0   |   Loss: 37.133   |   Done: False   |   Time Elapsed: 3.17s
# Time step 169 / 22923   |   Portfolio Value: 52.68   |   Inventory: 8   |   Action: 1  |   Reward: 3.640000000000015   |   Balance: 10003.81   |   Epsilon: 1.0   |   Loss: 14.38   |   Done: False   |   Time Elapsed: 3.2s
# Time step 170 / 22923   |   Portfolio Value: 63.32   |   Inventory: 7   |   Action: 0  |   Reward: 3.3499999999999943   |   Balance: 10007.16   |   Epsilon: 1.0   |   Loss: 37.779   |   Done: False   |   Time Elapsed: 3.22s
# Time step 171 / 22923   |   Portfolio Value: 55.27   |   Inventory: 6   |   Action: 1  |   Reward: 5.47999999999999   |   Balance: 10012.64   |   Epsilon: 1.0   |   Loss: 14.565   |   Done: False   |   Time Elapsed: 3.24s
# Time step 172 / 22923   |   Portfolio Value: 54.49   |   Inventory: 7   |   Action: 8  |   Reward: 0.0   |   Balance: 10012.64   |   Epsilon: 1.0   |   Loss: 24.624   |   Done: False   |   Time Elapsed: 3.26s
# Time step 173 / 22923   |   Portfolio Value: 46.65   |   Inventory: 6   |   Action: 1  |   Reward: -1.1200000000000045   |   Balance: 10011.52   |   Epsilon: 1.0   |   Loss: 20.518   |   Done: False   |   Time Elapsed: 3.28s
# Time step 174 / 22923   |   Portfolio Value: 43.53   |   Inventory: 7   |   Action: 6  |   Reward: 0.0   |   Balance: 10011.52   |   Epsilon: 1.0   |   Loss: 22.963   |   Done: False   |   Time Elapsed: 3.3s
# Time step 175 / 22923   |   Portfolio Value: 48.57   |   Inventory: 6   |   Action: 3  |   Reward: 0.7199999999999989   |   Balance: 10012.24   |   Epsilon: 1.0   |   Loss: 30.512   |   Done: False   |   Time Elapsed: 3.32s
# Time step 176 / 22923   |   Portfolio Value: 45.09   |   Inventory: 7   |   Action: 7  |   Reward: 0.0   |   Balance: 10012.24   |   Epsilon: 1.0   |   Loss: 29.2   |   Done: False   |   Time Elapsed: 3.34s
# Time step 177 / 22923   |   Portfolio Value: 38.86   |   Inventory: 8   |   Action: 8  |   Reward: 0.0   |   Balance: 10012.24   |   Epsilon: 1.0   |   Loss: 26.406   |   Done: False   |   Time Elapsed: 3.36s
# Time step 178 / 22923   |   Portfolio Value: -50.18   |   Inventory: 7   |   Action: 3  |   Reward: -11.129999999999995   |   Balance: 10001.11   |   Epsilon: 1.0   |   Loss: 14.4   |   Done: False   |   Time Elapsed: 3.39s
# Time step 179 / 22923   |   Portfolio Value: -60.4   |   Inventory: 8   |   Action: 7  |   Reward: 0.0   |   Balance: 10001.11   |   Epsilon: 1.0   |   Loss: 15.138   |   Done: False   |   Time Elapsed: 3.41s
# Time step 180 / 22923   |   Portfolio Value: -70.18   |   Inventory: 8   |   Action: 4  |   Reward: -0.1   |   Balance: 10001.01   |   Epsilon: 1.0   |   Loss: 18.744   |   Done: False   |   Time Elapsed: 3.43s
# Time step 181 / 22923   |   Portfolio Value: -70.9   |   Inventory: 9   |   Action: 8  |   Reward: 0.0   |   Balance: 10001.01   |   Epsilon: 1.0   |   Loss: 24.041   |   Done: False   |   Time Elapsed: 3.46s
# Time step 182 / 22923   |   Portfolio Value: -69.46   |   Inventory: 8   |   Action: 0  |   Reward: 0.1599999999999966   |   Balance: 10001.17   |   Epsilon: 1.0   |   Loss: 16.609   |   Done: False   |   Time Elapsed: 3.48s
# Time step 183 / 22923   |   Portfolio Value: -66.1   |   Inventory: 9   |   Action: 7  |   Reward: 0.0   |   Balance: 10001.17   |   Epsilon: 1.0   |   Loss: 18.11   |   Done: False   |   Time Elapsed: 3.5s
# Time step 184 / 22923   |   Portfolio Value: -56.56   |   Inventory: 8   |   Action: 1  |   Reward: 1.0600000000000023   |   Balance: 10002.23   |   Epsilon: 1.0   |   Loss: 17.513   |   Done: False   |   Time Elapsed: 3.53s
# Time step 185 / 22923   |   Portfolio Value: -51.28   |   Inventory: 9   |   Action: 7  |   Reward: 0.0   |   Balance: 10002.23   |   Epsilon: 1.0   |   Loss: 19.185   |   Done: False   |   Time Elapsed: 3.55s
# Time step 186 / 22923   |   Portfolio Value: -62.53   |   Inventory: 10   |   Action: 8  |   Reward: 0.0   |   Balance: 10002.23   |   Epsilon: 1.0   |   Loss: 21.201   |   Done: False   |   Time Elapsed: 3.57s
# Time step 187 / 22923   |   Portfolio Value: -59.23   |   Inventory: 11   |   Action: 8  |   Reward: 0.0   |   Balance: 10002.23   |   Epsilon: 1.0   |   Loss: 16.208   |   Done: False   |   Time Elapsed: 3.59s
# Time step 188 / 22923   |   Portfolio Value: -49.11   |   Inventory: 10   |   Action: 0  |   Reward: 0.9200000000000159   |   Balance: 10003.15   |   Epsilon: 1.0   |   Loss: 12.066   |   Done: False   |   Time Elapsed: 3.61s
# Time step 189 / 22923   |   Portfolio Value: -44.21   |   Inventory: 11   |   Action: 7  |   Reward: 0.0   |   Balance: 10003.15   |   Epsilon: 1.0   |   Loss: 12.237   |   Done: False   |   Time Elapsed: 3.63s
# Time step 190 / 22923   |   Portfolio Value: -70.39   |   Inventory: 10   |   Action: 2  |   Reward: -2.380000000000024   |   Balance: 10000.77   |   Epsilon: 1.0   |   Loss: 15.778   |   Done: False   |   Time Elapsed: 3.65s
# Time step 191 / 22923   |   Portfolio Value: -60.99   |   Inventory: 9   |   Action: 2  |   Reward: 0.30000000000001137   |   Balance: 10001.07   |   Epsilon: 1.0   |   Loss: 24.27   |   Done: False   |   Time Elapsed: 3.67s
# Time step 192 / 22923   |   Portfolio Value: -68.74   |   Inventory: 9   |   Action: 4  |   Reward: -0.1   |   Balance: 10000.97   |   Epsilon: 1.0   |   Loss: 29.617   |   Done: False   |   Time Elapsed: 3.69s
# Time step 193 / 22923   |   Portfolio Value: -58.57   |   Inventory: 10   |   Action: 7  |   Reward: 0.0   |   Balance: 10000.97   |   Epsilon: 1.0   |   Loss: 15.06   |   Done: False   |   Time Elapsed: 3.71s
# Time step 194 / 22923   |   Portfolio Value: -67.87   |   Inventory: 9   |   Action: 3  |   Reward: -0.9299999999999784   |   Balance: 10000.04   |   Epsilon: 1.0   |   Loss: 21.924   |   Done: False   |   Time Elapsed: 3.74s
# Time step 195 / 22923   |   Portfolio Value: -58.24   |   Inventory: 8   |   Action: 0  |   Reward: -0.5300000000000011   |   Balance: 9999.51   |   Epsilon: 1.0   |   Loss: 15.303   |   Done: False   |   Time Elapsed: 3.76s
# Time step 196 / 22923   |   Portfolio Value: -39.44   |   Inventory: 7   |   Action: 1  |   Reward: 2.819999999999993   |   Balance: 10002.33   |   Epsilon: 1.0   |   Loss: 9.522   |   Done: False   |   Time Elapsed: 3.78s
# Time step 197 / 22923   |   Portfolio Value: -43.29   |   Inventory: 6   |   Action: 2  |   Reward: -11.20999999999998   |   Balance: 9991.12   |   Epsilon: 1.0   |   Loss: 18.245   |   Done: False   |   Time Elapsed: 3.8s
# Time step 198 / 22923   |   Portfolio Value: -39.61   |   Inventory: 6   |   Action: 4  |   Reward: -0.1   |   Balance: 9991.02   |   Epsilon: 1.0   |   Loss: 18.362   |   Done: False   |   Time Elapsed: 3.82s
# Time step 199 / 22923   |   Portfolio Value: -47.23   |   Inventory: 7   |   Action: 6  |   Reward: 0.0   |   Balance: 9991.02   |   Epsilon: 1.0   |   Loss: 9.056   |   Done: False   |   Time Elapsed: 3.84s
# Time step 200 / 22923   |   Portfolio Value: -43.66   |   Inventory: 6   |   Action: 0  |   Reward: 0.5099999999999909   |   Balance: 9991.53   |   Epsilon: 1.0   |   Loss: 11.341   |   Done: False   |   Time Elapsed: 3.86s
# Time step 201 / 22923   |   Portfolio Value: -50.02   |   Inventory: 5   |   Action: 2  |   Reward: -6.410000000000025   |   Balance: 9985.12   |   Epsilon: 1.0   |   Loss: 18.35   |   Done: False   |   Time Elapsed: 3.88s
# Time step 202 / 22923   |   Portfolio Value: -50.02   |   Inventory: 4   |   Action: 0  |   Reward: -11.800000000000011   |   Balance: 9973.32   |   Epsilon: 1.0   |   Loss: 28.641   |   Done: False   |   Time Elapsed: 3.9s
# Time step 203 / 22923   |   Portfolio Value: -44.1   |   Inventory: 5   |   Action: 5  |   Reward: 0.0   |   Balance: 9973.32   |   Epsilon: 1.0   |   Loss: 15.6   |   Done: False   |   Time Elapsed: 3.93s
# Time step 204 / 22923   |   Portfolio Value: -47.05   |   Inventory: 4   |   Action: 1  |   Reward: -0.5900000000000034   |   Balance: 9972.73   |   Epsilon: 1.0   |   Loss: 16.095   |   Done: False   |   Time Elapsed: 3.95s
# Time step 205 / 22923   |   Portfolio Value: -49.29   |   Inventory: 5   |   Action: 7  |   Reward: 0.0   |   Balance: 9972.73   |   Epsilon: 1.0   |   Loss: 10.345   |   Done: False   |   Time Elapsed: 3.97s
# Time step 206 / 22923   |   Portfolio Value: -52.74   |   Inventory: 4   |   Action: 3  |   Reward: -0.6899999999999977   |   Balance: 9972.04   |   Epsilon: 1.0   |   Loss: 31.924   |   Done: False   |   Time Elapsed: 3.99s
# Time step 207 / 22923   |   Portfolio Value: -50.98   |   Inventory: 3   |   Action: 1  |   Reward: -10.030000000000001   |   Balance: 9962.01   |   Epsilon: 1.0   |   Loss: 11.228   |   Done: False   |   Time Elapsed: 4.01s
# Time step 208 / 22923   |   Portfolio Value: -52.57   |   Inventory: 4   |   Action: 7  |   Reward: 0.0   |   Balance: 9962.01   |   Epsilon: 1.0   |   Loss: 17.825   |   Done: False   |   Time Elapsed: 4.03s
# Time step 209 / 22923   |   Portfolio Value: -50.33   |   Inventory: 5   |   Action: 7  |   Reward: 0.0   |   Balance: 9962.01   |   Epsilon: 1.0   |   Loss: 7.611   |   Done: False   |   Time Elapsed: 4.05s
# Time step 210 / 22923   |   Portfolio Value: -50.33   |   Inventory: 4   |   Action: 1  |   Reward: 0.0   |   Balance: 9962.01   |   Epsilon: 1.0   |   Loss: 13.631   |   Done: False   |   Time Elapsed: 4.08s
# Time step 211 / 22923   |   Portfolio Value: -50.83   |   Inventory: 4   |   Action: 4  |   Reward: -0.1   |   Balance: 9961.91   |   Epsilon: 1.0   |   Loss: 16.193   |   Done: False   |   Time Elapsed: 4.1s
# Time step 212 / 22923   |   Portfolio Value: -51.63   |   Inventory: 3   |   Action: 3  |   Reward: 0.2599999999999909   |   Balance: 9962.17   |   Epsilon: 1.0   |   Loss: 28.914   |   Done: False   |   Time Elapsed: 4.12s
# Time step 213 / 22923   |   Portfolio Value: -57.06   |   Inventory: 2   |   Action: 3  |   Reward: -14.820000000000022   |   Balance: 9947.35   |   Epsilon: 1.0   |   Loss: 19.834   |   Done: False   |   Time Elapsed: 4.14s
# Time step 214 / 22923   |   Portfolio Value: -53.38   |   Inventory: 1   |   Action: 0  |   Reward: -3.5600000000000023   |   Balance: 9943.79   |   Epsilon: 1.0   |   Loss: 13.024   |   Done: False   |   Time Elapsed: 4.16s
# Time step 215 / 22923   |   Portfolio Value: -49.86   |   Inventory: 0   |   Action: 1  |   Reward: 6.349999999999994   |   Balance: 9950.14   |   Epsilon: 1.0   |   Loss: 18.841   |   Done: False   |   Time Elapsed: 4.19s
# Time step 216 / 22923   |   Portfolio Value: -49.86   |   Inventory: 1   |   Action: 7  |   Reward: 0.0   |   Balance: 9950.14   |   Epsilon: 1.0   |   Loss: 7.442   |   Done: False   |   Time Elapsed: 4.21s
# Time step 217 / 22923   |   Portfolio Value: -46.66   |   Inventory: 2   |   Action: 6  |   Reward: 0.0   |   Balance: 9950.14   |   Epsilon: 1.0   |   Loss: 19.296   |   Done: False   |   Time Elapsed: 4.23s
# Time step 218 / 22923   |   Portfolio Value: -47.52   |   Inventory: 3   |   Action: 6  |   Reward: 0.0   |   Balance: 9950.14   |   Epsilon: 1.0   |   Loss: 15.969   |   Done: False   |   Time Elapsed: 4.25s
# Time step 219 / 22923   |   Portfolio Value: -48.96   |   Inventory: 2   |   Action: 0  |   Reward: -0.4800000000000182   |   Balance: 9949.66   |   Epsilon: 1.0   |   Loss: 11.866   |   Done: False   |   Time Elapsed: 4.27s
# Time step 220 / 22923   |   Portfolio Value: -48.14   |   Inventory: 3   |   Action: 6  |   Reward: 0.0   |   Balance: 9949.66   |   Epsilon: 1.0   |   Loss: 8.83   |   Done: False   |   Time Elapsed: 4.3s
# Time step 221 / 22923   |   Portfolio Value: -51.92   |   Inventory: 4   |   Action: 8  |   Reward: 0.0   |   Balance: 9949.66   |   Epsilon: 1.0   |   Loss: 8.245   |   Done: False   |   Time Elapsed: 4.32s
# ...
# Time step 2659 / 22923   |   Portfolio Value: -1501.75   |   Inventory: 27   |   Action: 4  |   Reward: -0.1   |   Balance: 8612.41   |   Epsilon: 0.999   |   Loss: 2.993   |   Done: False   |   Time Elapsed: 60.0s
# Time step 2660 / 22923   |   Portfolio Value: -1502.29   |   Inventory: 28   |   Action: 8  |   Reward: 0.0   |   Balance: 8612.41   |   Epsilon: 0.999   |   Loss: 3.49   |   Done: False   |   Time Elapsed: 60.02s
# Time step 2661 / 22923   |   Portfolio Value: -1488.57   |   Inventory: 27   |   Action: 3  |   Reward: 0.4899999999999807   |   Balance: 8612.9   |   Epsilon: 0.999   |   Loss: 2.257   |   Done: False   |   Time Elapsed: 60.05s
# Time step 2662 / 22923   |   Portfolio Value: -1470.48   |   Inventory: 28   |   Action: 8  |   Reward: 0.0   |   Balance: 8612.9   |   Epsilon: 0.999   |   Loss: 3.703   |   Done: False   |   Time Elapsed: 60.07s
# Time step 2663 / 22923   |   Portfolio Value: -1490.08   |   Inventory: 27   |   Action: 1  |   Reward: -0.700000000000017   |   Balance: 8612.2   |   Epsilon: 0.999   |   Loss: 3.116   |   Done: False   |   Time Elapsed: 60.1s
# Time step 2664 / 22923   |   Portfolio Value: -1475.77   |   Inventory: 26   |   Action: 0  |   Reward: -2.200000000000017   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 1.645   |   Done: False   |   Time Elapsed: 60.12s
# Time step 2665 / 22923   |   Portfolio Value: -1464.59   |   Inventory: 27   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 1.669   |   Done: False   |   Time Elapsed: 60.14s
# Time step 2666 / 22923   |   Portfolio Value: -1458.65   |   Inventory: 28   |   Action: 8  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 1.797   |   Done: False   |   Time Elapsed: 60.16s
# Time step 2667 / 22923   |   Portfolio Value: -1458.37   |   Inventory: 29   |   Action: 5  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 3.512   |   Done: False   |   Time Elapsed: 60.19s
# Time step 2668 / 22923   |   Portfolio Value: -1488.82   |   Inventory: 30   |   Action: 8  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 3.065   |   Done: False   |   Time Elapsed: 60.21s
# Time step 2669 / 22923   |   Portfolio Value: -1501.72   |   Inventory: 31   |   Action: 6  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 2.763   |   Done: False   |   Time Elapsed: 60.23s
# Time step 2670 / 22923   |   Portfolio Value: -1512.26   |   Inventory: 32   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 3.555   |   Done: False   |   Time Elapsed: 60.25s
# Time step 2671 / 22923   |   Portfolio Value: -1546.82   |   Inventory: 33   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 2.094   |   Done: False   |   Time Elapsed: 60.27s
# Time step 2672 / 22923   |   Portfolio Value: -1589.06   |   Inventory: 34   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.0   |   Epsilon: 0.999   |   Loss: 4.462   |   Done: False   |   Time Elapsed: 60.29s
# Time step 2673 / 22923   |   Portfolio Value: -1560.5   |   Inventory: 33   |   Action: 2  |   Reward: 0.8400000000000034   |   Balance: 8610.84   |   Epsilon: 0.999   |   Loss: 4.958   |   Done: False   |   Time Elapsed: 60.32s
# Time step 2674 / 22923   |   Portfolio Value: -1577.0   |   Inventory: 34   |   Action: 8  |   Reward: 0.0   |   Balance: 8610.84   |   Epsilon: 0.999   |   Loss: 2.642   |   Done: False   |   Time Elapsed: 60.34s
# Time step 2675 / 22923   |   Portfolio Value: -1577.34   |   Inventory: 35   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.84   |   Epsilon: 0.999   |   Loss: 2.898   |   Done: False   |   Time Elapsed: 60.36s
# Time step 2676 / 22923   |   Portfolio Value: -1588.19   |   Inventory: 34   |   Action: 1  |   Reward: -0.3100000000000023   |   Balance: 8610.53   |   Epsilon: 0.999   |   Loss: 2.42   |   Done: False   |   Time Elapsed: 60.39s
# Time step 2677 / 22923   |   Portfolio Value: -1632.39   |   Inventory: 35   |   Action: 8  |   Reward: 0.0   |   Balance: 8610.53   |   Epsilon: 0.999   |   Loss: 1.987   |   Done: False   |   Time Elapsed: 60.41s
# Time step 2678 / 22923   |   Portfolio Value: -1618.04   |   Inventory: 34   |   Action: 0  |   Reward: 0.4099999999999966   |   Balance: 8610.94   |   Epsilon: 0.999   |   Loss: 4.148   |   Done: False   |   Time Elapsed: 60.43s
# Time step 2679 / 22923   |   Portfolio Value: -1605.12   |   Inventory: 35   |   Action: 6  |   Reward: 0.0   |   Balance: 8610.94   |   Epsilon: 0.999   |   Loss: 4.845   |   Done: False   |   Time Elapsed: 60.46s
# Time step 2680 / 22923   |   Portfolio Value: -1611.77   |   Inventory: 36   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.94   |   Epsilon: 0.999   |   Loss: 1.864   |   Done: False   |   Time Elapsed: 60.48s
# Time step 2681 / 22923   |   Portfolio Value: -1609.61   |   Inventory: 37   |   Action: 6  |   Reward: 0.0   |   Balance: 8610.94   |   Epsilon: 0.999   |   Loss: 5.344   |   Done: False   |   Time Elapsed: 60.5s
# Time step 2682 / 22923   |   Portfolio Value: -1574.83   |   Inventory: 36   |   Action: 0  |   Reward: 0.9399999999999977   |   Balance: 8611.88   |   Epsilon: 0.999   |   Loss: 4.007   |   Done: False   |   Time Elapsed: 60.52s
# Time step 2683 / 22923   |   Portfolio Value: -1580.95   |   Inventory: 37   |   Action: 5  |   Reward: 0.0   |   Balance: 8611.88   |   Epsilon: 0.999   |   Loss: 4.818   |   Done: False   |   Time Elapsed: 60.55s
# Time step 2684 / 22923   |   Portfolio Value: -1569.48   |   Inventory: 38   |   Action: 6  |   Reward: 0.0   |   Balance: 8611.88   |   Epsilon: 0.999   |   Loss: 2.229   |   Done: False   |   Time Elapsed: 60.57s
# Time step 2685 / 22923   |   Portfolio Value: -1507.92   |   Inventory: 39   |   Action: 5  |   Reward: 0.0   |   Balance: 8611.88   |   Epsilon: 0.999   |   Loss: 4.9   |   Done: False   |   Time Elapsed: 60.59s
# Time step 2686 / 22923   |   Portfolio Value: -1552.38   |   Inventory: 40   |   Action: 6  |   Reward: 0.0   |   Balance: 8611.88   |   Epsilon: 0.999   |   Loss: 3.788   |   Done: False   |   Time Elapsed: 60.61s
# Time step 2687 / 22923   |   Portfolio Value: -1582.38   |   Inventory: 41   |   Action: 7  |   Reward: 0.0   |   Balance: 8611.88   |   Epsilon: 0.999   |   Loss: 2.415   |   Done: False   |   Time Elapsed: 60.63s
# Time step 2688 / 22923   |   Portfolio Value: -1562.7   |   Inventory: 40   |   Action: 2  |   Reward: 0.47999999999998977   |   Balance: 8612.36   |   Epsilon: 0.999   |   Loss: 2.696   |   Done: False   |   Time Elapsed: 60.65s
# Time step 2689 / 22923   |   Portfolio Value: -1553.1   |   Inventory: 39   |   Action: 1  |   Reward: -0.030000000000001137   |   Balance: 8612.33   |   Epsilon: 0.999   |   Loss: 3.931   |   Done: False   |   Time Elapsed: 60.67s
# Time step 2690 / 22923   |   Portfolio Value: -1542.57   |   Inventory: 40   |   Action: 7  |   Reward: 0.0   |   Balance: 8612.33   |   Epsilon: 0.999   |   Loss: 2.051   |   Done: False   |   Time Elapsed: 60.7s
# Time step 2691 / 22923   |   Portfolio Value: -1553.77   |   Inventory: 39   |   Action: 3  |   Reward: -0.28000000000000114   |   Balance: 8612.05   |   Epsilon: 0.999   |   Loss: 1.747   |   Done: False   |   Time Elapsed: 60.72s
# Time step 2692 / 22923   |   Portfolio Value: -1557.28   |   Inventory: 38   |   Action: 2  |   Reward: -1.2699999999999818   |   Balance: 8610.78   |   Epsilon: 0.999   |   Loss: 2.921   |   Done: False   |   Time Elapsed: 60.74s
# Time step 2693 / 22923   |   Portfolio Value: -1538.0   |   Inventory: 38   |   Action: 4  |   Reward: -0.1   |   Balance: 8610.68   |   Epsilon: 0.999   |   Loss: 5.641   |   Done: False   |   Time Elapsed: 60.76s
# Time step 2694 / 22923   |   Portfolio Value: -1506.46   |   Inventory: 39   |   Action: 6  |   Reward: 0.0   |   Balance: 8610.68   |   Epsilon: 0.999   |   Loss: 5.602   |   Done: False   |   Time Elapsed: 60.78s
# Time step 2695 / 22923   |   Portfolio Value: -1533.76   |   Inventory: 40   |   Action: 7  |   Reward: 0.0   |   Balance: 8610.68   |   Epsilon: 0.999   |   Loss: 4.146   |   Done: False   |   Time Elapsed: 60.8s
# Time step 2696 / 22923   |   Portfolio Value: -1537.36   |   Inventory: 39   |   Action: 2  |   Reward: -0.09000000000000341   |   Balance: 8610.59   |   Epsilon: 0.999   |   Loss: 4.241   |   Done: False   |   Time Elapsed: 60.83s
# Time step 2697 / 22923   |   Portfolio Value: -1524.1   |   Inventory: 38   |   Action: 0  |   Reward: -0.45000000000001705   |   Balance: 8610.14   |   Epsilon: 0.999   |   Loss: 2.979   |   Done: False   |   Time Elapsed: 60.85s
# Time step 2698 / 22923   |   Portfolio Value: -1514.98   |   Inventory: 39   |   Action: 6  |   Reward: 0.0   |   Balance: 8610.14   |   Epsilon: 0.999   |   Loss: 2.934   |   Done: False   |   Time Elapsed: 60.87s
# Time step 2699 / 22923   |   Portfolio Value: -1564.9   |   Inventory: 40   |   Action: 5  |   Reward: 0.0   |   Balance: 8610.14   |   Epsilon: 0.999   |   Loss: 4.651   |   Done: False   |   Time Elapsed: 60.89s
# Time step 2700 / 22923   |   Portfolio Value: -1546.5   |   Inventory: 41   |   Action: 5  |   Reward: 0.0   |   Balance: 8610.14   |   Epsilon: 0.999   |   Loss: 1.503   |   Done: False   |   Time Elapsed: 60.92s
# Time step 2701 / 22923   |   Portfolio Value: -1536.25   |   Inventory: 40   |   Action: 2  |   Reward: 0.25   |   Balance: 8610.39   |   Epsilon: 0.999   |   Loss: 6.803   |   Done: False   |   Time Elapsed: 60.94s
# Time step 2702 / 22923   |   Portfolio Value: -1584.25   |   Inventory: 39   |   Action: 2  |   Reward: -0.4900000000000091   |   Balance: 8609.9   |   Epsilon: 0.999   |   Loss: 3.324   |   Done: False   |   Time Elapsed: 60.96s
# Time step 2703 / 22923   |   Portfolio Value: -1588.54   |   Inventory: 40   |   Action: 7  |   Reward: 0.0   |   Balance: 8609.9   |   Epsilon: 0.999   |   Loss: 6.906   |   Done: False   |   Time Elapsed: 60.98s
# Time step 2704 / 22923   |   Portfolio Value: -1590.54   |   Inventory: 41   |   Action: 7  |   Reward: 0.0   |   Balance: 8609.9   |   Epsilon: 0.999   |   Loss: 1.963   |   Done: False   |   Time Elapsed: 61.0s
# Time step 2705 / 22923   |   Portfolio Value: -1568.09   |   Inventory: 41   |   Action: 4  |   Reward: -0.1   |   Balance: 8609.8   |   Epsilon: 0.999   |   Loss: 2.487   |   Done: False   |   Time Elapsed: 61.03s
# Time step 2706 / 22923   |   Portfolio Value: -1559.48   |   Inventory: 40   |   Action: 3  |   Reward: 0.7599999999999909   |   Balance: 8610.56   |   Epsilon: 0.999   |   Loss: 2.493   |   Done: False   |   Time Elapsed: 61.05s
# Time step 2707 / 22923   |   Portfolio Value: -1567.08   |   Inventory: 41   |   Action: 5  |   Reward: 0.0   |   Balance: 8610.56   |   Epsilon: 0.999   |   Loss: 2.656   |   Done: False   |   Time Elapsed: 61.07s
# Time step 2708 / 22923   |   Portfolio Value: -1556.01   |   Inventory: 42   |   Action: 8  |   Reward: 0.0   |   Balance: 8610.56   |   Epsilon: 0.999   |   Loss: 2.09   |   Done: False   |   Time Elapsed: 61.09s
# Time step 2709 / 22923   |   Portfolio Value: -1527.45   |   Inventory: 41   |   Action: 0  |   Reward: 0.6800000000000068   |   Balance: 8611.24   |   Epsilon: 0.999   |   Loss: 4.382   |   Done: False   |   Time Elapsed: 61.11s
# Time step 2710 / 22923   |   Portfolio Value: -1520.07   |   Inventory: 40   |   Action: 0  |   Reward: 1.1299999999999955   |   Balance: 8612.37   |   Epsilon: 0.999   |   Loss: 5.193   |   Done: False   |   Time Elapsed: 61.14s
# Time step 2711 / 22923   |   Portfolio Value: -1534.87   |   Inventory: 39   |   Action: 1  |   Reward: 1.2800000000000011   |   Balance: 8613.65   |   Epsilon: 0.999   |   Loss: 1.761   |   Done: False   |   Time Elapsed: 61.16s
# Time step 2712 / 22923   |   Portfolio Value: -1549.79   |   Inventory: 39   |   Action: 4  |   Reward: -0.1   |   Balance: 8613.55   |   Epsilon: 0.999   |   Loss: 2.917   |   Done: False   |   Time Elapsed: 61.18s
# Time step 2713 / 22923   |   Portfolio Value: -1552.13   |   Inventory: 40   |   Action: 6  |   Reward: 0.0   |   Balance: 8613.55   |   Epsilon: 0.999   |   Loss: 4.376   |   Done: False   |   Time Elapsed: 61.2s
# Time step 2714 / 22923   |   Portfolio Value: -1574.93   |   Inventory: 39   |   Action: 3  |   Reward: -0.5700000000000216   |   Balance: 8612.98   |   Epsilon: 0.999   |   Loss: 3.059   |   Done: False   |   Time Elapsed: 61.22s
# Time step 2715 / 22923   |   Portfolio Value: -1563.62   |   Inventory: 38   |   Action: 2  |   Reward: -1.3199999999999932   |   Balance: 8611.66   |   Epsilon: 0.999   |   Loss: 1.993   |   Done: False   |   Time Elapsed: 61.24s
# Time step 2716 / 22923   |   Portfolio Value: -1538.54   |   Inventory: 37   |   Action: 3  |   Reward: 0.8200000000000216   |   Balance: 8612.48   |   Epsilon: 0.999   |   Loss: 2.589   |   Done: False   |   Time Elapsed: 61.26s
# Time step 2717 / 22923   |   Portfolio Value: -1408.3   |   Inventory: 36   |   Action: 3  |   Reward: 4.649999999999977   |   Balance: 8617.13   |   Epsilon: 0.999   |   Loss: 1.01   |   Done: False   |   Time Elapsed: 61.28s
# Time step 2718 / 22923   |   Portfolio Value: -1439.0   |   Inventory: 36   |   Action: 4  |   Reward: -0.1   |   Balance: 8617.03   |   Epsilon: 0.999   |   Loss: 3.446   |   Done: False   |   Time Elapsed: 61.31s
# Time step 2719 / 22923   |   Portfolio Value: -1440.44   |   Inventory: 35   |   Action: 1  |   Reward: 4.590000000000003   |   Balance: 8621.62   |   Epsilon: 0.999   |   Loss: 2.458   |   Done: False   |   Time Elapsed: 61.33s
# Time step 2720 / 22923   |   Portfolio Value: -1459.69   |   Inventory: 36   |   Action: 8  |   Reward: 0.0   |   Balance: 8621.62   |   Epsilon: 0.999   |   Loss: 7.549   |   Done: False   |   Time Elapsed: 61.35s
# Time step 2721 / 22923   |   Portfolio Value: -1442.77   |   Inventory: 37   |   Action: 8  |   Reward: 0.0   |   Balance: 8621.62   |   Epsilon: 0.999   |   Loss: 3.596   |   Done: False   |   Time Elapsed: 61.37s
# Time step 2722 / 22923   |   Portfolio Value: -1440.18   |   Inventory: 38   |   Action: 7  |   Reward: 0.0   |   Balance: 8621.62   |   Epsilon: 0.999   |   Loss: 3.427   |   Done: False   |   Time Elapsed: 61.39s
# Time step 2723 / 22923   |   Portfolio Value: -1469.92   |   Inventory: 38   |   Action: 4  |   Reward: -0.1   |   Balance: 8621.52   |   Epsilon: 0.999   |   Loss: 2.84   |   Done: False   |   Time Elapsed: 61.42s
# Time step 2724 / 22923   |   Portfolio Value: -1460.42   |   Inventory: 39   |   Action: 5  |   Reward: 0.0   |   Balance: 8621.52   |   Epsilon: 0.999   |   Loss: 3.178   |   Done: False   |   Time Elapsed: 61.44s
# Time step 2725 / 22923   |   Portfolio Value: -1470.17   |   Inventory: 38   |   Action: 1  |   Reward: -0.25   |   Balance: 8621.27   |   Epsilon: 0.999   |   Loss: 3.111   |   Done: False   |   Time Elapsed: 61.46s
# Time step 2726 / 22923   |   Portfolio Value: -1454.21   |   Inventory: 39   |   Action: 6  |   Reward: 0.0   |   Balance: 8621.27   |   Epsilon: 0.999   |   Loss: 3.11   |   Done: False   |   Time Elapsed: 61.48s
# Time step 2727 / 22923   |   Portfolio Value: -1457.72   |   Inventory: 38   |   Action: 3  |   Reward: -0.09000000000000341   |   Balance: 8621.18   |   Epsilon: 0.999   |   Loss: 3.036   |   Done: False   |   Time Elapsed: 61.5s
# Time step 2728 / 22923   |   Portfolio Value: -1337.26   |   Inventory: 37   |   Action: 1  |   Reward: 2.719999999999999   |   Balance: 8623.9   |   Epsilon: 0.999   |   Loss: 2.796   |   Done: False   |   Time Elapsed: 61.52s
# Time step 2729 / 22923   |   Portfolio Value: -1345.4   |   Inventory: 38   |   Action: 6  |   Reward: 0.0   |   Balance: 8623.9   |   Epsilon: 0.999   |   Loss: 3.804   |   Done: False   |   Time Elapsed: 61.54s
# Time step 2730 / 22923   |   Portfolio Value: -1338.56   |   Inventory: 37   |   Action: 0  |   Reward: 0.1799999999999784   |   Balance: 8624.08   |   Epsilon: 0.999   |   Loss: 3.005   |   Done: False   |   Time Elapsed: 61.57s

# %%
import matplotlib.pyplot as plt

train_df, test_df, train_close, test_close = get_precollected_data(split_ratio=0.8)

def plot_portfolio_value(data, title, eth_price, filename):
    plt.figure(figsize=(20, 12))
    plt.plot(eth_price["Close"][::50], label="ETH Price")
    # for i in range(40, len(data)):
    #     plt.plot(data[i]["Portfolio Value"], label="Portfolio Value")
    plt.plot(data[len(data)-1]["Portfolio Value"][::50], label="Portfolio Value")
    plt.xlabel("Time Steps")
    plt.ylabel("Value")
    plt.legend()
    plt.title(title)
    plt.savefig(filename)
    

def plot_portfolio_value_test(data, title, eth_price, filename):
    plt.figure(figsize=(20, 12))
    plt.plot(eth_price["Close"][::10], label="ETH Price")
    plt.plot(data["Portfolio Value"][::10], label="Portfolio Value")
    plt.xlabel("Time Steps")
    plt.ylabel("Value")
    plt.legend()
    plt.title(title)
    plt.savefig(filename)

def plot_inventory_held(data, title, filename):
    plt.figure(figsize=(12, 6))
    plt.plot(data["Inventory Size"][::10], label="Inventory Held")
    plt.xlabel("Time Steps")
    plt.ylabel("Amount")
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.savefig(filename)

def plot_actions(data, title, filename):
    plt.figure(figsize=(12, 6))
    plt.plot(data["Actions"][::10], label="Actions")
    plt.xlabel("Time Steps")
    plt.ylabel("Action")
    plt.title(title)
    plt.legend()
    plt.grid()
    plt.savefig(filename)

# Visualize the data
# You can change the index to visualize a specific training episode

with open ("Output/episode_mem.json", "r") as f:
    episode_data = json.load(f)

with open ("Output/testing_mem.json", "r") as f:
    testing_data = json.load(f)

# look at last episode
selected_episode = len(episode_data) - 1


# plot_portfolio_value(episode_data, f"Portfolio Value for Episode {selected_episode}", train_close, "Output/episode_portfolio.png")
plot_portfolio_value(episode_data, f"Portfolio Value for Training", train_close, "Output/episode_portfolio.png")
# plot_inventory_held(episode_data[selected_episode], f"Inventory Held for Episode {selected_episode}", "Output/episode_inventory.png")
# plot_actions(episode_data[selected_episode], f"Actions for Episode {selected_episode}", "Output/episode_actions.png")

plot_portfolio_value_test(testing_data, f"Portfolio Value for Testing", test_close, "Output/testing_portfolio.png")
# plot_inventory_held(testing_data, f"Inventory Held for Testing", "Output/testing_inventory.png")
# plot_actions(testing_data, f"Actions for Testing", "Output/testing_actions.png")
# Out:
# Pre-collected data loaded successfully.
# NaN values dropped.
# Data split.
# Train data saved.
# Test data saved.
